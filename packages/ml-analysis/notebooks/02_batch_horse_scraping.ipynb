# %%
# ===== セル1: セットアップ =====

import sys
import os
import time
from datetime import datetime
import json

# パス設定
current_dir = os.getcwd()  # notebooks/
project_root = os.path.dirname(current_dir)  # ml-analysis/
scraping_path = os.path.join(project_root, 'src', 'scraping')

# パス確認
print(f"📁 現在地: {current_dir}")
print(f"📁 プロジェクトルート: {project_root}")
print(f"📁 スクレイピングパス: {scraping_path}")
print(f"✅ パス存在確認: {os.path.exists(scraping_path)}")

if scraping_path not in sys.path:
    sys.path.append(scraping_path)

# モジュールインポート
from simple_offset_scraper import (
    SimpleOffsetHorseListScraper, 
    CompleteBatchProcessor,
    get_next_100_horses,
    run_complete_100_horses_batch,
    test_offset_scraper
)

print("🚀 モジュール読み込み完了")
print("-" * 50)
# Out:
# 📁 現在地: /Users/skdata_mng/Documents/PROJECTS/STALLION/stallion-analytics/packages/ml-analysis/notebooks
# 📁 プロジェクトルート: /Users/skdata_mng/Documents/PROJECTS/STALLION/stallion-analytics/packages/ml-analysis
# 📁 スクレイピングパス: /Users/skdata_mng/Documents/PROJECTS/STALLION/stallion-analytics/packages/ml-analysis/src/scraping
# ✅ パス存在確認: True
# 🚀 モジュール読み込み完了
# --------------------------------------------------

# %%
print("🔍 詳細データ処理開始")

# CompleteBatchProcessorを使用
processor = CompleteBatchProcessor()

# 100頭で詳細処理をテスト
batch_results = processor.collect_and_process_horses(
    total_target=200,
    batch_size=25,
    start_offset=500,
    min_birth_year=1800,
    process_details=True,  # 詳細処理有効
    delay_between_horses=2  # n秒間隔
)

print("\n📊 バッチ処理結果:")
print(f"  リスト取得: {batch_results.get('list_count', 0)}頭")
print(f"  詳細成功: {len(batch_results.get('success', []))}頭")
print(f"  詳細失敗: {len(batch_results.get('failed', []))}頭")
# Out:
# 🔍 詳細データ処理開始
# ======================================================================
# 🏇 完全バッチ処理開始
# ======================================================================
# 🎯 目標: 200頭
# 📦 バッチサイズ: 25頭
# 📍 開始オフセット: 500
# 📅 最小生年: 1800年
# 🔧 詳細処理: 有効
#
# 🔍 Step 1: 馬リスト取得
# 📦 リストバッチ: オフセット500, 25頭取得
# 🎯 G1馬取得開始:
#    オフセット: 500
#    最大取得数: 25頭
#    最小生年: 1800年
# --------------------------------------------------
# 📄 開始ページ: 6, ページ内位置: 0
#
# 📄 ページ6を処理中...
#   ✓ [  1] ユウフヨウホウ (1997年)
#   ✓ [  2] タップダンスシチー (1997年)
#   ✓ [  3] マイネルコンバット (1997年)
#   ✓ [  4] ティコティコタック (1997年)
#   ✓ [  5] アグネスフライト (1997年)
#   ✓ [  6] エアシャカール (1997年)
#   ✓ [  7] イーグルカフェ (1997年)
#   ✓ [  8] トウカイポイント (1996年)
#   ✓ [  9] スティンガー (1996年)
#   ✓ [ 10] トーホウエンペラー (1996年)
#   ✓ [ 11] トロットスター (1996年)
#   ✓ [ 12] ウメノファイバー (1996年)
#   ✓ [ 13] リージェントブラフ (1996年)
#   ✓ [ 14] タイキヘラクレス (1996年)
#   ✓ [ 15] ゴールドティアラ (1996年)
#   ✓ [ 16] ブゼンキャンドル (1996年)
#   ✓ [ 17] サウスヴィグラス (1996年)
#   ✓ [ 18] オリオンザサンクス (1996年)
#   ✓ [ 19] アドマイヤコジーン (1996年)
#   ✓ [ 20] プリモディーネ (1996年)
#   ✓ [ 21] ナリタトップロード (1996年)
#   ✓ [ 22] ノボトゥルー (1996年)
#   ✓ [ 23] メイショウドトウ (1996年)
#   ✓ [ 24] テイエムオペラオー (1996年)
#   ✓ [ 25] アドマイヤベガ (1996年)
#
# ✅ 合計25頭を取得しました
# ✅ リストバッチ完了: 25頭追加, 累計25頭
# 📦 リストバッチ: オフセット525, 25頭取得
# 🎯 G1馬取得開始:
#    オフセット: 525
#    最大取得数: 25頭
#    最小生年: 1800年
# --------------------------------------------------
# 📄 開始ページ: 6, ページ内位置: 25
#
# 📄 ページ6を処理中...
#   ✓ [  1] トゥザヴィクトリー (1996年)
#   ✓ [  2] シンボリインディ (1996年)
#   ✓ [  3] Fairy King Prawn (1995年)
#   ✓ [  4] マキバスナイパー (1995年)
#   ✓ [  5] エリモエクセル (1995年)
#   ✓ [  6] インテリパワー (1995年)
#   ✓ [  7] ニホンピロジュピタ (1995年)
#   ✓ [  8] スペシャルウィーク (1995年)
#   ✓ [  9] キングヘイロー (1995年)
#   ✓ [ 10] アグネスワールド (1995年)
#   ✓ [ 11] セイウンスカイ (1995年)
#   ✓ [ 12] ワールドクリーク (1995年)
#   ✓ [ 13] アインブライド (1995年)
#   ✓ [ 14] ナリタホマレ (1995年)
#   ✓ [ 15] ランドパワー (1995年)
#   ✓ [ 16] エアジハード (1995年)
#   ✓ [ 17] ファレノプシス (1995年)
#   ✓ [ 18] ウイングアロー (1995年)
#   ✓ [ 19] エルコンドルパサー (1995年)
#   ✓ [ 20] マイネルラヴ (1995年)
#   ✓ [ 21] Karasi (1995年)
#   ✓ [ 22] グラスワンダー (1995年)
#   ✓ [ 23] St. Steven (1994年)
#   ✓ [ 24] メイセイオペラ (1994年)
#   ✓ [ 25] マチカネフクキタル (1994年)
#
# ✅ 合計25頭を取得しました
# ✅ リストバッチ完了: 25頭追加, 累計50頭
# 📦 リストバッチ: オフセット550, 25頭取得
# 🎯 G1馬取得開始:
#    オフセット: 550
#    最大取得数: 25頭
#    最小生年: 1800年
# --------------------------------------------------
# 📄 開始ページ: 6, ページ内位置: 50
#
# 📄 ページ6を処理中...
#   ✓ [  1] ブラックホーク (1994年)
#   ✓ [  2] ファストフレンド (1994年)
#   ✓ [  3] テイエムメガトン (1994年)
#   ✓ [  4] メジロドーベル (1994年)
#   ✓ [  5] サイレンススズカ (1994年)
#   ✓ [  6] サニーブライアン (1994年)
#   ✓ [  7] メジロブライト (1994年)
#   ✓ [  8] キョウエイマーチ (1994年)
#   ✓ [  9] シーキングザパール (1994年)
#   ✓ [ 10] マイネルマックス (1994年)
#   ✓ [ 11] ゴッドスピード (1994年)
#   ✓ [ 12] ステイゴールド (1994年)
#   ✓ [ 13] タイキシャトル (1994年)
#   ✓ [ 14] シルクジャスティス (1994年)
#   ✓ [ 15] ダイタクヤマト (1994年)
#   ✓ [ 16] ダンスインザダーク (1993年)
#   ✓ [ 17] イシノサンデー (1993年)
#   ✓ [ 18] ゴーカイ (1993年)
#   ✓ [ 19] シンコウフォレスト (1993年)
#   ✓ [ 20] メジロファラオ (1993年)
#   ✓ [ 21] マサラッキ (1993年)
#   ✓ [ 22] シンコウウインディ (1993年)
#   ✓ [ 23] ファビラスラフイン (1993年)
#   ✓ [ 24] バブルガムフェロー (1993年)
#   ✓ [ 25] エアグルーヴ (1993年)
#
# ✅ 合計25頭を取得しました
# ✅ リストバッチ完了: 25頭追加, 累計75頭
# 📦 リストバッチ: オフセット575, 25頭取得
# 🎯 G1馬取得開始:
#    オフセット: 575
#    最大取得数: 25頭
#    最小生年: 1800年
# --------------------------------------------------
# 📄 開始ページ: 6, ページ内位置: 75
#
# 📄 ページ6を処理中...
#   ✓ [  1] トーヨーシアトル (1993年)
#   ✓ [  2] エリモシック (1993年)
#   ✓ [  3] ファイトガリバー (1993年)
#   ✓ [  4] ビワハイジ (1993年)
#   ✓ [  5] フサイチコンコルド (1993年)
#   ✓ [  6] タイキフォーチュン (1993年)
#   ✓ [  7] マーベラスサンデー (1992年)
#   ✓ [  8] ダンスパートナー (1992年)
#   ✓ [  9] フラワーパーク (1992年)
#   ✓ [ 10] コンサートボーイ (1992年)
#   ✓ [ 11] ジェニュイン (1992年)
#   ✓ [ 12] タヤスツヨシ (1992年)
#   ✓ [ 13] ヤマニンパラダイス (1992年)
#   ✓ [ 14] ピルサドスキー (1992年)
#   ✓ [ 15] グルメフロンティア (1992年)
#   ✓ [ 16] フジキセキ (1992年)
#   ✓ [ 17] サクラキャンドル (1992年)
#   ✓ [ 18] マヤノトップガン (1992年)
#   ✓ [ 19] ワンダーパヒューム (1992年)
#   ✓ [ 20] アブクマポーロ (1992年)
#   ✓ [ 21] ヒシアケボノ (1992年)
#   ✓ [ 22] シングスピール (1992年)
#   ✓ [ 23] タイキシャーロック (1992年)
#
# 📄 ページ7を処理中...
#   ✓ [ 24] オグリローマン (1991年)
#   ✓ [ 25] サクラローレル (1991年)
#
# ✅ 合計25頭を取得しました
# ✅ リストバッチ完了: 25頭追加, 累計100頭
# 📦 リストバッチ: オフセット600, 25頭取得
# 🎯 G1馬取得開始:
#    オフセット: 600
#    最大取得数: 25頭
#    最小生年: 1800年
# --------------------------------------------------
# 📄 開始ページ: 7, ページ内位置: 0
#
# 📄 ページ7を処理中...
#   ✓ [  1] オグリローマン (1991年)
#   ✓ [  2] サクラローレル (1991年)
#   ✓ [  3] ナリタブライアン (1991年)
#   ✓ [  4] シンコウキング (1991年)
#   ✓ [  5] ハートレイク (1991年)
#   ✓ [  6] オフサイドトラップ (1991年)
#   ✓ [  7] チョウカイキャロル (1991年)
#   ✓ [  8] ヒシアマゾン (1991年)
#   ✓ [  9] タイキブリザード (1991年)
#   ✓ [ 10] ナリタタイシン (1990年)
#   ✓ [ 11] ダンツシアトル (1990年)
#   ✓ [ 12] サクラチトセオー (1990年)
#   ✓ [ 13] ネーハイシーザー (1990年)
#   ✓ [ 14] スエヒロジョウオー (1990年)
#   ✓ [ 15] ノースフライト (1990年)
#   ✓ [ 16] ホクトベガ (1990年)
#   ✓ [ 17] ウイニングチケット (1990年)
#   ✓ [ 18] マーベラスクラウン (1990年)
#   ✓ [ 19] ビワハヤヒデ (1990年)
#   ✓ [ 20] ベガ (1990年)
#   ✓ [ 21] エルウェーウィン (1990年)
#   ✓ [ 22] Lando (1990年)
#   ✓ [ 23] トロットサンダー (1989年)
#   ✓ [ 24] ミホノブルボン (1989年)
#   ✓ [ 25] レガシーワールド (1989年)
#
# ✅ 合計25頭を取得しました
# ✅ リストバッチ完了: 23頭追加, 累計123頭
# 📦 リストバッチ: オフセット625, 25頭取得
# 🎯 G1馬取得開始:
#    オフセット: 625
#    最大取得数: 25頭
#    最小生年: 1800年
# --------------------------------------------------
# 📄 開始ページ: 7, ページ内位置: 25
#
# 📄 ページ7を処理中...
#   ✓ [  1] ニシノフラワー (1989年)
#   ✓ [  2] サクラバクシンオー (1989年)
#   ✓ [  3] アドラーブル (1989年)
#   ✓ [  4] タケノベルベット (1989年)
#   ✓ [  5] ライスシャワー (1989年)
#   ✓ [  6] シンコウラブリイ (1989年)
#   ✓ [  7] ヤマニンゼファー (1988年)
#   ✓ [  8] シスタートウショウ (1988年)
#   ✓ [  9] レオダーバン (1988年)
#   ✓ [ 10] トウカイテイオー (1988年)
#   ✓ [ 11] リンデンリリー (1988年)
#   ✓ [ 12] イソノルーブル (1988年)
#   ✓ [ 13] リンドシェーバー (1988年)
#   ✓ [ 14] イブキマイカグラ (1988年)
#   ✓ [ 15] アグネスフローラ (1987年)
#   ✓ [ 16] コガネタイフウ (1987年)
#   ✓ [ 17] プレクラスニー (1987年)
#   ✓ [ 18] レッツゴーターキン (1987年)
#   ✓ [ 19] ハクタイセイ (1987年)
#   ✓ [ 20] ダイイチルビー (1987年)
#   ✓ [ 21] メジロライアン (1987年)
#   ✓ [ 22] アイネスフウジン (1987年)
#   ✓ [ 23] ダイタクヘリオス (1987年)
#   ✓ [ 24] メジロマックイーン (1987年)
#   ✓ [ 25] エイシンサニー (1987年)
#
# ✅ 合計25頭を取得しました
# ✅ リストバッチ完了: 25頭追加, 累計148頭
# 📦 リストバッチ: オフセット650, 25頭取得
# 🎯 G1馬取得開始:
#    オフセット: 650
#    最大取得数: 25頭
#    最小生年: 1800年
# --------------------------------------------------
# 📄 開始ページ: 7, ページ内位置: 50
#
# 📄 ページ7を処理中...
#   ✓ [  1] メジロパーマー (1987年)
#   ✓ [  2] キョウエイタップ (1987年)
#   ✓ [  3] サンドピアリス (1986年)
#   ✓ [  4] ドクタースパート (1986年)
#   ✓ [  5] ラッキーゲラン (1986年)
#   ✓ [  6] ゴールデンフェザント (1986年)
#   ✓ [  7] バンブービギン (1986年)
#   ✓ [  8] オサイチジョージ (1986年)
#   ✓ [  9] ウィナーズサークル (1986年)
#   ✓ [ 10] サクラホクトオー (1986年)
#   ✓ [ 11] ライトカラー (1986年)
#   ✓ [ 12] シャダイカグラ (1986年)
#   ✓ [ 13] Better Loosen Up (1985年)
#   ✓ [ 14] コスモドリーム (1985年)
#   ✓ [ 15] ダイユウサク (1985年)
#   ✓ [ 16] スーパークリーク (1985年)
#   ✓ [ 17] ミヤマポピー (1985年)
#   ✓ [ 18] バンブーメモリー (1985年)
#   ✓ [ 19] サッカーボーイ (1985年)
#   ✓ [ 20] パッシングショット (1985年)
#   ✓ [ 21] ヤエノムテキ (1985年)
#   ✓ [ 22] オグリキャップ (1985年)
#   ✓ [ 23] アラホウトク (1985年)
#   ✓ [ 24] サクラチヨノオー (1985年)
#   ✓ [ 25] タマモクロス (1984年)
#
# ✅ 合計25頭を取得しました
# ✅ リストバッチ完了: 25頭追加, 累計173頭
# 📦 リストバッチ: オフセット675, 25頭取得
# 🎯 G1馬取得開始:
#    オフセット: 675
#    最大取得数: 25頭
#    最小生年: 1800年
# --------------------------------------------------
# 📄 開始ページ: 7, ページ内位置: 75
#
# 📄 ページ7を処理中...
#   ✓ [  1] イナリワン (1984年)
#   ✓ [  2] マックスビューティ (1984年)
#   ✓ [  3] サクラスターオー (1984年)
#   ✓ [  4] タレンティドガール (1984年)
#   ✓ [  5] ゴールドシチー (1984年)
#   ✓ [  6] メリーナイス (1984年)
#   ✓ [  7] ペイザバトラー (1984年)
#   ✓ [  8] Le Glorieux (1984年)
#   ✓ [  9] Horlicks (1983年)
#   ✓ [ 10] フレッシュボイス (1983年)
#   ✓ [ 11] メジロデュレン (1983年)
#   ✓ [ 12] ニッポーテイオー (1983年)
#   ✓ [ 13] メジロラモーヌ (1983年)
#   ✓ [ 14] ダイナコスモス (1983年)
#   ✓ [ 15] ダイナガリバー (1983年)
#   ✓ [ 16] クシロキング (1982年)
#   ✓ [ 17] サクラユタカオー (1982年)
#   ✓ [ 18] パーシャンボーイ (1982年)
#   ✓ [ 19] タカラスチール (1982年)
#   ✓ [ 20] ミホシンザン (1982年)
#   ✓ [ 21] スズパレード (1981年)
#   ✓ [ 22] シンボリルドルフ (1981年)
#   ✓ [ 23] ギャロップダイナ (1980年)
#   ✓ [ 24] ミスターシービー (1980年)
#   ✓ [ 25] Jupiter Island (1979年)
#
# ✅ 合計25頭を取得しました
# ✅ リストバッチ完了: 25頭追加, 累計198頭
# 📦 リストバッチ: オフセット700, 2頭取得
# 🎯 G1馬取得開始:
#    オフセット: 700
#    最大取得数: 2頭
#    最小生年: 1800年
# --------------------------------------------------
# 📄 開始ページ: 8, ページ内位置: 0
#
# 📄 ページ8を処理中...
# ❌ データ取得に失敗しました
#
# ✅ 合計0頭を取得しました
# ⚠️ これ以上馬が見つかりません
#
# 🔍 Step 2: 詳細データ処理（198頭）
# 🐎 [1/198] ユウフヨウホウ (ID: 1997109368)
#
# --- 馬ID: 1997109368 完全取得開始 ---
# 🔍 ページ取得: https://db.netkeiba.com/horse/1997109368/
# 🔍 馬詳細ページ取得: 1997109368
#     📄 ページタイトル: ユウフヨウホウ (Yu Fuyoho) | 競走馬データ - netkeiba
#     📝 馬名取得: ユウフヨウホウ
#     🔤 性別取得: stallion
#     🔤 英語名取得: Yu Fuyoho
#     ✅ プロフィールテーブル発見
#       - 生年月日 (birth_date): 1997-03-19
#       - 調教師 (trainer): 松元茂樹(栗東)
#       - 馬主 (owner): アイテツ
#       - 生産者 (breeder): タイヘイ牧場
#       - 産地 (birthplace): 静内町
#       - 獲得賞金 (中央) (total_prize_central): 10227
#       - 通算成績 (career_record): {'starts': 29, 'wins': 2, 'win_rate': 6.9, 'first': 2, 'second': 1, 'third': 4, 'others': 22}
#       - 近親馬 (related_horses): ゴーカイ、ユウセンショウ
#     📋 取得データ項目数: 12
#   ✅ 基本情報取得成功: ユウフヨウホウ
#   🌳 血統関係取得: 1997109368
#     🧬 父ID設定: 1983104853
#     🧬 母ID設定: 1983105709
#     🧬 母父ID設定: 1976100765
#       💡 子供ID既存: 1997109368 は既にリストに含まれています
#     💕 種付関係更新: 1983104853 × 1983105709 → 子供追加: 1997109368
#     💾 保存データ構造:
#       直接カラム: ['id', 'name_ja', 'name_en', 'birth_date', 'sex', 'sire_id', 'dam_id', 'maternal_grandsire_id']
#       プロフィール項目: ['trainer', 'owner', 'breeder', 'birthplace', 'total_prize_central', 'career_record', 'related_horses']
#       💡 関係既存: sire_of
#       💡 関係既存: dam_of
#       💡 関係既存: bms_of
#       💡 関係既存: mating
#     ✅ 0件の関係を保存
# ✅ 完了: ユウフヨウホウ
#     ✅ 完了
# 🐎 [2/198] タップダンスシチー (ID: 1997110043)
#
# --- 馬ID: 1997110043 完全取得開始 ---
# 🔍 ページ取得: https://db.netkeiba.com/horse/1997110043/
# 🔍 馬詳細ページ取得: 1997110043
#     📄 ページタイトル: タップダンスシチー (Tap Dance City) | 競走馬データ - netkeiba
#     📝 馬名取得: タップダンスシチー
#     🔤 性別取得: stallion
#     🔤 英語名取得: Tap Dance City
#     ✅ プロフィールテーブル発見
#       - 生年月日 (birth_date): 1997-03-16
#       - 調教師 (trainer): 佐々木晶(栗東)
#       - 馬主 (owner): 友駿ホースクラブ
#       - 生産者 (breeder): Echo Valley Horse Farm & Swettenham Stud
#       - 産地 (birthplace): 米
#       - 獲得賞金 (中央) (total_prize_central): 100422
#       - 通算成績 (career_record): {'starts': 42, 'wins': 12, 'win_rate': 28.6, 'first': 12, 'second': 6, 'third': 7, 'others': 17}
#       - 近親馬 (related_horses): クリプトシチー、スルーシング
#     📋 取得データ項目数: 12
#   ✅ 基本情報取得成功: タップダンスシチー
#   🌳 血統関係取得: 1997110043
#     🧬 父ID設定: 000a00fdb2
#     🧬 母ID設定: 000a00a464
#     🧬 母父ID設定: 000a000e04
#       💡 子供ID既存: 1997110043 は既にリストに含まれています
#     💕 種付関係更新: 000a00fdb2 × 000a00a464 → 子供追加: 1997110043
#     💾 保存データ構造:
#       直接カラム: ['id', 'name_ja', 'name_en', 'birth_date', 'sex', 'sire_id', 'dam_id', 'maternal_grandsire_id']
#       プロフィール項目: ['trainer', 'owner', 'breeder', 'birthplace', 'total_prize_central', 'career_record', 'related_horses']
#       💡 関係既存: sire_of
#       💡 関係既存: dam_of
#       💡 関係既存: bms_of
#       💡 関係既存: mating
#     ✅ 0件の関係を保存
# ✅ 完了: タップダンスシチー
#     ✅ 完了
# 🐎 [3/198] マイネルコンバット (ID: 1997104109)
#
# --- 馬ID: 1997104109 完全取得開始 ---
# 🔍 ページ取得: https://db.netkeiba.com/horse/1997104109/
# 🔍 馬詳細ページ取得: 1997104109
#     📄 ページタイトル: マイネルコンバット (Meiner Combat) | 競走馬データ - netkeiba
#     📝 馬名取得: マイネルコンバット
#     🔤 性別取得: stallion
#     🔤 英語名取得: Meiner Combat
#     ✅ プロフィールテーブル発見
#       - 生年月日 (birth_date): 1997-03-14
#       - 調教師 (trainer): 稲葉隆一(美浦)
#       - 馬主 (owner): サラブレッドクラブ・ラフィアン
#       - 生産者 (breeder): 高松牧場
#       - 産地 (birthplace): 浦河町
#       - 獲得賞金 (中央) (total_prize_central): 4773
#       - 獲得賞金 (地方) (total_prize_local): 7550
#       - 通算成績 (career_record): {'starts': 29, 'wins': 4, 'win_rate': 13.8, 'first': 4, 'second': 5, 'third': 1, 'others': 19}
#       - 近親馬 (related_horses): サンキューホーラー、アガペー
#     📋 取得データ項目数: 13
#   ✅ 基本情報取得成功: マイネルコンバット
#   🌳 血統関係取得: 1997104109
#     🧬 父ID設定: 000a0000b0
#     🧬 母ID設定: 1987105548
#     🧬 母父ID設定: 000a000258
#       💡 子供ID既存: 1997104109 は既にリストに含まれています
#     💕 種付関係更新: 000a0000b0 × 1987105548 → 子供追加: 1997104109
#     💾 保存データ構造:
#       直接カラム: ['id', 'name_ja', 'name_en', 'birth_date', 'sex', 'sire_id', 'dam_id', 'maternal_grandsire_id']
#       プロフィール項目: ['trainer', 'owner', 'breeder', 'birthplace', 'total_prize_central', 'total_prize_local', 'career_record', 'related_horses']
#       💡 関係既存: sire_of
#       💡 関係既存: dam_of
#       💡 関係既存: bms_of
#       💡 関係既存: mating
#     ✅ 0件の関係を保存
# ✅ 完了: マイネルコンバット
#     ✅ 完了
# 🐎 [4/198] ティコティコタック (ID: 1997104234)
#
# --- 馬ID: 1997104234 完全取得開始 ---
# 🔍 ページ取得: https://db.netkeiba.com/horse/1997104234/
# 🔍 馬詳細ページ取得: 1997104234
#     📄 ページタイトル: ティコティコタック (Tico Tico Tac) | 競走馬データ - netkeiba
#     📝 馬名取得: ティコティコタック
#     🔤 性別取得: mare
#     🔤 英語名取得: Tico Tico Tac
#     ✅ プロフィールテーブル発見
#       - 生年月日 (birth_date): 1997-03-11
#       - 調教師 (trainer): 松田正弘(栗東)
#       - 馬主 (owner): バンブー牧場
#       - 生産者 (breeder): バンブー牧場
#       - 産地 (birthplace): 浦河町
#       - 獲得賞金 (中央) (total_prize_central): 20281
#       - 通算成績 (career_record): {'starts': 22, 'wins': 4, 'win_rate': 18.2, 'first': 4, 'second': 2, 'third': 4, 'others': 12}
#       - 近親馬 (related_horses): バンブーラグタイム、バンブージャック
#     📋 取得データ項目数: 12
#   ✅ 基本情報取得成功: ティコティコタック
#   🌳 血統関係取得: 1997104234
#     🧬 父ID設定: 1985103538
#     🧬 母ID設定: 1991101860
#     🧬 母父ID設定: 000a000082
#       💡 子供ID既存: 1997104234 は既にリストに含まれています
#     💕 種付関係更新: 1985103538 × 1991101860 → 子供追加: 1997104234
#     💾 保存データ構造:
#       直接カラム: ['id', 'name_ja', 'name_en', 'birth_date', 'sex', 'sire_id', 'dam_id', 'maternal_grandsire_id']
#       プロフィール項目: ['trainer', 'owner', 'breeder', 'birthplace', 'total_prize_central', 'career_record', 'related_horses']
#       💡 関係既存: sire_of
#       💡 関係既存: dam_of
#       💡 関係既存: bms_of
#       💡 関係既存: mating
#     ✅ 0件の関係を保存
# ✅ 完了: ティコティコタック
#     ✅ 完了
# 🐎 [5/198] アグネスフライト (ID: 1997103400)
#
# --- 馬ID: 1997103400 完全取得開始 ---
# 🔍 ページ取得: https://db.netkeiba.com/horse/1997103400/
# 🔍 馬詳細ページ取得: 1997103400
#     📄 ページタイトル: アグネスフライト (Agnes Flight) | 競走馬データ - netkeiba
#     📝 馬名取得: アグネスフライト
#     🔤 性別取得: stallion
#     🔤 英語名取得: Agnes Flight
#     ✅ プロフィールテーブル発見
#       - 生年月日 (birth_date): 1997-03-02
#       - 調教師 (trainer): 長浜博之(栗東)
#       - 馬主 (owner): 渡辺孝男
#       - 生産者 (breeder): 社台ファーム
#       - 産地 (birthplace): 千歳市
#       - 獲得賞金 (中央) (total_prize_central): 20919
#       - 通算成績 (career_record): {'starts': 14, 'wins': 4, 'win_rate': 28.6, 'first': 4, 'second': 2, 'third': 0, 'others': 8}
#       - 近親馬 (related_horses): アグネスタキオン、アグネスタカオー
#     📋 取得データ項目数: 12
#   ✅ 基本情報取得成功: アグネスフライト
#   🌳 血統関係取得: 1997103400
#     🧬 父ID設定: 000a00033a
#     🧬 母ID設定: 1987103805
#     🧬 母父ID設定: 000a0003c6
#       💡 子供ID既存: 1997103400 は既にリストに含まれています
#     💕 種付関係更新: 000a00033a × 1987103805 → 子供追加: 1997103400
#     💾 保存データ構造:
#       直接カラム: ['id', 'name_ja', 'name_en', 'birth_date', 'sex', 'sire_id', 'dam_id', 'maternal_grandsire_id']
#       プロフィール項目: ['trainer', 'owner', 'breeder', 'birthplace', 'total_prize_central', 'career_record', 'related_horses']
#       💡 関係既存: sire_of
#       💡 関係既存: dam_of
#       💡 関係既存: bms_of
#       💡 関係既存: mating
#     ✅ 0件の関係を保存
# ✅ 完了: アグネスフライト
#     ✅ 完了
# 🐎 [6/198] エアシャカール (ID: 1997103398)
#
# --- 馬ID: 1997103398 完全取得開始 ---
# 🔍 ページ取得: https://db.netkeiba.com/horse/1997103398/
# 🔍 馬詳細ページ取得: 1997103398
#     📄 ページタイトル: エアシャカール (Air Shakur) | 競走馬データ - netkeiba
#     📝 馬名取得: エアシャカール
#     🔤 性別取得: stallion
#     🔤 英語名取得: Air Shakur
#     ✅ プロフィールテーブル発見
#       - 生年月日 (birth_date): 1997-02-26
#       - 調教師 (trainer): 森秀行(栗東)
#       - 馬主 (owner): ラッキーフィールド
#       - 生産者 (breeder): 社台ファーム
#       - 産地 (birthplace): 千歳市
#       - 獲得賞金 (中央) (total_prize_central): 50505
#       - 通算成績 (career_record): {'starts': 20, 'wins': 4, 'win_rate': 20.0, 'first': 4, 'second': 6, 'third': 1, 'others': 9}
#       - 近親馬 (related_horses): エアデジャヴー、エアサバス
#     📋 取得データ項目数: 12
#   ✅ 基本情報取得成功: エアシャカール
#   🌳 血統関係取得: 1997103398
#     🧬 父ID設定: 000a00033a
#     🧬 母ID設定: 000a00018c
#     🧬 母父ID設定: 000a001b47
#       💡 子供ID既存: 1997103398 は既にリストに含まれています
#     💕 種付関係更新: 000a00033a × 000a00018c → 子供追加: 1997103398
#     💾 保存データ構造:
#       直接カラム: ['id', 'name_ja', 'name_en', 'birth_date', 'sex', 'sire_id', 'dam_id', 'maternal_grandsire_id']
#       プロフィール項目: ['trainer', 'owner', 'breeder', 'birthplace', 'total_prize_central', 'career_record', 'related_horses']
#       💡 関係既存: sire_of
#       💡 関係既存: dam_of
#       💡 関係既存: bms_of
#       💡 関係既存: mating
#     ✅ 0件の関係を保存
# ✅ 完了: エアシャカール
#     ✅ 完了
# 🐎 [7/198] イーグルカフェ (ID: 1997110118)
#
# --- 馬ID: 1997110118 完全取得開始 ---
# 🔍 ページ取得: https://db.netkeiba.com/horse/1997110118/
# 🔍 馬詳細ページ取得: 1997110118
#     📄 ページタイトル: イーグルカフェ (Eagle Cafe) | 競走馬データ - netkeiba
#     📝 馬名取得: イーグルカフェ
#     🔤 性別取得: stallion
#     🔤 英語名取得: Eagle Cafe
#     ✅ プロフィールテーブル発見
#       - 生年月日 (birth_date): 1997-02-10
#       - 調教師 (trainer): 小島太(美浦)
#       - 馬主 (owner): 西川清
#       - 生産者 (breeder): E. J. Hudson Jr. Irrevocable Trust & W. S. Kilroy
#       - 産地 (birthplace): 米
#       - 獲得賞金 (中央) (total_prize_central): 40057
#       - 獲得賞金 (地方) (total_prize_local): 780
#       - 通算成績 (career_record): {'starts': 46, 'wins': 5, 'win_rate': 10.9, 'first': 5, 'second': 4, 'third': 4, 'others': 33}
#       - 近親馬 (related_horses): ハセノガルチ、Music Fever
#     📋 取得データ項目数: 13
#   ✅ 基本情報取得成功: イーグルカフェ
#   🌳 血統関係取得: 1997110118
#     🧬 父ID設定: 000a001cd6
#     🧬 母ID設定: 000a00a3a6
#     🧬 母父ID設定: 000a001676
#     💕 種付関係新規作成: 000a001cd6 × 000a00a3a6 → 子供: 1997110118
#     💾 保存データ構造:
#       直接カラム: ['id', 'name_ja', 'name_en', 'birth_date', 'sex', 'sire_id', 'dam_id', 'maternal_grandsire_id']
#       プロフィール項目: ['trainer', 'owner', 'breeder', 'birthplace', 'total_prize_central', 'total_prize_local', 'career_record', 'related_horses']
#       💾 関係保存: sire_of (000a001cd6 -> 1997110118)
#       💾 関係保存: dam_of (000a00a3a6 -> 1997110118)
#       💾 関係保存: bms_of (000a001676 -> 1997110118)
#       💾 関係保存: mating (000a001cd6 -> 000a00a3a6)
#     ✅ 4件の関係を保存
# ✅ 完了: イーグルカフェ
#     ✅ 完了
# 🐎 [8/198] トウカイポイント (ID: 1996106049)
#
# --- 馬ID: 1996106049 完全取得開始 ---
# 🔍 ページ取得: https://db.netkeiba.com/horse/1996106049/
# 🔍 馬詳細ページ取得: 1996106049
#     📄 ページタイトル: トウカイポイント (Tokai Point) | 競走馬データ - netkeiba
#     📝 馬名取得: トウカイポイント
#     🔤 英語名取得: Tokai Point
#     ✅ プロフィールテーブル発見
#       - 生年月日 (birth_date): 1996-05-18
#       - 調教師 (trainer): 後藤由之(美浦)
#       - 馬主 (owner): 内村正則
#       - 生産者 (breeder): 竹内良一
#       - 産地 (birthplace): 三石町
#       - 獲得賞金 (中央) (total_prize_central): 30519
#       - 獲得賞金 (地方) (total_prize_local): 450
#       - 通算成績 (career_record): {'starts': 37, 'wins': 7, 'win_rate': 18.9, 'first': 7, 'second': 8, 'third': 3, 'others': 19}
#       - 近親馬 (related_horses): パープルエビス、マッチザピース
#     📋 取得データ項目数: 12
#   ✅ 基本情報取得成功: トウカイポイント
#   🌳 血統関係取得: 1996106049
#     🧬 父ID設定: 1988101025
#     🧬 母ID設定: 1990104647
#     🧬 母父ID設定: 000a0002a6
#     💕 種付関係新規作成: 1988101025 × 1990104647 → 子供: 1996106049
#     💾 保存データ構造:
#       直接カラム: ['id', 'name_ja', 'name_en', 'birth_date', 'sex', 'sire_id', 'dam_id', 'maternal_grandsire_id']
#       プロフィール項目: ['trainer', 'owner', 'breeder', 'birthplace', 'total_prize_central', 'total_prize_local', 'career_record', 'related_horses']
#       💾 関係保存: sire_of (1988101025 -> 1996106049)
#       💾 関係保存: dam_of (1990104647 -> 1996106049)
#       💾 関係保存: bms_of (000a0002a6 -> 1996106049)
#       💾 関係保存: mating (1988101025 -> 1990104647)
#     ✅ 4件の関係を保存
# ✅ 完了: トウカイポイント
#     ✅ 完了
# 🐎 [9/198] スティンガー (ID: 1996107252)
#
# --- 馬ID: 1996107252 完全取得開始 ---
# 🔍 ページ取得: https://db.netkeiba.com/horse/1996107252/
# 🔍 馬詳細ページ取得: 1996107252
#     📄 ページタイトル: スティンガー (Stinger) | 競走馬データ - netkeiba
#     📝 馬名取得: スティンガー
#     🔤 性別取得: mare
#     🔤 英語名取得: Stinger
#     ✅ プロフィールテーブル発見
#       - 生年月日 (birth_date): 1996-05-15
#       - 調教師 (trainer): 藤沢和雄(美浦)
#       - 馬主 (owner): 吉田照哉
#       - 生産者 (breeder): 社台ファーム
#       - 産地 (birthplace): 千歳市
#       - 獲得賞金 (中央) (total_prize_central): 40250
#       - 通算成績 (career_record): {'starts': 21, 'wins': 7, 'win_rate': 33.3, 'first': 7, 'second': 0, 'third': 3, 'others': 11}
#       - 近親馬 (related_horses): サイレントハピネス、レガシーオブゼルダ
#     📋 取得データ項目数: 12
#   ✅ 基本情報取得成功: スティンガー
#   🌳 血統関係取得: 1996107252
#     🧬 父ID設定: 000a00033a
#     🧬 母ID設定: 000a006146
#     🧬 母父ID設定: 000a001785
#     💕 種付関係新規作成: 000a00033a × 000a006146 → 子供: 1996107252
#     💾 保存データ構造:
#       直接カラム: ['id', 'name_ja', 'name_en', 'birth_date', 'sex', 'sire_id', 'dam_id', 'maternal_grandsire_id']
#       プロフィール項目: ['trainer', 'owner', 'breeder', 'birthplace', 'total_prize_central', 'career_record', 'related_horses']
#       💾 関係保存: sire_of (000a00033a -> 1996107252)
#       💾 関係保存: dam_of (000a006146 -> 1996107252)
#       💾 関係保存: bms_of (000a001785 -> 1996107252)
#       💾 関係保存: mating (000a00033a -> 000a006146)
#     ✅ 4件の関係を保存
# ✅ 完了: スティンガー
#     ✅ 完了
# 🐎 [10/198] トーホウエンペラー (ID: 1996102712)
#
# --- 馬ID: 1996102712 完全取得開始 ---
# 🔍 ページ取得: https://db.netkeiba.com/horse/1996102712/
# 🔍 馬詳細ページ取得: 1996102712
#     📄 ページタイトル: トーホウエンペラー (Toho Emperor) | 競走馬データ - netkeiba
#     📝 馬名取得: トーホウエンペラー
#     🔤 性別取得: stallion
#     🔤 英語名取得: Toho Emperor
#     ✅ プロフィールテーブル発見
#       - 生年月日 (birth_date): 1996-05-11
#       - 調教師 (trainer): 千葉四美(岩手)
#       - 馬主 (owner): 東豊物産株
#       - 生産者 (breeder): 千葉飯田牧場
#       - 産地 (birthplace): 門別
#       - 獲得賞金 (中央) (total_prize_central): 2653
#       - 獲得賞金 (地方) (total_prize_local): 30875
#       - 通算成績 (career_record): {'starts': 33, 'wins': 20, 'win_rate': 60.6, 'first': 20, 'second': 5, 'third': 2, 'others': 6}
#       - 近親馬 (related_horses): ストロングレオン、レインボーリオーネ
#     📋 取得データ項目数: 13
#   ✅ 基本情報取得成功: トーホウエンペラー
#   🌳 血統関係取得: 1996102712
#     🧬 父ID設定: 000a000082
#     🧬 母ID設定: 1988103202
#     🧬 母父ID設定: 000a000251
#     💕 種付関係新規作成: 000a000082 × 1988103202 → 子供: 1996102712
#     💾 保存データ構造:
#       直接カラム: ['id', 'name_ja', 'name_en', 'birth_date', 'sex', 'sire_id', 'dam_id', 'maternal_grandsire_id']
#       プロフィール項目: ['trainer', 'owner', 'breeder', 'birthplace', 'total_prize_central', 'total_prize_local', 'career_record', 'related_horses']
#       💾 関係保存: sire_of (000a000082 -> 1996102712)
#       💾 関係保存: dam_of (1988103202 -> 1996102712)
#       💾 関係保存: bms_of (000a000251 -> 1996102712)
#       💾 関係保存: mating (000a000082 -> 1988103202)
#     ✅ 4件の関係を保存
# ✅ 完了: トーホウエンペラー
#     ✅ 完了
# 🐎 [11/198] トロットスター (ID: 1996103651)
#
# --- 馬ID: 1996103651 完全取得開始 ---
# 🔍 ページ取得: https://db.netkeiba.com/horse/1996103651/
# 🔍 馬詳細ページ取得: 1996103651
#     📄 ページタイトル: トロットスター (Trot Star) | 競走馬データ - netkeiba
#     📝 馬名取得: トロットスター
#     🔤 性別取得: stallion
#     🔤 英語名取得: Trot Star
#     ✅ プロフィールテーブル発見
#       - 生年月日 (birth_date): 1996-05-11
#       - 調教師 (trainer): 中野栄治(美浦)
#       - 馬主 (owner): 高野稔
#       - 生産者 (breeder): 荻伏三好ファーム
#       - 産地 (birthplace): 浦河町
#       - 獲得賞金 (中央) (total_prize_central): 40239
#       - 通算成績 (career_record): {'starts': 34, 'wins': 8, 'win_rate': 23.5, 'first': 8, 'second': 7, 'third': 0, 'others': 19}
#       - 近親馬 (related_horses): マキシマムスピード、プリンスヤンクス
#     📋 取得データ項目数: 12
#   ✅ 基本情報取得成功: トロットスター
#   🌳 血統関係取得: 1996103651
#     🧬 父ID設定: 000a0000c5
#     🧬 母ID設定: 1989100816
#     🧬 母父ID設定: 000a000d17
#     💕 種付関係新規作成: 000a0000c5 × 1989100816 → 子供: 1996103651
#     💾 保存データ構造:
#       直接カラム: ['id', 'name_ja', 'name_en', 'birth_date', 'sex', 'sire_id', 'dam_id', 'maternal_grandsire_id']
#       プロフィール項目: ['trainer', 'owner', 'breeder', 'birthplace', 'total_prize_central', 'career_record', 'related_horses']
#       💾 関係保存: sire_of (000a0000c5 -> 1996103651)
#       💾 関係保存: dam_of (1989100816 -> 1996103651)
#       💾 関係保存: bms_of (000a000d17 -> 1996103651)
#       💾 関係保存: mating (000a0000c5 -> 1989100816)
#     ✅ 4件の関係を保存
# ✅ 完了: トロットスター
#     ✅ 完了
# 🐎 [12/198] ウメノファイバー (ID: 1996101247)
#
# --- 馬ID: 1996101247 完全取得開始 ---
# 🔍 ページ取得: https://db.netkeiba.com/horse/1996101247/
# 🔍 馬詳細ページ取得: 1996101247
#     📄 ページタイトル: ウメノファイバー (Umeno Fiber) | 競走馬データ - netkeiba
#     📝 馬名取得: ウメノファイバー
#     🔤 性別取得: mare
#     🔤 英語名取得: Umeno Fiber
#     ✅ プロフィールテーブル発見
#       - 生年月日 (birth_date): 1996-05-05
#       - 調教師 (trainer): 相沢郁(美浦)
#       - 馬主 (owner): 梅崎敏則
#       - 生産者 (breeder): 斉藤安行
#       - 産地 (birthplace): 新冠町
#       - 獲得賞金 (中央) (total_prize_central): 20899
#       - 通算成績 (career_record): {'starts': 16, 'wins': 4, 'win_rate': 25.0, 'first': 4, 'second': 0, 'third': 0, 'others': 12}
#       - 近親馬 (related_horses): ウメノテイオー、ウメノビクトリー
#     📋 取得データ項目数: 12
#   ✅ 基本情報取得成功: ウメノファイバー
#   🌳 血統関係取得: 1996101247
#     🧬 父ID設定: 1982101222
#     🧬 母ID設定: 1986102459
#     🧬 母父ID設定: 000a000484
#     💕 種付関係新規作成: 1982101222 × 1986102459 → 子供: 1996101247
#     💾 保存データ構造:
#       直接カラム: ['id', 'name_ja', 'name_en', 'birth_date', 'sex', 'sire_id', 'dam_id', 'maternal_grandsire_id']
#       プロフィール項目: ['trainer', 'owner', 'breeder', 'birthplace', 'total_prize_central', 'career_record', 'related_horses']
#       💾 関係保存: sire_of (1982101222 -> 1996101247)
#       💾 関係保存: dam_of (1986102459 -> 1996101247)
#       💾 関係保存: bms_of (000a000484 -> 1996101247)
#       💾 関係保存: mating (1982101222 -> 1986102459)
#     ✅ 4件の関係を保存
# ✅ 完了: ウメノファイバー
#     ✅ 完了
# 🐎 [13/198] リージェントブラフ (ID: 1996104207)
#
# --- 馬ID: 1996104207 完全取得開始 ---
# 🔍 ページ取得: https://db.netkeiba.com/horse/1996104207/
# 🔍 馬詳細ページ取得: 1996104207
#     📄 ページタイトル: リージェントブラフ (Regent Bluff) | 競走馬データ - netkeiba
#     📝 馬名取得: リージェントブラフ
#     🔤 性別取得: stallion
#     🔤 英語名取得: Regent Bluff
#     ✅ プロフィールテーブル発見
#       - 生年月日 (birth_date): 1996-05-02
#       - 調教師 (trainer): 大久保洋(美浦)
#       - 馬主 (owner): 大原詔宏
#       - 生産者 (breeder): 吉田隆
#       - 産地 (birthplace): 浦河町
#       - 獲得賞金 (中央) (total_prize_central): 20911
#       - 獲得賞金 (地方) (total_prize_local): 30825
#       - 通算成績 (career_record): {'starts': 57, 'wins': 9, 'win_rate': 15.8, 'first': 9, 'second': 12, 'third': 8, 'others': 28}
#       - 近親馬 (related_horses): ラシアンゴールド、スリルパッション
#     📋 取得データ項目数: 13
#   ✅ 基本情報取得成功: リージェントブラフ
#   🌳 血統関係取得: 1996104207
#     🧬 父ID設定: 000a000d01
#     🧬 母ID設定: 1980102440
#     🧬 母父ID設定: 000a000ae0
#     💕 種付関係新規作成: 000a000d01 × 1980102440 → 子供: 1996104207
#     💾 保存データ構造:
#       直接カラム: ['id', 'name_ja', 'name_en', 'birth_date', 'sex', 'sire_id', 'dam_id', 'maternal_grandsire_id']
#       プロフィール項目: ['trainer', 'owner', 'breeder', 'birthplace', 'total_prize_central', 'total_prize_local', 'career_record', 'related_horses']
#       💾 関係保存: sire_of (000a000d01 -> 1996104207)
#       💾 関係保存: dam_of (1980102440 -> 1996104207)
#       💾 関係保存: bms_of (000a000ae0 -> 1996104207)
#       💾 関係保存: mating (000a000d01 -> 1980102440)
#     ✅ 4件の関係を保存
# ✅ 完了: リージェントブラフ
#     ✅ 完了
# 🐎 [14/198] タイキヘラクレス (ID: 1996106515)
#
# --- 馬ID: 1996106515 完全取得開始 ---
# 🔍 ページ取得: https://db.netkeiba.com/horse/1996106515/
# 🔍 馬詳細ページ取得: 1996106515
#     📄 ページタイトル: タイキヘラクレス (Taiki Herakles) | 競走馬データ - netkeiba
#     📝 馬名取得: タイキヘラクレス
#     🔤 英語名取得: Taiki Herakles
#     ✅ プロフィールテーブル発見
#       - 生年月日 (birth_date): 1996-04-27
#       - 調教師 (trainer): 蛯名信広(美浦)
#       - 馬主 (owner): 大樹ファーム
#       - 生産者 (breeder): 大樹ファーム
#       - 産地 (birthplace): 大樹町
#       - 獲得賞金 (中央) (total_prize_central): 5645
#       - 獲得賞金 (地方) (total_prize_local): 10800
#       - 通算成績 (career_record): {'starts': 18, 'wins': 6, 'win_rate': 33.3, 'first': 6, 'second': 1, 'third': 1, 'others': 10}
#       - 近親馬 (related_horses): タイキエンプレス、タイキビューティー
#     📋 取得データ項目数: 12
#   ✅ 基本情報取得成功: タイキヘラクレス
#   🌳 血統関係取得: 1996106515
#     🧬 父ID設定: 1984109006
#     🧬 母ID設定: 1988107901
#     🧬 母父ID設定: 000a0015e0
#     💕 種付関係新規作成: 1984109006 × 1988107901 → 子供: 1996106515
#     💾 保存データ構造:
#       直接カラム: ['id', 'name_ja', 'name_en', 'birth_date', 'sex', 'sire_id', 'dam_id', 'maternal_grandsire_id']
#       プロフィール項目: ['trainer', 'owner', 'breeder', 'birthplace', 'total_prize_central', 'total_prize_local', 'career_record', 'related_horses']
#       💾 関係保存: sire_of (1984109006 -> 1996106515)
#       💾 関係保存: dam_of (1988107901 -> 1996106515)
#       💾 関係保存: bms_of (000a0015e0 -> 1996106515)
#       💾 関係保存: mating (1984109006 -> 1988107901)
#     ✅ 4件の関係を保存
# ✅ 完了: タイキヘラクレス
#     ✅ 完了
# 🐎 [15/198] ゴールドティアラ (ID: 1996110142)
#
# --- 馬ID: 1996110142 完全取得開始 ---
# 🔍 ページ取得: https://db.netkeiba.com/horse/1996110142/
# 🔍 馬詳細ページ取得: 1996110142
#     📄 ページタイトル: ゴールドティアラ (Gold Tiara) | 競走馬データ - netkeiba
#     📝 馬名取得: ゴールドティアラ
#     🔤 性別取得: mare
#     🔤 英語名取得: Gold Tiara
#     ✅ プロフィールテーブル発見
#       - 生年月日 (birth_date): 1996-04-25
#       - 調教師 (trainer): 松田国英(栗東)
#       - 馬主 (owner): 吉田和子
#       - 生産者 (breeder): Everest Stables Inc.
#       - 産地 (birthplace): 米
#       - 獲得賞金 (中央) (total_prize_central): 20396
#       - 獲得賞金 (地方) (total_prize_local): 10580
#       - 通算成績 (career_record): {'starts': 32, 'wins': 9, 'win_rate': 28.1, 'first': 9, 'second': 2, 'third': 3, 'others': 18}
#       - 近親馬 (related_horses): ケイアイブライト、ベストブート
#     📋 取得データ項目数: 13
#   ✅ 基本情報取得成功: ゴールドティアラ
#   🌳 血統関係取得: 1996110142
#     🧬 父ID設定: 000a001bea
#     🧬 母ID設定: 000a00aa15
#     🧬 母父ID設定: 000a001b87
#     💕 種付関係新規作成: 000a001bea × 000a00aa15 → 子供: 1996110142
#     💾 保存データ構造:
#       直接カラム: ['id', 'name_ja', 'name_en', 'birth_date', 'sex', 'sire_id', 'dam_id', 'maternal_grandsire_id']
#       プロフィール項目: ['trainer', 'owner', 'breeder', 'birthplace', 'total_prize_central', 'total_prize_local', 'career_record', 'related_horses']
#       💾 関係保存: sire_of (000a001bea -> 1996110142)
#       💾 関係保存: dam_of (000a00aa15 -> 1996110142)
#       💾 関係保存: bms_of (000a001b87 -> 1996110142)
#       💾 関係保存: mating (000a001bea -> 000a00aa15)
#     ✅ 4件の関係を保存
# ✅ 完了: ゴールドティアラ
#     ✅ 完了
# 🐎 [16/198] ブゼンキャンドル (ID: 1996106915)
#
# --- 馬ID: 1996106915 完全取得開始 ---
# 🔍 ページ取得: https://db.netkeiba.com/horse/1996106915/
# 🔍 馬詳細ページ取得: 1996106915
#     📄 ページタイトル: ブゼンキャンドル (Buzen Candle) | 競走馬データ - netkeiba
#     📝 馬名取得: ブゼンキャンドル
#     🔤 性別取得: mare
#     🔤 英語名取得: Buzen Candle
#     ✅ プロフィールテーブル発見
#       - 生年月日 (birth_date): 1996-04-24
#       - 調教師 (trainer): 松田博資(栗東)
#       - 馬主 (owner): 上田牧場
#       - 生産者 (breeder): 上田牧場
#       - 産地 (birthplace): 白老町
#       - 獲得賞金 (中央) (total_prize_central): 10365
#       - 通算成績 (career_record): {'starts': 27, 'wins': 4, 'win_rate': 14.8, 'first': 4, 'second': 3, 'third': 6, 'others': 14}
#       - 近親馬 (related_horses): スピードアラシ、ホウシュウムサシ
#     📋 取得データ項目数: 12
#   ✅ 基本情報取得成功: ブゼンキャンドル
#   🌳 血統関係取得: 1996106915
#     🧬 父ID設定: 000a00022a
#     🧬 母ID設定: 1985103293
#     🧬 母父ID設定: 1979101744
#     💕 種付関係新規作成: 000a00022a × 1985103293 → 子供: 1996106915
#     💾 保存データ構造:
#       直接カラム: ['id', 'name_ja', 'name_en', 'birth_date', 'sex', 'sire_id', 'dam_id', 'maternal_grandsire_id']
#       プロフィール項目: ['trainer', 'owner', 'breeder', 'birthplace', 'total_prize_central', 'career_record', 'related_horses']
#       💾 関係保存: sire_of (000a00022a -> 1996106915)
#       💾 関係保存: dam_of (1985103293 -> 1996106915)
#       💾 関係保存: bms_of (1979101744 -> 1996106915)
#       💾 関係保存: mating (000a00022a -> 1985103293)
#     ✅ 4件の関係を保存
# ✅ 完了: ブゼンキャンドル
#     ✅ 完了
# 🐎 [17/198] サウスヴィグラス (ID: 1996110138)
#
# --- 馬ID: 1996110138 完全取得開始 ---
# 🔍 ページ取得: https://db.netkeiba.com/horse/1996110138/
# 🔍 馬詳細ページ取得: 1996110138
#     📄 ページタイトル: サウスヴィグラス (South Vigorous) | 競走馬データ - netkeiba
#     📝 馬名取得: サウスヴィグラス
#     🔤 性別取得: stallion
#     🔤 英語名取得: South Vigorous
#     ✅ プロフィールテーブル発見
#       - 生年月日 (birth_date): 1996-04-19
#       - 調教師 (trainer): 高橋祥泰(美浦)
#       - 馬主 (owner): 南波壽
#       - 生産者 (breeder): Samuel H. Rogers Jr.
#       - 産地 (birthplace): 米
#       - 獲得賞金 (中央) (total_prize_central): 20967
#       - 獲得賞金 (地方) (total_prize_local): 20405
#       - 通算成績 (career_record): {'starts': 33, 'wins': 16, 'win_rate': 48.5, 'first': 16, 'second': 8, 'third': 2, 'others': 7}
#       - 近親馬 (related_horses): ベネラ、ナイジェラ
#     📋 取得データ項目数: 13
#   ✅ 基本情報取得成功: サウスヴィグラス
#   🌳 血統関係取得: 1996110138
#     🧬 父ID設定: 000a00010f
#     🧬 母ID設定: 000a0000d6
#     🧬 母父ID設定: 000a001982
#     💕 種付関係新規作成: 000a00010f × 000a0000d6 → 子供: 1996110138
#     💾 保存データ構造:
#       直接カラム: ['id', 'name_ja', 'name_en', 'birth_date', 'sex', 'sire_id', 'dam_id', 'maternal_grandsire_id']
#       プロフィール項目: ['trainer', 'owner', 'breeder', 'birthplace', 'total_prize_central', 'total_prize_local', 'career_record', 'related_horses']
#       💾 関係保存: sire_of (000a00010f -> 1996110138)
#       💾 関係保存: dam_of (000a0000d6 -> 1996110138)
#       💾 関係保存: bms_of (000a001982 -> 1996110138)
#       💾 関係保存: mating (000a00010f -> 000a0000d6)
#     ✅ 4件の関係を保存
# ✅ 完了: サウスヴィグラス
#     ✅ 完了
# 🐎 [18/198] オリオンザサンクス (ID: 1996103237)
#
# --- 馬ID: 1996103237 完全取得開始 ---
# 🔍 ページ取得: https://db.netkeiba.com/horse/1996103237/
# 🔍 馬詳細ページ取得: 1996103237
#     📄 ページタイトル: オリオンザサンクス (Orion the Thanks) | 競走馬データ - netkeiba
#     📝 馬名取得: オリオンザサンクス
#     🔤 性別取得: stallion
#     🔤 英語名取得: Orion the Thanks
#     ✅ プロフィールテーブル発見
#       - 生年月日 (birth_date): 1996-04-10
#       - 調教師 (trainer): 赤間清松(大井)
#       - 馬主 (owner): 日浦桂子
#       - 生産者 (breeder): 森永隆範
#       - 産地 (birthplace): 門別
#       - 獲得賞金 (地方) (total_prize_local): 20291
#       - 通算成績 (career_record): {'starts': 24, 'wins': 11, 'win_rate': 45.8, 'first': 11, 'second': 2, 'third': 1, 'others': 10}
#       - 近親馬 (related_horses): イサミオリュー、オリオンワンサイド
#     📋 取得データ項目数: 12
#   ✅ 基本情報取得成功: オリオンザサンクス
#   🌳 血統関係取得: 1996103237
#     🧬 父ID設定: 000a000d73
#     🧬 母ID設定: 1991106520
#     🧬 母父ID設定: 000a000d2f
#     💕 種付関係新規作成: 000a000d73 × 1991106520 → 子供: 1996103237
#     💾 保存データ構造:
#       直接カラム: ['id', 'name_ja', 'name_en', 'birth_date', 'sex', 'sire_id', 'dam_id', 'maternal_grandsire_id']
#       プロフィール項目: ['trainer', 'owner', 'breeder', 'birthplace', 'total_prize_local', 'career_record', 'related_horses']
#       💾 関係保存: sire_of (000a000d73 -> 1996103237)
#       💾 関係保存: dam_of (1991106520 -> 1996103237)
#       💾 関係保存: bms_of (000a000d2f -> 1996103237)
#       💾 関係保存: mating (000a000d73 -> 1991106520)
#     ✅ 4件の関係を保存
# ✅ 完了: オリオンザサンクス
#     ✅ 完了
# 🐎 [19/198] アドマイヤコジーン (ID: 1996106512)
#
# --- 馬ID: 1996106512 完全取得開始 ---
# 🔍 ページ取得: https://db.netkeiba.com/horse/1996106512/
# 🔍 馬詳細ページ取得: 1996106512
#     📄 ページタイトル: アドマイヤコジーン (Admire Cozzene) | 競走馬データ - netkeiba
#     📝 馬名取得: アドマイヤコジーン
#     🔤 性別取得: stallion
#     🔤 英語名取得: Admire Cozzene
#     ✅ プロフィールテーブル発見
#       - 生年月日 (birth_date): 1996-04-08
#       - 調教師 (trainer): 橋田満(栗東)
#       - 馬主 (owner): 近藤利一
#       - 生産者 (breeder): 大樹ファーム
#       - 産地 (birthplace): 大樹町
#       - 獲得賞金 (中央) (total_prize_central): 30126
#       - 通算成績 (career_record): {'starts': 23, 'wins': 6, 'win_rate': 26.1, 'first': 6, 'second': 3, 'third': 2, 'others': 12}
#       - 近親馬 (related_horses): タイキエンデバー、タイキデスティニー
#     📋 取得データ項目数: 12
#   ✅ 基本情報取得成功: アドマイヤコジーン
#   🌳 血統関係取得: 1996106512
#     🧬 父ID設定: 000a001bda
#     🧬 母ID設定: 1991104457
#     🧬 母父ID設定: 000a000258
#     💕 種付関係新規作成: 000a001bda × 1991104457 → 子供: 1996106512
#     💾 保存データ構造:
#       直接カラム: ['id', 'name_ja', 'name_en', 'birth_date', 'sex', 'sire_id', 'dam_id', 'maternal_grandsire_id']
#       プロフィール項目: ['trainer', 'owner', 'breeder', 'birthplace', 'total_prize_central', 'career_record', 'related_horses']
#       💾 関係保存: sire_of (000a001bda -> 1996106512)
#       💾 関係保存: dam_of (1991104457 -> 1996106512)
#       💾 関係保存: bms_of (000a000258 -> 1996106512)
#       💾 関係保存: mating (000a001bda -> 1991104457)
#     ✅ 4件の関係を保存
# ✅ 完了: アドマイヤコジーン
#     ✅ 完了
# 🐎 [20/198] プリモディーネ (ID: 1996101283)
#
# --- 馬ID: 1996101283 完全取得開始 ---
# 🔍 ページ取得: https://db.netkeiba.com/horse/1996101283/
# 🔍 馬詳細ページ取得: 1996101283
#     📄 ページタイトル: プリモディーネ (Primo Ordine) | 競走馬データ - netkeiba
#     📝 馬名取得: プリモディーネ
#     🔤 性別取得: mare
#     🔤 英語名取得: Primo Ordine
#     ✅ プロフィールテーブル発見
#       - 生年月日 (birth_date): 1996-04-05
#       - 調教師 (trainer): 西橋豊治(栗東)
#       - 馬主 (owner): 伊達秀和
#       - 生産者 (breeder): サンシャイン牧場
#       - 産地 (birthplace): 門別町
#       - 獲得賞金 (中央) (total_prize_central): 10770
#       - 通算成績 (career_record): {'starts': 10, 'wins': 3, 'win_rate': 30.0, 'first': 3, 'second': 0, 'third': 1, 'others': 6}
#       - 近親馬 (related_horses): アドニス、イルラーゴ
#     📋 取得データ項目数: 12
#   ✅ 基本情報取得成功: プリモディーネ
#   🌳 血統関係取得: 1996101283
#     🧬 父ID設定: 000a000013
#     🧬 母ID設定: 1988100742
#     🧬 母父ID設定: 000a0003bd
#     💕 種付関係新規作成: 000a000013 × 1988100742 → 子供: 1996101283
#     💾 保存データ構造:
#       直接カラム: ['id', 'name_ja', 'name_en', 'birth_date', 'sex', 'sire_id', 'dam_id', 'maternal_grandsire_id']
#       プロフィール項目: ['trainer', 'owner', 'breeder', 'birthplace', 'total_prize_central', 'career_record', 'related_horses']
#       💾 関係保存: sire_of (000a000013 -> 1996101283)
#       💾 関係保存: dam_of (1988100742 -> 1996101283)
#       💾 関係保存: bms_of (000a0003bd -> 1996101283)
#       💾 関係保存: mating (000a000013 -> 1988100742)
#     ✅ 4件の関係を保存
# ✅ 完了: プリモディーネ
#     ✅ 完了
# 🐎 [21/198] ナリタトップロード (ID: 1996102442)
#
# --- 馬ID: 1996102442 完全取得開始 ---
# 🔍 ページ取得: https://db.netkeiba.com/horse/1996102442/
# 🔍 馬詳細ページ取得: 1996102442
#     📄 ページタイトル: ナリタトップロード (Narita Top Road) | 競走馬データ - netkeiba
#     📝 馬名取得: ナリタトップロード
#     🔤 性別取得: stallion
#     🔤 英語名取得: Narita Top Road
#     ✅ プロフィールテーブル発見
#       - 生年月日 (birth_date): 1996-04-04
#       - 調教師 (trainer): 沖芳夫(栗東)
#       - 馬主 (owner): 山路秀則
#       - 生産者 (breeder): 佐々木牧場
#       - 産地 (birthplace): 門別町
#       - 獲得賞金 (中央) (total_prize_central): 90011
#       - 通算成績 (career_record): {'starts': 30, 'wins': 8, 'win_rate': 26.7, 'first': 8, 'second': 6, 'third': 8, 'others': 8}
#       - 近親馬 (related_horses): フローラルグリーン、グリーンプレゼンス
#     📋 取得データ項目数: 12
#   ✅ 基本情報取得成功: ナリタトップロード
#   🌳 血統関係取得: 1996102442
#     🧬 父ID設定: 1985103538
#     🧬 母ID設定: 000a00012a
#     🧬 母父ID設定: 000a001785
#     💕 種付関係新規作成: 1985103538 × 000a00012a → 子供: 1996102442
#     💾 保存データ構造:
#       直接カラム: ['id', 'name_ja', 'name_en', 'birth_date', 'sex', 'sire_id', 'dam_id', 'maternal_grandsire_id']
#       プロフィール項目: ['trainer', 'owner', 'breeder', 'birthplace', 'total_prize_central', 'career_record', 'related_horses']
#       💾 関係保存: sire_of (1985103538 -> 1996102442)
#       💾 関係保存: dam_of (000a00012a -> 1996102442)
#       💾 関係保存: bms_of (000a001785 -> 1996102442)
#       💾 関係保存: mating (1985103538 -> 000a00012a)
#     ✅ 4件の関係を保存
# ✅ 完了: ナリタトップロード
#     ✅ 完了
# 🐎 [22/198] ノボトゥルー (ID: 1996110169)
#
# --- 馬ID: 1996110169 完全取得開始 ---
# 🔍 ページ取得: https://db.netkeiba.com/horse/1996110169/
# 🔍 馬詳細ページ取得: 1996110169
#     📄 ページタイトル: ノボトゥルー (Nobo True) | 競走馬データ - netkeiba
#     📝 馬名取得: ノボトゥルー
#     🔤 性別取得: stallion
#     🔤 英語名取得: Nobo True
#     ✅ プロフィールテーブル発見
#       - 生年月日 (birth_date): 1996-03-27
#       - 調教師 (trainer): 森秀行(栗東)
#       - 馬主 (owner): ＬＳ．Ｍ
#       - 生産者 (breeder): Mr. & Mrs. J. S. Moss
#       - 産地 (birthplace): 米
#       - 獲得賞金 (中央) (total_prize_central): 30621
#       - 獲得賞金 (地方) (total_prize_local): 30075
#       - 通算成績 (career_record): {'starts': 88, 'wins': 11, 'win_rate': 12.5, 'first': 11, 'second': 14, 'third': 13, 'others': 50}
#       - 近親馬 (related_horses): ハセノデジュール、ガティーク
#     📋 取得データ項目数: 13
#   ✅ 基本情報取得成功: ノボトゥルー
#   🌳 血統関係取得: 1996110169
#     🧬 父ID設定: 000a001e93
#     🧬 母ID設定: 000a009b5a
#     🧬 母父ID設定: 000a001615
#     💕 種付関係新規作成: 000a001e93 × 000a009b5a → 子供: 1996110169
#     💾 保存データ構造:
#       直接カラム: ['id', 'name_ja', 'name_en', 'birth_date', 'sex', 'sire_id', 'dam_id', 'maternal_grandsire_id']
#       プロフィール項目: ['trainer', 'owner', 'breeder', 'birthplace', 'total_prize_central', 'total_prize_local', 'career_record', 'related_horses']
#       💾 関係保存: sire_of (000a001e93 -> 1996110169)
#       💾 関係保存: dam_of (000a009b5a -> 1996110169)
#       💾 関係保存: bms_of (000a001615 -> 1996110169)
#       💾 関係保存: mating (000a001e93 -> 000a009b5a)
#     ✅ 4件の関係を保存
# ✅ 完了: ノボトゥルー
#     ✅ 完了
# 🐎 [23/198] メイショウドトウ (ID: 1996110113)
#
# --- 馬ID: 1996110113 完全取得開始 ---
# 🔍 ページ取得: https://db.netkeiba.com/horse/1996110113/
# 🔍 馬詳細ページ取得: 1996110113
#     📄 ページタイトル: メイショウドトウ (Meisho Doto) | 競走馬データ - netkeiba
#     📝 馬名取得: メイショウドトウ
#     🔤 性別取得: stallion
#     🔤 英語名取得: Meisho Doto
#     ✅ プロフィールテーブル発見
#       - 生年月日 (birth_date): 1996-03-25
#       - 調教師 (trainer): 安田伊佐(栗東)
#       - 馬主 (owner): 松本好雄
#       - 生産者 (breeder): P. Hardy
#       - 産地 (birthplace): 愛
#       - 獲得賞金 (中央) (total_prize_central): 90133
#       - 通算成績 (career_record): {'starts': 27, 'wins': 10, 'win_rate': 37.0, 'first': 10, 'second': 8, 'third': 2, 'others': 7}
#       - 近親馬 (related_horses): トロフィーディール、プリンセスルシータ
#     📋 取得データ項目数: 12
#   ✅ 基本情報取得成功: メイショウドトウ
#   🌳 血統関係取得: 1996110113
#     🧬 父ID設定: 000a002085
#     🧬 母ID設定: 000a000296
#     🧬 母父ID設定: 000a001785
#     💕 種付関係新規作成: 000a002085 × 000a000296 → 子供: 1996110113
#     💾 保存データ構造:
#       直接カラム: ['id', 'name_ja', 'name_en', 'birth_date', 'sex', 'sire_id', 'dam_id', 'maternal_grandsire_id']
#       プロフィール項目: ['trainer', 'owner', 'breeder', 'birthplace', 'total_prize_central', 'career_record', 'related_horses']
#       💾 関係保存: sire_of (000a002085 -> 1996110113)
#       💾 関係保存: dam_of (000a000296 -> 1996110113)
#       💾 関係保存: bms_of (000a001785 -> 1996110113)
#       💾 関係保存: mating (000a002085 -> 000a000296)
#     ✅ 4件の関係を保存
# ✅ 完了: メイショウドトウ
#     ✅ 完了
# 🐎 [24/198] テイエムオペラオー (ID: 1996100292)
#
# --- 馬ID: 1996100292 完全取得開始 ---
# 🔍 ページ取得: https://db.netkeiba.com/horse/1996100292/
# 🔍 馬詳細ページ取得: 1996100292
#     📄 ページタイトル: テイエムオペラオー (T.M.Opera O) | 競走馬データ - netkeiba
#     📝 馬名取得: テイエムオペラオー
#     🔤 性別取得: stallion
#     🔤 英語名取得: T.M.Opera O
#     ✅ プロフィールテーブル発見
#       - 生年月日 (birth_date): 1996-03-13
#       - 調教師 (trainer): 岩元市三(栗東)
#       - 馬主 (owner): 竹園正繼
#       - 生産者 (breeder): 杵臼牧場
#       - 産地 (birthplace): 浦河町
#       - セリ取引価格 (auction_price): 1,050万円(1997年 北海道10月市場)
#       - 獲得賞金 (中央) (total_prize_central): 180518
#       - 通算成績 (career_record): {'starts': 26, 'wins': 14, 'win_rate': 53.8, 'first': 14, 'second': 6, 'third': 3, 'others': 3}
#       - 近親馬 (related_horses): チャンネルフォー、キャプテンクック
#     📋 取得データ項目数: 13
#   ✅ 基本情報取得成功: テイエムオペラオー
#   🌳 血統関係取得: 1996100292
#     🧬 父ID設定: 000a000d77
#     🧬 母ID設定: 000a00612d
#     🧬 母父ID設定: 000a001340
#     💕 種付関係新規作成: 000a000d77 × 000a00612d → 子供: 1996100292
#     💾 保存データ構造:
#       直接カラム: ['id', 'name_ja', 'name_en', 'birth_date', 'sex', 'sire_id', 'dam_id', 'maternal_grandsire_id']
#       プロフィール項目: ['trainer', 'owner', 'breeder', 'birthplace', 'auction_price', 'total_prize_central', 'career_record', 'related_horses']
#       💾 関係保存: sire_of (000a000d77 -> 1996100292)
#       💾 関係保存: dam_of (000a00612d -> 1996100292)
#       💾 関係保存: bms_of (000a001340 -> 1996100292)
#       💾 関係保存: mating (000a000d77 -> 000a00612d)
#     ✅ 4件の関係を保存
# ✅ 完了: テイエムオペラオー
#     ✅ 完了
# 🐎 [25/198] アドマイヤベガ (ID: 1996107396)
#
# --- 馬ID: 1996107396 完全取得開始 ---
# 🔍 ページ取得: https://db.netkeiba.com/horse/1996107396/
# 🔍 馬詳細ページ取得: 1996107396
#     📄 ページタイトル: アドマイヤベガ (Admire Vega) | 競走馬データ - netkeiba
#     📝 馬名取得: アドマイヤベガ
#     🔤 性別取得: stallion
#     🔤 英語名取得: Admire Vega
#     ✅ プロフィールテーブル発見
#       - 生年月日 (birth_date): 1996-03-12
#       - 調教師 (trainer): 橋田満(栗東)
#       - 馬主 (owner): 近藤利一
#       - 生産者 (breeder): ノーザンファーム
#       - 産地 (birthplace): 早来町
#       - 獲得賞金 (中央) (total_prize_central): 20060
#       - 通算成績 (career_record): {'starts': 8, 'wins': 4, 'win_rate': 50.0, 'first': 4, 'second': 1, 'third': 0, 'others': 3}
#       - 近親馬 (related_horses): アドマイヤドン、キャプテンベガ
#     📋 取得データ項目数: 12
#   ✅ 基本情報取得成功: アドマイヤベガ
#   🌳 血統関係取得: 1996107396
#     🧬 父ID設定: 000a00033a
#     🧬 母ID設定: 1990104462
#     🧬 母父ID設定: 1983109006
#     💕 種付関係新規作成: 000a00033a × 1990104462 → 子供: 1996107396
#     💾 保存データ構造:
#       直接カラム: ['id', 'name_ja', 'name_en', 'birth_date', 'sex', 'sire_id', 'dam_id', 'maternal_grandsire_id']
#       プロフィール項目: ['trainer', 'owner', 'breeder', 'birthplace', 'total_prize_central', 'career_record', 'related_horses']
#       💾 関係保存: sire_of (000a00033a -> 1996107396)
#       💾 関係保存: dam_of (1990104462 -> 1996107396)
#       💾 関係保存: bms_of (1983109006 -> 1996107396)
#       💾 関係保存: mating (000a00033a -> 1990104462)
#     ✅ 4件の関係を保存
# ✅ 完了: アドマイヤベガ
#     ✅ 完了
# 🐎 [26/198] トゥザヴィクトリー (ID: 1996107386)
#
# --- 馬ID: 1996107386 完全取得開始 ---
# 🔍 ページ取得: https://db.netkeiba.com/horse/1996107386/
# 🔍 馬詳細ページ取得: 1996107386
#     📄 ページタイトル: トゥザヴィクトリー (To the Victory) | 競走馬データ - netkeiba
#     📝 馬名取得: トゥザヴィクトリー
#     🔤 性別取得: mare
#     🔤 英語名取得: To the Victory
#     ✅ プロフィールテーブル発見
#       - 生年月日 (birth_date): 1996-02-22
#       - 調教師 (trainer): 池江泰郎(栗東)
#       - 馬主 (owner): 金子真人
#       - 生産者 (breeder): ノーザンファーム
#       - 産地 (birthplace): 早来町
#       - 獲得賞金 (中央) (total_prize_central): 40762
#       - 通算成績 (career_record): {'starts': 21, 'wins': 6, 'win_rate': 28.6, 'first': 6, 'second': 4, 'third': 4, 'others': 7}
#       - 近親馬 (related_horses): サイレントディール、クリスタルウイング
#     📋 取得データ項目数: 12
#   ✅ 基本情報取得成功: トゥザヴィクトリー
#   🌳 血統関係取得: 1996107386
#     🧬 父ID設定: 000a00033a
#     🧬 母ID設定: 000a006496
#     🧬 母父ID設定: 000a001676
#     💕 種付関係新規作成: 000a00033a × 000a006496 → 子供: 1996107386
#     💾 保存データ構造:
#       直接カラム: ['id', 'name_ja', 'name_en', 'birth_date', 'sex', 'sire_id', 'dam_id', 'maternal_grandsire_id']
#       プロフィール項目: ['trainer', 'owner', 'breeder', 'birthplace', 'total_prize_central', 'career_record', 'related_horses']
#       💾 関係保存: sire_of (000a00033a -> 1996107386)
#       💾 関係保存: dam_of (000a006496 -> 1996107386)
#       💾 関係保存: bms_of (000a001676 -> 1996107386)
#       💾 関係保存: mating (000a00033a -> 000a006496)
#     ✅ 4件の関係を保存
# ✅ 完了: トゥザヴィクトリー
#     ✅ 完了
# 🐎 [27/198] シンボリインディ (ID: 1996110357)
#
# --- 馬ID: 1996110357 完全取得開始 ---
# 🔍 ページ取得: https://db.netkeiba.com/horse/1996110357/
# 🔍 馬詳細ページ取得: 1996110357
#     📄 ページタイトル: シンボリインディ (Symboli Indy) | 競走馬データ - netkeiba
#     📝 馬名取得: シンボリインディ
#     🔤 性別取得: stallion
#     🔤 英語名取得: Symboli Indy
#     ✅ プロフィールテーブル発見
#       - 生年月日 (birth_date): 1996-01-20
#       - 調教師 (trainer): 藤沢和雄(美浦)
#       - 馬主 (owner): シンボリ牧場
#       - 生産者 (breeder): Symboli Stud
#       - 産地 (birthplace): 米
#       - 獲得賞金 (中央) (total_prize_central): 20443
#       - 通算成績 (career_record): {'starts': 15, 'wins': 5, 'win_rate': 33.3, 'first': 5, 'second': 2, 'third': 0, 'others': 8}
#       - 近親馬 (related_horses): スイートクラフティ、スイートスリリング
#     📋 取得データ項目数: 12
#   ✅ 基本情報取得成功: シンボリインディ
#   🌳 血統関係取得: 1996110357
#     🧬 父ID設定: 000a001d37
#     🧬 母ID設定: 000a000140
#     🧬 母父ID設定: 000a0000d3
#     💕 種付関係新規作成: 000a001d37 × 000a000140 → 子供: 1996110357
#     💾 保存データ構造:
#       直接カラム: ['id', 'name_ja', 'name_en', 'birth_date', 'sex', 'sire_id', 'dam_id', 'maternal_grandsire_id']
#       プロフィール項目: ['trainer', 'owner', 'breeder', 'birthplace', 'total_prize_central', 'career_record', 'related_horses']
#       💾 関係保存: sire_of (000a001d37 -> 1996110357)
#       💾 関係保存: dam_of (000a000140 -> 1996110357)
#       💾 関係保存: bms_of (000a0000d3 -> 1996110357)
#       💾 関係保存: mating (000a001d37 -> 000a000140)
#     ✅ 4件の関係を保存
# ✅ 完了: シンボリインディ
#     ✅ 完了
# 🐎 [28/198] Fairy King Prawn (ID: 1995190008)
#
# --- 馬ID: 1995190008 完全取得開始 ---
# 🔍 ページ取得: https://db.netkeiba.com/horse/1995190008/
# 🔍 馬詳細ページ取得: 1995190008
#     📄 ページタイトル: Fairy King Prawn (フェアリーキングプローン) | 競走馬データ - netkeiba
#     📝 馬名取得: Fairy King Prawn
#     🔤 英語名取得: フェアリーキングプローン
#     ✅ プロフィールテーブル発見
#       - 生年月日 (birth_date): 1995-10-13
#       - 調教師 (trainer): アラン(海外)
#       - 馬主 (owner): Ｐ．ロー
#       - 生産者 (breeder): Tremon Thoroughbreds VIC
#       - 産地 (birthplace): 豪
#       - 獲得賞金 (中央) (total_prize_central): 9786
#       - 通算成績 (career_record): {'starts': 4, 'wins': 2, 'win_rate': 50.0, 'first': 2, 'second': 1, 'third': 0, 'others': 1}
#       - 近親馬 (related_horses): Crevette、Easy Rocking
#     📋 取得データ項目数: 11
#   ✅ 基本情報取得成功: Fairy King Prawn
#   🌳 血統関係取得: 1995190008
#     🧬 父ID設定: 000a0000d1
#     🧬 母ID設定: 000a00b09e
#     🧬 母父ID設定: 000a001948
#     💕 種付関係新規作成: 000a0000d1 × 000a00b09e → 子供: 1995190008
#     💾 保存データ構造:
#       直接カラム: ['id', 'name_ja', 'name_en', 'birth_date', 'sex', 'sire_id', 'dam_id', 'maternal_grandsire_id']
#       プロフィール項目: ['trainer', 'owner', 'breeder', 'birthplace', 'total_prize_central', 'career_record', 'related_horses']
#       💾 関係保存: sire_of (000a0000d1 -> 1995190008)
#       💾 関係保存: dam_of (000a00b09e -> 1995190008)
#       💾 関係保存: bms_of (000a001948 -> 1995190008)
#       💾 関係保存: mating (000a0000d1 -> 000a00b09e)
#     ✅ 4件の関係を保存
# ✅ 完了: Fairy King Prawn
#     ✅ 完了
# 🐎 [29/198] マキバスナイパー (ID: 1995108222)
#
# --- 馬ID: 1995108222 完全取得開始 ---
# 🔍 ページ取得: https://db.netkeiba.com/horse/1995108222/
# 🔍 馬詳細ページ取得: 1995108222
#     📄 ページタイトル: マキバスナイパー (Makiba Sniper) | 競走馬データ - netkeiba
#     📝 馬名取得: マキバスナイパー
#     🔤 性別取得: stallion
#     🔤 英語名取得: Makiba Sniper
#     ✅ プロフィールテーブル発見
#       - 生年月日 (birth_date): 1995-05-29
#       - 調教師 (trainer): 法理勝弘(高崎)
#       - 馬主 (owner): 新田知也
#       - 生産者 (breeder): 千葉新田牧場
#       - 産地 (birthplace): 池田
#       - 獲得賞金 (地方) (total_prize_local): 50441
#       - 通算成績 (career_record): {'starts': 67, 'wins': 21, 'win_rate': 31.3, 'first': 21, 'second': 10, 'third': 8, 'others': 28}
#       - 近親馬 (related_horses): マキバサイレント、マキバサンダー
#     📋 取得データ項目数: 12
#   ✅ 基本情報取得成功: マキバスナイパー
#   🌳 血統関係取得: 1995108222
#     🧬 父ID設定: 1977107057
#     🧬 母ID設定: 000a006281
#     🧬 母父ID設定: 000a000e46
#     💕 種付関係新規作成: 1977107057 × 000a006281 → 子供: 1995108222
#     💾 保存データ構造:
#       直接カラム: ['id', 'name_ja', 'name_en', 'birth_date', 'sex', 'sire_id', 'dam_id', 'maternal_grandsire_id']
#       プロフィール項目: ['trainer', 'owner', 'breeder', 'birthplace', 'total_prize_local', 'career_record', 'related_horses']
#       💾 関係保存: sire_of (1977107057 -> 1995108222)
#       💾 関係保存: dam_of (000a006281 -> 1995108222)
#       💾 関係保存: bms_of (000a000e46 -> 1995108222)
#       💾 関係保存: mating (1977107057 -> 000a006281)
#     ✅ 4件の関係を保存
# ✅ 完了: マキバスナイパー
#     ✅ 完了
# 🐎 [30/198] エリモエクセル (ID: 1995105495)
#
# --- 馬ID: 1995105495 完全取得開始 ---
# 🔍 ページ取得: https://db.netkeiba.com/horse/1995105495/
# 🔍 馬詳細ページ取得: 1995105495
#     📄 ページタイトル: エリモエクセル (Erimo Excel) | 競走馬データ - netkeiba
#     📝 馬名取得: エリモエクセル
#     🔤 性別取得: mare
#     🔤 英語名取得: Erimo Excel
#     ✅ プロフィールテーブル発見
#       - 生年月日 (birth_date): 1995-05-18
#       - 調教師 (trainer): 加藤敬二(栗東)
#       - 馬主 (owner): 山本慎一
#       - 生産者 (breeder): えりも農場
#       - 産地 (birthplace): えりも町
#       - 獲得賞金 (中央) (total_prize_central): 30676
#       - 通算成績 (career_record): {'starts': 17, 'wins': 6, 'win_rate': 35.3, 'first': 6, 'second': 0, 'third': 2, 'others': 9}
#       - 近親馬 (related_horses): ファンダフル、エリモノライオン
#     📋 取得データ項目数: 12
#   ✅ 基本情報取得成功: エリモエクセル
#   🌳 血統関係取得: 1995105495
#     🧬 父ID設定: 000a000d71
#     🧬 母ID設定: 000a0062b1
#     🧬 母父ID設定: 000a0014ce
#     💕 種付関係新規作成: 000a000d71 × 000a0062b1 → 子供: 1995105495
#     💾 保存データ構造:
#       直接カラム: ['id', 'name_ja', 'name_en', 'birth_date', 'sex', 'sire_id', 'dam_id', 'maternal_grandsire_id']
#       プロフィール項目: ['trainer', 'owner', 'breeder', 'birthplace', 'total_prize_central', 'career_record', 'related_horses']
#       💾 関係保存: sire_of (000a000d71 -> 1995105495)
#       💾 関係保存: dam_of (000a0062b1 -> 1995105495)
#       💾 関係保存: bms_of (000a0014ce -> 1995105495)
#       💾 関係保存: mating (000a000d71 -> 000a0062b1)
#     ✅ 4件の関係を保存
# ✅ 完了: エリモエクセル
#     ✅ 完了
# 🐎 [31/198] インテリパワー (ID: 1995107646)
#
# --- 馬ID: 1995107646 完全取得開始 ---
# 🔍 ページ取得: https://db.netkeiba.com/horse/1995107646/
# 🔍 馬詳細ページ取得: 1995107646
# ...
#       - 調教師 (trainer): 沢峰次(美浦)
#       - 馬主 (owner): 有限会社社台レースホース
#       - 生産者 (breeder): 社台ファーム
#       - 産地 (birthplace): 白老町
#       - 獲得賞金 (中央) (total_prize_central): 10750
#       - 通算成績 (career_record): {'starts': 10, 'wins': 4, 'win_rate': 40.0, 'first': 4, 'second': 3, 'third': 2, 'others': 1}
#       - 近親馬 (related_horses): ワーキングガール、ダイナワードン
#     📋 取得データ項目数: 12
#   ✅ 基本情報取得成功: ダイナコスモス
#   🌳 血統関係取得: 1983104043
#     🧬 父ID設定: 000a000444
#     🧬 母ID設定: 1977103846
#     🧬 母父ID設定: 000a000258
#     💕 種付関係新規作成: 000a000444 × 1977103846 → 子供: 1983104043
#     💾 保存データ構造:
#       直接カラム: ['id', 'name_ja', 'name_en', 'birth_date', 'sex', 'sire_id', 'dam_id', 'maternal_grandsire_id']
#       プロフィール項目: ['trainer', 'owner', 'breeder', 'birthplace', 'total_prize_central', 'career_record', 'related_horses']
#       💾 関係保存: sire_of (000a000444 -> 1983104043)
#       💾 関係保存: dam_of (1977103846 -> 1983104043)
#       💾 関係保存: bms_of (000a000258 -> 1983104043)
#       💾 関係保存: mating (000a000444 -> 1977103846)
#     ✅ 4件の関係を保存
# ✅ 完了: ダイナコスモス
#     ✅ 完了
# 🐎 [188/198] ダイナガリバー (ID: 1983104089)
#
# --- 馬ID: 1983104089 完全取得開始 ---
# 🔍 ページ取得: https://db.netkeiba.com/horse/1983104089/
# 🔍 馬詳細ページ取得: 1983104089
#     📄 ページタイトル: ダイナガリバー (Dyna Gulliver) | 競走馬データ - netkeiba
#     📝 馬名取得: ダイナガリバー
#     🔤 性別取得: stallion
#     🔤 英語名取得: Dyna Gulliver
#     ✅ プロフィールテーブル発見
#       - 生年月日 (birth_date): 1983-03-23
#       - 調教師 (trainer): 松山吉三(美浦)
#       - 馬主 (owner): 社台レースホース
#       - 生産者 (breeder): 社台ファーム
#       - 産地 (birthplace): 千歳市
#       - 獲得賞金 (中央) (total_prize_central): 20740
#       - 通算成績 (career_record): {'starts': 13, 'wins': 5, 'win_rate': 38.5, 'first': 5, 'second': 2, 'third': 1, 'others': 5}
#       - 近親馬 (related_horses): カズシゲ、ユアースダイナ
#     📋 取得データ項目数: 12
#   ✅ 基本情報取得成功: ダイナガリバー
#   🌳 血統関係取得: 1983104089
#     🧬 父ID設定: 000a000258
#     🧬 母ID設定: 1955103325
#     🧬 母父ID設定: 000a0003e1
#     💕 種付関係新規作成: 000a000258 × 1955103325 → 子供: 1983104089
#     💾 保存データ構造:
#       直接カラム: ['id', 'name_ja', 'name_en', 'birth_date', 'sex', 'sire_id', 'dam_id', 'maternal_grandsire_id']
#       プロフィール項目: ['trainer', 'owner', 'breeder', 'birthplace', 'total_prize_central', 'career_record', 'related_horses']
#       💾 関係保存: sire_of (000a000258 -> 1983104089)
#       💾 関係保存: dam_of (1955103325 -> 1983104089)
#       💾 関係保存: bms_of (000a0003e1 -> 1983104089)
#       💾 関係保存: mating (000a000258 -> 1955103325)
#     ✅ 4件の関係を保存
# ✅ 完了: ダイナガリバー
#     ✅ 完了
# 🐎 [189/198] クシロキング (ID: 1982100320)
#
# --- 馬ID: 1982100320 完全取得開始 ---
# 🔍 ページ取得: https://db.netkeiba.com/horse/1982100320/
# 🔍 馬詳細ページ取得: 1982100320
#     📄 ページタイトル: クシロキング (Kushiro King) | 競走馬データ - netkeiba
#     📝 馬名取得: クシロキング
#     🔤 性別取得: stallion
#     🔤 英語名取得: Kushiro King
#     ✅ プロフィールテーブル発見
#       - 生年月日 (birth_date): 1982-05-18
#       - 調教師 (trainer): 中野吉太郎(美浦)
#       - 馬主 (owner): 阿部昭
#       - 生産者 (breeder): 上山牧場
#       - 産地 (birthplace): 浦河町
#       - 獲得賞金 (中央) (total_prize_central): 20150
#       - 通算成績 (career_record): {'starts': 25, 'wins': 7, 'win_rate': 28.0, 'first': 7, 'second': 5, 'third': 3, 'others': 10}
#       - 近親馬 (related_horses): スワロークイーン、ドリームテイント
#     📋 取得データ項目数: 12
#   ✅ 基本情報取得成功: クシロキング
#   🌳 血統関係取得: 1982100320
#     🧬 父ID設定: 000a0003ff
#     🧬 母ID設定: 1977103941
#     🧬 母父ID設定: 000a000355
#     💕 種付関係新規作成: 000a0003ff × 1977103941 → 子供: 1982100320
#     💾 保存データ構造:
#       直接カラム: ['id', 'name_ja', 'name_en', 'birth_date', 'sex', 'sire_id', 'dam_id', 'maternal_grandsire_id']
#       プロフィール項目: ['trainer', 'owner', 'breeder', 'birthplace', 'total_prize_central', 'career_record', 'related_horses']
#       💾 関係保存: sire_of (000a0003ff -> 1982100320)
#       💾 関係保存: dam_of (1977103941 -> 1982100320)
#       💾 関係保存: bms_of (000a000355 -> 1982100320)
#       💾 関係保存: mating (000a0003ff -> 1977103941)
#     ✅ 4件の関係を保存
# ✅ 完了: クシロキング
#     ✅ 完了
# 🐎 [190/198] サクラユタカオー (ID: 1982101222)
#
# --- 馬ID: 1982101222 完全取得開始 ---
# 🔍 ページ取得: https://db.netkeiba.com/horse/1982101222/
# 🔍 馬詳細ページ取得: 1982101222
#     📄 ページタイトル: サクラユタカオー (Sakura Yutaka O) | 競走馬データ - netkeiba
#     📝 馬名取得: サクラユタカオー
#     🔤 性別取得: stallion
#     🔤 英語名取得: Sakura Yutaka O
#     ✅ プロフィールテーブル発見
#       - 生年月日 (birth_date): 1982-04-29
#       - 調教師 (trainer): 境勝太郎(美浦)
#       - 馬主 (owner): 株式会社さくらコマース
#       - 生産者 (breeder): 藤原牧場
#       - 産地 (birthplace): 静内町
#       - 獲得賞金 (中央) (total_prize_central): 10000
#       - 通算成績 (career_record): {'starts': 12, 'wins': 6, 'win_rate': 50.0, 'first': 6, 'second': 2, 'third': 0, 'others': 4}
#       - 近親馬 (related_horses): サクラシンゲキ、サクラスマイル
#     📋 取得データ項目数: 12
#   ✅ 基本情報取得成功: サクラユタカオー
#   🌳 血統関係取得: 1982101222
#     🧬 父ID設定: 000a000355
#     🧬 母ID設定: 1955103119
#     🧬 母父ID設定: 000a0009ef
#     💕 種付関係新規作成: 000a000355 × 1955103119 → 子供: 1982101222
#     💾 保存データ構造:
#       直接カラム: ['id', 'name_ja', 'name_en', 'birth_date', 'sex', 'sire_id', 'dam_id', 'maternal_grandsire_id']
#       プロフィール項目: ['trainer', 'owner', 'breeder', 'birthplace', 'total_prize_central', 'career_record', 'related_horses']
#       💾 関係保存: sire_of (000a000355 -> 1982101222)
#       💾 関係保存: dam_of (1955103119 -> 1982101222)
#       💾 関係保存: bms_of (000a0009ef -> 1982101222)
#       💾 関係保存: mating (000a000355 -> 1955103119)
#     ✅ 4件の関係を保存
# ✅ 完了: サクラユタカオー
#     ✅ 完了
# 🐎 [191/198] パーシャンボーイ (ID: 1982107332)
#
# --- 馬ID: 1982107332 完全取得開始 ---
# 🔍 ページ取得: https://db.netkeiba.com/horse/1982107332/
# 🔍 馬詳細ページ取得: 1982107332
#     📄 ページタイトル: パーシャンボーイ (Persian Boy) | 競走馬データ - netkeiba
#     📝 馬名取得: パーシャンボーイ
#     🔤 性別取得: stallion
#     🔤 英語名取得: Persian Boy
#     ✅ プロフィールテーブル発見
#       - 生年月日 (birth_date): 1982-04-18
#       - 調教師 (trainer): 高松三太(美浦)
#       - 馬主 (owner): 伊達秀和
#       - 生産者 (breeder): Dunchurch Lodge Stud Co.
#       - 産地 (birthplace): 英
#       - 獲得賞金 (中央) (total_prize_central): 10250
#       - 通算成績 (career_record): {'starts': 11, 'wins': 5, 'win_rate': 45.5, 'first': 5, 'second': 3, 'third': 0, 'others': 3}
#       - 近親馬 (related_horses): クリプテイック、クリプト
#     📋 取得データ項目数: 12
#   ✅ 基本情報取得成功: パーシャンボーイ
#   🌳 血統関係取得: 1982107332
#     🧬 父ID設定: 000a0012f3
#     🧬 母ID設定: 000a007246
#     🧬 母父ID設定: 000a000ec9
#     💕 種付関係新規作成: 000a0012f3 × 000a007246 → 子供: 1982107332
#     💾 保存データ構造:
#       直接カラム: ['id', 'name_ja', 'name_en', 'birth_date', 'sex', 'sire_id', 'dam_id', 'maternal_grandsire_id']
#       プロフィール項目: ['trainer', 'owner', 'breeder', 'birthplace', 'total_prize_central', 'career_record', 'related_horses']
#       💾 関係保存: sire_of (000a0012f3 -> 1982107332)
#       💾 関係保存: dam_of (000a007246 -> 1982107332)
#       💾 関係保存: bms_of (000a000ec9 -> 1982107332)
#       💾 関係保存: mating (000a0012f3 -> 000a007246)
#     ✅ 4件の関係を保存
# ✅ 完了: パーシャンボーイ
#     ✅ 完了
# 🐎 [192/198] タカラスチール (ID: 1982100976)
#
# --- 馬ID: 1982100976 完全取得開始 ---
# 🔍 ページ取得: https://db.netkeiba.com/horse/1982100976/
# 🔍 馬詳細ページ取得: 1982100976
#     📄 ページタイトル: タカラスチール (Takara Steal) | 競走馬データ - netkeiba
#     📝 馬名取得: タカラスチール
#     🔤 性別取得: mare
#     🔤 英語名取得: Takara Steal
#     ✅ プロフィールテーブル発見
#       - 生年月日 (birth_date): 1982-04-16
#       - 調教師 (trainer): 坂本栄三郎(美浦)
#       - 馬主 (owner): 村山義男
#       - 生産者 (breeder): 鈴木実
#       - 産地 (birthplace): 静内町
#       - 獲得賞金 (中央) (total_prize_central): 10490
#       - 通算成績 (career_record): {'starts': 32, 'wins': 8, 'win_rate': 25.0, 'first': 8, 'second': 5, 'third': 6, 'others': 13}
#       - 近親馬 (related_horses): タカラフラッシュ、ウメノシンオー
#     📋 取得データ項目数: 12
#   ✅ 基本情報取得成功: タカラスチール
#   🌳 血統関係取得: 1982100976
#     🧬 父ID設定: 000a0004ce
#     🧬 母ID設定: 1955104875
#     🧬 母父ID設定: 000a0003eb
#     💕 種付関係新規作成: 000a0004ce × 1955104875 → 子供: 1982100976
#     💾 保存データ構造:
#       直接カラム: ['id', 'name_ja', 'name_en', 'birth_date', 'sex', 'sire_id', 'dam_id', 'maternal_grandsire_id']
#       プロフィール項目: ['trainer', 'owner', 'breeder', 'birthplace', 'total_prize_central', 'career_record', 'related_horses']
#       💾 関係保存: sire_of (000a0004ce -> 1982100976)
#       💾 関係保存: dam_of (1955104875 -> 1982100976)
#       💾 関係保存: bms_of (000a0003eb -> 1982100976)
#       💾 関係保存: mating (000a0004ce -> 1955104875)
#     ✅ 4件の関係を保存
# ✅ 完了: タカラスチール
#     ✅ 完了
# 🐎 [193/198] ミホシンザン (ID: 1982103164)
#
# --- 馬ID: 1982103164 完全取得開始 ---
# 🔍 ページ取得: https://db.netkeiba.com/horse/1982103164/
# 🔍 馬詳細ページ取得: 1982103164
#     📄 ページタイトル: ミホシンザン (Miho Shinzan) | 競走馬データ - netkeiba
#     📝 馬名取得: ミホシンザン
#     🔤 性別取得: stallion
#     🔤 英語名取得: Miho Shinzan
#     ✅ プロフィールテーブル発見
#       - 生年月日 (birth_date): 1982-04-16
#       - 調教師 (trainer): 田中朋次郎(美浦)
#       - 馬主 (owner): 堤勘時
#       - 生産者 (breeder): 日進牧場
#       - 産地 (birthplace): 浦河町
#       - 獲得賞金 (中央) (total_prize_central): 40710
#       - 通算成績 (career_record): {'starts': 17, 'wins': 10, 'win_rate': 58.8, 'first': 10, 'second': 1, 'third': 4, 'others': 2}
#       - 近親馬 (related_horses): リックナポリ、ジョウテンムサシ
#     📋 取得データ項目数: 12
#   ✅ 基本情報取得成功: ミホシンザン
#   🌳 血統関係取得: 1982103164
#     🧬 父ID設定: 000a000a2d
#     🧬 母ID設定: 1955108338
#     🧬 母父ID設定: 000a000234
#     💕 種付関係新規作成: 000a000a2d × 1955108338 → 子供: 1982103164
#     💾 保存データ構造:
#       直接カラム: ['id', 'name_ja', 'name_en', 'birth_date', 'sex', 'sire_id', 'dam_id', 'maternal_grandsire_id']
#       プロフィール項目: ['trainer', 'owner', 'breeder', 'birthplace', 'total_prize_central', 'career_record', 'related_horses']
#       💾 関係保存: sire_of (000a000a2d -> 1982103164)
#       💾 関係保存: dam_of (1955108338 -> 1982103164)
#       💾 関係保存: bms_of (000a000234 -> 1982103164)
#       💾 関係保存: mating (000a000a2d -> 1955108338)
#     ✅ 4件の関係を保存
# ✅ 完了: ミホシンザン
#     ✅ 完了
# 🐎 [194/198] スズパレード (ID: 1981101373)
#
# --- 馬ID: 1981101373 完全取得開始 ---
# 🔍 ページ取得: https://db.netkeiba.com/horse/1981101373/
# 🔍 馬詳細ページ取得: 1981101373
#     📄 ページタイトル: スズパレード (Suzu Parade) | 競走馬データ - netkeiba
#     📝 馬名取得: スズパレード
#     🔤 性別取得: stallion
#     🔤 英語名取得: Suzu Parade
#     ✅ プロフィールテーブル発見
#       - 生年月日 (birth_date): 1981-03-21
#       - 調教師 (trainer): 富田六郎(美浦)
#       - 馬主 (owner): 小紫芳夫
#       - 生産者 (breeder): 柏台牧場
#       - 産地 (birthplace): 門別町
#       - 獲得賞金 (中央) (total_prize_central): 20230
#       - 通算成績 (career_record): {'starts': 25, 'wins': 12, 'win_rate': 48.0, 'first': 12, 'second': 1, 'third': 1, 'others': 11}
#       - 近親馬 (related_horses): スズドレッサー、ユウキスナイパー
#     📋 取得データ項目数: 12
#   ✅ 基本情報取得成功: スズパレード
#   🌳 血統関係取得: 1981101373
#     🧬 父ID設定: 000a0004c6
#     🧬 母ID設定: 1955104487
#     🧬 母父ID設定: 000a0004ae
#     💕 種付関係新規作成: 000a0004c6 × 1955104487 → 子供: 1981101373
#     💾 保存データ構造:
#       直接カラム: ['id', 'name_ja', 'name_en', 'birth_date', 'sex', 'sire_id', 'dam_id', 'maternal_grandsire_id']
#       プロフィール項目: ['trainer', 'owner', 'breeder', 'birthplace', 'total_prize_central', 'career_record', 'related_horses']
#       💾 関係保存: sire_of (000a0004c6 -> 1981101373)
#       💾 関係保存: dam_of (1955104487 -> 1981101373)
#       💾 関係保存: bms_of (000a0004ae -> 1981101373)
#       💾 関係保存: mating (000a0004c6 -> 1955104487)
#     ✅ 4件の関係を保存
# ✅ 完了: スズパレード
#     ✅ 完了
# 🐎 [195/198] シンボリルドルフ (ID: 1981107017)
#
# --- 馬ID: 1981107017 完全取得開始 ---
# 🔍 ページ取得: https://db.netkeiba.com/horse/1981107017/
# 🔍 馬詳細ページ取得: 1981107017
#     📄 ページタイトル: シンボリルドルフ (Symboli Rudolf) | 競走馬データ - netkeiba
#     📝 馬名取得: シンボリルドルフ
#     🔤 性別取得: stallion
#     🔤 英語名取得: Symboli Rudolf
#     ✅ プロフィールテーブル発見
#       - 生年月日 (birth_date): 1981-03-13
#       - 調教師 (trainer): 野平祐二(美浦)
#       - 馬主 (owner): シンボリ牧場
#       - 生産者 (breeder): シンボリ牧場
#       - 産地 (birthplace): 門別町
#       - 獲得賞金 (中央) (total_prize_central): 60482
#       - 通算成績 (career_record): {'starts': 16, 'wins': 13, 'win_rate': 81.2, 'first': 13, 'second': 1, 'third': 1, 'others': 1}
#       - 近親馬 (related_horses): シンボリフレンド、マチカネアスカ
#     📋 取得データ項目数: 12
#   ✅ 基本情報取得成功: シンボリルドルフ
#   🌳 血統関係取得: 1981107017
#     🧬 父ID設定: 000a00026d
#     🧬 母ID設定: 1955103905
#     🧬 母父ID設定: 1963100089
#     💕 種付関係新規作成: 000a00026d × 1955103905 → 子供: 1981107017
#     💾 保存データ構造:
#       直接カラム: ['id', 'name_ja', 'name_en', 'birth_date', 'sex', 'sire_id', 'dam_id', 'maternal_grandsire_id']
#       プロフィール項目: ['trainer', 'owner', 'breeder', 'birthplace', 'total_prize_central', 'career_record', 'related_horses']
#       💾 関係保存: sire_of (000a00026d -> 1981107017)
#       💾 関係保存: dam_of (1955103905 -> 1981107017)
#       💾 関係保存: bms_of (1963100089 -> 1981107017)
#       💾 関係保存: mating (000a00026d -> 1955103905)
#     ✅ 4件の関係を保存
# ✅ 完了: シンボリルドルフ
#     ✅ 完了
# 🐎 [196/198] ギャロップダイナ (ID: 1980101941)
#
# --- 馬ID: 1980101941 完全取得開始 ---
# 🔍 ページ取得: https://db.netkeiba.com/horse/1980101941/
# 🔍 馬詳細ページ取得: 1980101941
#     📄 ページタイトル: ギャロップダイナ (Gallop Dyna) | 競走馬データ - netkeiba
#     📝 馬名取得: ギャロップダイナ
#     🔤 性別取得: stallion
#     🔤 英語名取得: Gallop Dyna
#     ✅ プロフィールテーブル発見
#       - 生年月日 (birth_date): 1980-04-25
#       - 調教師 (trainer): 矢野進(美浦)
#       - 馬主 (owner): 有限会社社台レースホース
#       - 生産者 (breeder): 社台ファーム
#       - 産地 (birthplace): 早来町
#       - 獲得賞金 (中央) (total_prize_central): 20118
#       - 通算成績 (career_record): {'starts': 42, 'wins': 10, 'win_rate': 23.8, 'first': 10, 'second': 10, 'third': 4, 'others': 18}
#       - 近親馬 (related_horses): ダイナチャイナ、エイシンオーシャン
#     📋 取得データ項目数: 12
#   ✅ 基本情報取得成功: ギャロップダイナ
#   🌳 血統関係取得: 1980101941
#     🧬 父ID設定: 000a000258
#     🧬 母ID設定: 1955106626
#     🧬 母父ID設定: 000a00040e
#     💕 種付関係新規作成: 000a000258 × 1955106626 → 子供: 1980101941
#     💾 保存データ構造:
#       直接カラム: ['id', 'name_ja', 'name_en', 'birth_date', 'sex', 'sire_id', 'dam_id', 'maternal_grandsire_id']
#       プロフィール項目: ['trainer', 'owner', 'breeder', 'birthplace', 'total_prize_central', 'career_record', 'related_horses']
#       💾 関係保存: sire_of (000a000258 -> 1980101941)
#       💾 関係保存: dam_of (1955106626 -> 1980101941)
#       💾 関係保存: bms_of (000a00040e -> 1980101941)
#       💾 関係保存: mating (000a000258 -> 1955106626)
#     ✅ 4件の関係を保存
# ✅ 完了: ギャロップダイナ
#     ✅ 完了
# 🐎 [197/198] ミスターシービー (ID: 1980107022)
#
# --- 馬ID: 1980107022 完全取得開始 ---
# 🔍 ページ取得: https://db.netkeiba.com/horse/1980107022/
# 🔍 馬詳細ページ取得: 1980107022
#     📄 ページタイトル: ミスターシービー (Mr. C. B.) | 競走馬データ - netkeiba
#     📝 馬名取得: ミスターシービー
#     🔤 性別取得: stallion
#     🔤 英語名取得: Mr. C. B.
#     ✅ プロフィールテーブル発見
#       - 生年月日 (birth_date): 1980-04-07
#       - 調教師 (trainer): 松山康久(美浦)
#       - 馬主 (owner): 千明牧場
#       - 生産者 (breeder): 千明牧場
#       - 産地 (birthplace): 浦河町
#       - 獲得賞金 (中央) (total_prize_central): 30080
#       - 通算成績 (career_record): {'starts': 15, 'wins': 8, 'win_rate': 53.3, 'first': 8, 'second': 3, 'third': 1, 'others': 3}
#     📋 取得データ項目数: 11
#   ✅ 基本情報取得成功: ミスターシービー
#   🌳 血統関係取得: 1980107022
#     🧬 父ID設定: 000a0003c7
#     🧬 母ID設定: 1955106410
#     🧬 母父ID設定: 000a00036a
#     💕 種付関係新規作成: 000a0003c7 × 1955106410 → 子供: 1980107022
#     💾 保存データ構造:
#       直接カラム: ['id', 'name_ja', 'name_en', 'birth_date', 'sex', 'sire_id', 'dam_id', 'maternal_grandsire_id']
#       プロフィール項目: ['trainer', 'owner', 'breeder', 'birthplace', 'total_prize_central', 'career_record']
#       💾 関係保存: sire_of (000a0003c7 -> 1980107022)
#       💾 関係保存: dam_of (1955106410 -> 1980107022)
#       💾 関係保存: bms_of (000a00036a -> 1980107022)
#       💾 関係保存: mating (000a0003c7 -> 1955106410)
#     ✅ 4件の関係を保存
# ✅ 完了: ミスターシービー
#     ✅ 完了
# 🐎 [198/198] Jupiter Island (ID: 1979109009)
#
# --- 馬ID: 1979109009 完全取得開始 ---
# 🔍 ページ取得: https://db.netkeiba.com/horse/1979109009/
# 🔍 馬詳細ページ取得: 1979109009
#     📄 ページタイトル: Jupiter Island (ジュピターアイランド) | 競走馬データ - netkeiba
#     📝 馬名取得: Jupiter Island
#     🔤 性別取得: stallion
#     🔤 英語名取得: ジュピターアイランド
#     ✅ プロフィールテーブル発見
#       - 生年月日 (birth_date): 1979-02-23
#       - 調教師 (trainer): ブリテン(海外)
#       - 馬主 (owner): タビストック侯爵
#       - 産地 (birthplace): 英
#       - 獲得賞金 (中央) (total_prize_central): 8000
#       - 通算成績 (career_record): {'starts': 1, 'wins': 1, 'win_rate': 100.0, 'first': 1, 'second': 0, 'third': 0, 'others': 0}
#       - 近親馬 (related_horses): レディシーモン、Krayyan
#     📋 取得データ項目数: 11
#   ✅ 基本情報取得成功: Jupiter Island
#   🌳 血統関係取得: 1979109009
#     🧬 父ID設定: 000a0004cc
#     🧬 母ID設定: 000a00aac2
#     🧬 母父ID設定: 000a000e3f
#     💕 種付関係新規作成: 000a0004cc × 000a00aac2 → 子供: 1979109009
#     💾 保存データ構造:
#       直接カラム: ['id', 'name_ja', 'name_en', 'birth_date', 'sex', 'sire_id', 'dam_id', 'maternal_grandsire_id']
#       プロフィール項目: ['trainer', 'owner', 'birthplace', 'total_prize_central', 'career_record', 'related_horses']
#       💾 関係保存: sire_of (000a0004cc -> 1979109009)
#       💾 関係保存: dam_of (000a00aac2 -> 1979109009)
#       💾 関係保存: bms_of (000a000e3f -> 1979109009)
#       💾 関係保存: mating (000a0004cc -> 000a00aac2)
#     ✅ 4件の関係を保存
# ✅ 完了: Jupiter Island
#     ✅ 完了
#
# ======================================================================
# 🏁 完全バッチ処理完了！
# ======================================================================
# 📋 馬リスト取得: 198頭
# ✅ 詳細処理成功: 198頭
# ❌ 詳細処理失敗: 0頭
# 📊 詳細処理成功率: 100.0%
# ======================================================================
# 📄 結果保存: outputs/complete_batch_results_20250824_001939.json
#
# 📊 バッチ処理結果:
#   リスト取得: 198頭
#   詳細成功: 198頭
#   詳細失敗: 0頭

# %%
# ===== セル1: セットアップ =====

import sys
import os
import time
from datetime import datetime
import json

# パス設定
current_dir = os.getcwd()  # notebooks/
project_root = os.path.dirname(current_dir)  # ml-analysis/
scraping_path = os.path.join(project_root, 'src', 'scraping')

# パス確認
print(f"📁 現在地: {current_dir}")
print(f"📁 プロジェクトルート: {project_root}")
print(f"📁 スクレイピングパス: {scraping_path}")
print(f"✅ パス存在確認: {os.path.exists(scraping_path)}")

if scraping_path not in sys.path:
    sys.path.append(scraping_path)

# モジュールインポート
from simple_offset_scraper import (
    SimpleOffsetHorseListScraper, 
    CompleteBatchProcessor,
    get_next_100_horses,
    run_complete_100_horses_batch,
    test_offset_scraper
)

print("🚀 モジュール読み込み完了")
print("-" * 50)
# Out:
# 📁 現在地: /Users/skdata_mng/Documents/PROJECTS/STALLION/stallion-analytics/packages/ml-analysis/notebooks
# 📁 プロジェクトルート: /Users/skdata_mng/Documents/PROJECTS/STALLION/stallion-analytics/packages/ml-analysis
# 📁 スクレイピングパス: /Users/skdata_mng/Documents/PROJECTS/STALLION/stallion-analytics/packages/ml-analysis/src/scraping
# ✅ パス存在確認: True
# 🚀 モジュール読み込み完了
# --------------------------------------------------

# %%
print("🔍 詳細データ処理開始")

# CompleteBatchProcessorを使用
processor = CompleteBatchProcessor()

# 100頭で詳細処理をテスト
batch_results = processor.collect_and_process_horses(
    total_target=100,
    batch_size=25,
    start_offset=100,
    min_birth_year=2000,
    process_details=True,  # 詳細処理有効
    delay_between_horses=3  # 3秒間隔
)

print("\n📊 バッチ処理結果:")
print(f"  リスト取得: {batch_results.get('list_count', 0)}頭")
print(f"  詳細成功: {len(batch_results.get('success', []))}頭")
print(f"  詳細失敗: {len(batch_results.get('failed', []))}頭")
# Out:
# 🔍 詳細データ処理開始
# ======================================================================
# 🏇 完全バッチ処理開始
# ======================================================================
# 🎯 目標: 100頭
# 📦 バッチサイズ: 25頭
# 📍 開始オフセット: 0
# 📅 最小生年: 2000年
# 🔧 詳細処理: 有効
#
# 🔍 Step 1: 馬リスト取得
# 📦 リストバッチ: オフセット0, 25頭取得
# 🎯 G1馬取得開始:
#    オフセット: 0
#    最大取得数: 25頭
#    最小生年: 2000年
# --------------------------------------------------
# 📄 開始ページ: 1, ページ内位置: 0
#
# 📄 ページ1を処理中...
#   ✓ [  1] カムニャック (2022年)
#   ✓ [  2] クロワデュノール (2022年)
#   ✓ [  3] ミリアッドラヴ (2022年)
#   ✓ [  4] アドマイヤズーム (2022年)
#   ✓ [  5] パンジャタワー (2022年)
#   ✓ [  6] アルマヴェローチェ (2022年)
#   ✓ [  7] ナチュラルライズ (2022年)
#   ✓ [  8] エンブロイダリー (2022年)
#   ✓ [  9] ミュージアムマイル (2022年)
#   ✓ [ 10] ミッキーファイト (2021年)
#   ✓ [ 11] メイショウタバル (2021年)
#   ✓ [ 12] レガレイラ (2021年)
#   ✓ [ 13] ジャスティンミラノ (2021年)
#   ✓ [ 14] ダノンデサイル (2021年)
#   ✓ [ 15] ヘデントール (2021年)
#   ✓ [ 16] ラムジェット (2021年)
#   ✓ [ 17] ジャンタルマンタル (2021年)
#   ✓ [ 18] アーバンシック (2021年)
#   ✓ [ 19] アスコリピチェーノ (2021年)
#   ✓ [ 20] フォーエバーヤング (2021年)
#   ✓ [ 21] ステレンボッシュ (2021年)
#   ✓ [ 22] アンモシエラ (2021年)
#   ✓ [ 23] チェルヴィニア (2021年)
#   ✓ [ 24] アマンテビアンコ (2021年)
#   ✓ [ 25] デルマソトガケ (2020年)
#
# ✅ 合計25頭を取得しました
# ✅ リストバッチ完了: 25頭追加, 累計25頭
# 📦 リストバッチ: オフセット25, 25頭取得
# 🎯 G1馬取得開始:
#    オフセット: 25
#    最大取得数: 25頭
#    最小生年: 2000年
# --------------------------------------------------
# 📄 開始ページ: 1, ページ内位置: 25
#
# 📄 ページ1を処理中...
#   ✓ [  1] ドゥレッツァ (2020年)
#   ✓ [  2] ブレイディヴェーグ (2020年)
#   ✓ [  3] ベラジオオペラ (2020年)
#   ✓ [  4] ミックファイア (2020年)
#   ✓ [  5] ソールオリエンス (2020年)
#   ✓ [  6] コスタノヴァ (2020年)
#   ✓ [  7] タスティエーラ (2020年)
#   ✓ [  8] ルガル (2020年)
#   ✓ [  9] シャンパンカラー (2020年)
#   ✓ [ 10] ドルチェモア (2020年)
#   ✓ [ 11] リバティアイランド (2020年)
#   ✓ [ 12] ドゥラエレーデ (2020年)
#   ✓ [ 13] ブローザホーン (2019年)
#   ✓ [ 14] ドウデュース (2019年)
#   ✓ [ 15] エコロデュエル (2019年)
#   ✓ [ 16] ノットゥルノ (2019年)
#   ✓ [ 17] ジャスティンパレス (2019年)
#   ✓ [ 18] ママコチャ (2019年)
#   ✓ [ 19] キングズソード (2019年)
#   ✓ [ 20] アスクビクターモア (2019年)
#   ✓ [ 21] マッドクール (2019年)
#   ✓ [ 22] サークルオブライフ (2019年)
#   ✓ [ 23] イクイノックス (2019年)
#   ✓ [ 24] サトノレーヴ (2019年)
#   ✓ [ 25] ドライスタウト (2019年)
#
# ✅ 合計25頭を取得しました
# ✅ リストバッチ完了: 25頭追加, 累計50頭
# 📦 リストバッチ: オフセット50, 25頭取得
# 🎯 G1馬取得開始:
#    オフセット: 50
#    最大取得数: 25頭
#    最小生年: 2000年
# --------------------------------------------------
# 📄 開始ページ: 1, ページ内位置: 50
#
# 📄 ページ1を処理中...
#   ✓ [  1] セリフォス (2019年)
#   ✓ [  2] ナミュール (2019年)
#   ✓ [  3] スターズオンアース (2019年)
#   ✓ [  4] ウィルソンテソーロ (2019年)
#   ✓ [  5] ジオグリフ (2019年)
#   ✓ [  6] ダノンスコーピオン (2019年)
#   ✓ [  7] キラーアビリティ (2019年)
#   ✓ [  8] スタニングローズ (2019年)
#   ✓ [  9] ヴァレーデラルナ (2019年)
#   ✓ [ 10] マイネルグロン (2018年)
#   ✓ [ 11] ピクシーナイト (2018年)
#   ✓ [ 12] ジェラルディーナ (2018年)
#   ✓ [ 13] アイコンテーラー (2018年)
#   ✓ [ 14] ペプチドナイル (2018年)
#   ✓ [ 15] キャッスルトップ (2018年)
#   ✓ [ 16] アカイトリノムスメ (2018年)
#   ✓ [ 17] イグナイター (2018年)
#   ✓ [ 18] シャフリヤール (2018年)
#   ✓ [ 19] ジャックドール (2018年)
#   ✓ [ 20] ソウルラッシュ (2018年)
#   ✓ [ 21] シュネルマイスター (2018年)
#   ✓ [ 22] ロマンチックウォリアー (2018年)
#   ✓ [ 23] エフフォーリア (2018年)
#   ✓ [ 24] ソダシ (2018年)
#   ✓ [ 25] テーオーロイヤル (2018年)
#
# ✅ 合計25頭を取得しました
# ✅ リストバッチ完了: 25頭追加, 累計75頭
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[29], line 7
#       4 processor = CompleteBatchProcessor()
#       6 # 100頭で詳細処理をテスト
# ----> 7 batch_results = processor.collect_and_process_horses(
#       8     total_target=100,
#       9     batch_size=25,
#      10     start_offset=0,
#      11     min_birth_year=2000,
#      12     process_details=True,  # 詳細処理有効
#      13     delay_between_horses=3  # 3秒間隔
#      14 )
#      16 print("\n📊 バッチ処理結果:")
#      17 print(f"  リスト取得: {batch_results.get('list_count', 0)}頭")
#
# File ~/Documents/PROJECTS/STALLION/stallion-analytics/packages/ml-analysis/src/scraping/simple_offset_scraper.py:218, in CompleteBatchProcessor.collect_and_process_horses(self, total_target, batch_size, start_offset, min_birth_year, process_details, delay_between_horses)
#     216 # Step 1: 馬リスト取得
#     217 print("🔍 Step 1: 馬リスト取得")
# --> 218 horse_list = self._collect_horse_list(total_target, batch_size, start_offset, min_birth_year)
#     220 if not horse_list:
#     221     return {'error': '馬リスト取得に失敗'}
#
# File ~/Documents/PROJECTS/STALLION/stallion-analytics/packages/ml-analysis/src/scraping/simple_offset_scraper.py:286, in CompleteBatchProcessor._collect_horse_list(self, total_target, batch_size, start_offset, min_birth_year)
#     283     print(f"✅ リストバッチ完了: {len(new_horses)}頭追加, 累計{len(all_horses)}頭")
#     285     if len(all_horses) < total_target:
# --> 286         time.sleep(2)
#     288 return all_horses
#
# KeyboardInterrupt:

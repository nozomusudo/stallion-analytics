# %%
# PostgreSQLからさまざまなデータを取得する

import os
import pandas as pd
import psycopg2
from psycopg2.extras import RealDictCursor
from sqlalchemy import create_engine
from dotenv import load_dotenv
import json
from datetime import datetime

# 環境変数読み込み
load_dotenv()
# Out:
# True

# %%
# =============================================================================
# 1. 接続設定
# =============================================================================

print("🔌 データベース接続を設定中...")

# PostgreSQL接続設定
pg_config = {
    'host': os.getenv('POSTGRES_HOST', 'localhost'),
    'database': os.getenv('POSTGRES_DB', 'stallion_db'),
    'user': os.getenv('POSTGRES_USER', 'stallion_user'),
    'password': os.getenv('POSTGRES_PASSWORD'),
    'port': int(os.getenv('POSTGRES_PORT', '5432'))
}

# SQLAlchemy エンジン作成（pandasで使用）
DATABASE_URL = f"postgresql://{pg_config['user']}:{pg_config['password']}@{pg_config['host']}:{pg_config['port']}/{pg_config['database']}"
engine = create_engine(DATABASE_URL)

print("✅ 接続設定完了")
# Out:
# 🔌 データベース接続を設定中...
# ✅ 接続設定完了

# %%
# =============================================================================
# pandas.read_sql
# =============================================================================

def query(sql):
    """SQLクエリを実行してDataFrameで結果を返す"""
    return pd.read_sql(sql, engine)

def show_tables():
    """全テーブル一覧を表示"""
    sql = "SELECT table_name FROM information_schema.tables WHERE table_schema = 'public';"
    return query(sql)

def desc(table_name):
    """テーブル構造を表示"""
    sql = f"""
    SELECT column_name, data_type, is_nullable, column_default 
    FROM information_schema.columns 
    WHERE table_name = '{table_name}' 
    ORDER BY ordinal_position;
    """
    return query(sql)

def count_all(table_name):
    """テーブルの行数を取得"""
    sql = f"SELECT COUNT(*) as count FROM {table_name};"
    return query(sql).iloc[0, 0]

# %% [markdown]
# ---
# 以下、単発のSQLを実行

# %%
# queryの中にSQLを書いて実行する

query ("""
      
    SELECT
        jockey_name,
        COUNT(*) AS win_count
    FROM race_results
    WHERE finish_position = 1
    GROUP BY jockey_name
    ORDER BY win_count DESC
    LIMIT 20;
      
    """)
# Out:
#    jockey_name  win_count
# 0         ルメール         46
# 1         川田将雅         27
# 2         Ｍ．デム         24
# 3         福永祐一         19
# 4           武豊         18
# 5         岩田康誠         16
# 6         池添謙一         16
# 7         戸崎圭太         12
# 8         蛯名正義         12
# 9         横山典弘          9
# 10        内田博幸          8
# 11         ムーア          8
# 12        北村友一          7
# 13         浜中俊          7
# 14        横山武史          6
# 15         レーン          6
# 16        モレイラ          5
# 17        松山弘平          5
# 18        吉田隼人          5
# 19        Ｃ．デム          5

# %% [markdown]
# ---
# 以下SQL練習 with claude

# %%
query("""
    WITH jockey_horse_wins AS (
        SELECT 
            jockey_name,
            horse_name,
            COUNT(*) as wins_together
        FROM race_results 
        WHERE finish_position = 1
        GROUP BY jockey_name, horse_name
    ),
    ranked_combinations AS (
        SELECT 
            jockey_name,
            horse_name,
            wins_together,
            ROW_NUMBER() OVER (PARTITION BY jockey_name ORDER BY wins_together DESC) as rank
        FROM jockey_horse_wins
    )
    SELECT 
        jockey_name,
        horse_name,
        wins_together
    FROM ranked_combinations
    WHERE rank = 1
    ORDER BY wins_together DESC
    LIMIT 20;
""")
# Out:
#    jockey_name horse_name  wins_together
# 0         ルメール    アーモンドアイ              8
# 1           武豊   キタサンブラック              6
# 2         池添謙一    オルフェーヴル              6
# 3         福永祐一     コントレイル              5
# 4         蛯名正義       アパパネ              4
# 5         川田将雅  リバティアイランド              4
# 6         岩田康誠    ロードカナロア              4
# 7         内田博幸    ゴールドシップ              4
# 8         武幸四郎   メイショウマンボ              3
# 9         松山弘平   デアリングタクト              3
# 10        吉田隼人        ソダシ              3
# 11        北村友一   クロノジェネシス              3
# 12        戸崎圭太   ストレイトガール              3
# 13        横山武史    エフフォーリア              3
# 14         浜中俊    ミッキーアイル              2
# 15         ムーア       モーリス              2
# 16        横山典弘    ゴールドシップ              2
# 17        横山和生    ベラジオオペラ              2
# 18         レーン    リスグラシュー              2
# 19        Ｍ．デム     ドゥラメンテ              2

# %%
# 各競馬場での騎手勝利ランキング
# 各競馬場で最も勝利数の多い騎手TOP3を取得してください

query("""
    
    WITH track_jockey_wins AS (
        SELECT
            r.track_name,
            rr.jockey_name,
            COUNT(*) AS wins
        FROM races r
        JOIN race_results rr ON r.race_id = rr.race_id
        WHERE rr.finish_position = 1
        GROUP BY r.track_name, rr.jockey_name
    ),
    ranked_jockeys AS (
        SELECT
            track_name,
            jockey_name,
            wins,
            ROW_NUMBER() OVER (PARTITION BY track_name ORDER BY wins DESC) AS rank
        FROM track_jockey_wins
    )
    SELECT
        track_name,
        jockey_name,
        wins
    FROM ranked_jockeys
    WHERE rank <= 3
    ORDER BY track_name, rank;
      
""")
# Out:
#    track_name jockey_name  wins
# 0          中京        福永祐一     3
# 1          中京        藤田伸二     3
# 2          中京          武豊     2
# 3         中京1         幸英明     1
# 4          中山          武豊     8
# 5          中山        福永祐一     7
# 6          中山        ルメール     7
# 7          京都          武豊    21
# 8          京都        ルメール    12
# 9          京都        横山典弘     9
# 10         新潟          武豊     1
# 11         新潟        大野拓弥     1
# 12         東京          武豊    25
# 13         東京        ルメール    16
# 14         東京        横山典弘    10
# 15        東京1        ルメール     5
# 16        東京1        川田将雅     3
# 17        東京1        Ｍ．デム     3
# 18         阪神          武豊    11
# 19         阪神        ルメール     9
# 20         阪神        川田将雅     9
# 21        阪神1        福永祐一     1
# 22        阪神1        横山和生     1

# %%
# 17.馬の連続勝利記録
# 各馬の最新5戦の成績（着順）を時系列順で取得してください

query("""
    WITH horse_total_prize AS (
        SELECT 
            id as horse_id,
            name_ja,
            COALESCE((profile->>'total_prize_central')::bigint, 0) as total_prize
        FROM horses
        WHERE profile->>'total_prize_central' IS NOT NULL
    ),
    horse_prize_ranking AS (
        SELECT 
            horse_id,
            name_ja,
            total_prize,
            ROW_NUMBER() OVER (ORDER BY total_prize DESC) as prize_rank
        FROM horse_total_prize
        ORDER BY total_prize DESC
        LIMIT 20
    ),
    latest_5_races_per_horse AS (
        SELECT
            rr.horse_id,
            rr.horse_name,
            r.track_name,
            r.race_name,
            r.race_date,
            rr.finish_position,
            rr.popularity,
            rr.jockey_name,
            ROW_NUMBER() OVER(PARTITION BY rr.horse_id ORDER BY r.race_date DESC) AS race_rank
        FROM race_results rr
        JOIN races r ON rr.race_id = r.race_id
        WHERE rr.finish_position IS NOT NULL
    )
    SELECT
        hpr.prize_rank,
        hpr.name_ja,
        hpr.total_prize,
        lr.track_name,
        lr.race_name,
        lr.race_date,
        lr.finish_position,
        lr.popularity,
        lr.jockey_name,
        lr.race_rank
    FROM horse_prize_ranking hpr
    JOIN latest_5_races_per_horse lr ON hpr.horse_id = lr.horse_id
    WHERE lr.race_rank <= 5
    ORDER BY hpr.prize_rank, lr.race_rank;
""")
# Out:
#     prize_rank   name_ja  total_prize track_name           race_name  \
# 0            1  キタサンブラック       180684         中山        第62回有馬記念(GI)
# 1            1  キタサンブラック       180684         東京     第37回ジャパンカップ(GI)
# 2            1  キタサンブラック       180684         東京     第156回天皇賞(秋)(GI)
# 3            1  キタサンブラック       180684         阪神        第58回宝塚記念(GI)
# 4            1  キタサンブラック       180684         京都     第155回天皇賞(春)(GI)
# ..         ...       ...          ...        ...                 ...
# 95          20   ダイワメジャー       100223         中山        第52回有馬記念(GI)
# 96          20   ダイワメジャー       100223         京都  第24回マイルチャンピオンS(GI)
# 97          20   ダイワメジャー       100223         東京     第136回天皇賞(秋)(GI)
# 98          20   ダイワメジャー       100223         阪神        第48回宝塚記念(GI)
# 99          20   ダイワメジャー       100223         東京        第57回安田記念(GI)
#
#      race_date  finish_position  popularity jockey_name  race_rank
# 0   2017-12-24                1           1          武豊          1
# 1   2017-11-26                3           1          武豊          2
# 2   2017-10-29                1           1          武豊          3
# 3   2017-06-25                9           1          武豊          4
# 4   2017-04-30                1           1          武豊          5
# ..         ...              ...         ...         ...        ...
# 95  2007-12-23                3           6        Ｍデムー          1
# 96  2007-11-18                1           1        安藤勝己          2
# 97  2007-10-28                9           3        安藤勝己          3
# 98  2007-06-24               12           5        安藤勝己          4
# 99  2007-06-03                1           2        安藤勝己          5
#
# [100 rows x 10 columns]

# %%
# 18. レースの人気と着順の関係
# 各レースで人気順位と着順の差を計算してください（大波乱度分析）

query ("""

    WITH upset_analysis AS (
        SELECT
            rr.race_id,
            r.race_name,
            r.race_date,
            rr.horse_name,
            rr.popularity,
            rr.finish_position, 
            rr.popularity - rr.finish_position AS upset_degree,
            ABS(rr.popularity - rr.finish_position) AS upset_magnitude,
            CASE
                WHEN rr.finish_position < rr.popularity THEN '好走'
                WHEN rr.finish_position = rr.popularity THEN '人気通り'
                ELSE '凡走'
            END AS performance_type
        FROM race_results rr
        JOIN races r ON r.race_id = rr.race_id
        WHERE rr.popularity IS NOT NULL
            AND rr.finish_position IS NOT NULL
    )
    SELECT
        *,
        CASE
            WHEN upset_magnitude >= 6 THEN '大波乱'
            WHEN upset_magnitude >= 3 THEN '波乱'
            ELSE '順当'
        END AS upset_level
    FROM upset_analysis
    WHERE upset_analysis.finish_position = 1
    ORDER BY race_date DESC
    LIMIT 50;
       


    """)
# Out:
#          race_id           race_name   race_date   horse_name  popularity  \
# 0   202509030411        第66回宝塚記念(GI)  2025-06-15     メイショウタバル           7
# 1   202505030211        第75回安田記念(GI)  2025-06-08    ジャンタルマンタル           2
# 2   202505021211        第92回東京優駿(GI)  2025-06-01     クロワデュノール           1
# 3   202505021011        第86回優駿牝馬(GI)  2025-05-25       カムニャック           4
# 4   202505020811   第20回ヴィクトリアマイル(GI)  2025-05-18    アスコリピチェーノ           1
# 5   202505020611   第30回NHKマイルカップ(GI)  2025-05-11      パンジャタワー           9
# 6   202508020411     第171回天皇賞(春)(GI)  2025-05-04       ヘデントール           1
# 7   202506030811         第85回皐月賞(GI)  2025-04-20    ミュージアムマイル           3
# 8   202509020611         第85回桜花賞(GI)  2025-04-13     エンブロイダリー           3
# 9   202509020411         第69回大阪杯(GI)  2025-04-06      ベラジオオペラ           2
# 10  202507020611       第55回高松宮記念(GI)  2025-03-30       サトノレーヴ           2
# 11  202406050911  第41回ホープフルステークス(GI)  2024-12-28     クロワデュノール           1
# 12  202406050811        第69回有馬記念(GI)  2024-12-22        レガレイラ           5
# 13  202408070611  第76回朝日フューチュリティ(GI)  2024-12-15     アドマイヤズーム           5
# 14  202408070411   第76回阪神ジュベナイルF(GI)  2024-12-08    アルマヴェローチェ           5
# 15  202405050812     第44回ジャパンカップ(GI)  2024-11-24       ドウデュース           1
# 16  202408060611  第41回マイルチャンピオンS(GI)  2024-11-17      ソウルラッシュ           4
# 17  202408060411    第49回エリザベス女王杯(GI)  2024-11-10     スタニングローズ           3
# 18  202405040811     第170回天皇賞(秋)(GI)  2024-10-27       ドウデュース           2
# 19  202408050611         第85回菊花賞(GI)  2024-10-20      アーバンシック           2
# 20  202408050411         第29回秋華賞(GI)  2024-10-13      チェルヴィニア           1
# 21  202406040911    第58回スプリンターズS(GI)  2024-09-29          ルガル           9
# 22  202408040811        第65回宝塚記念(GI)  2024-06-23      ブローザホーン           3
# 23  202405030211        第74回安田記念(GI)  2024-06-02  ロマンチックウォリアー           1
# 24  202405021211        第91回東京優駿(GI)  2024-05-26      ダノンデサイル           9
# 25  202405021011        第85回優駿牝馬(GI)  2024-05-19      チェルヴィニア           2
# 26  202405020811   第19回ヴィクトリアマイル(GI)  2024-05-12    テンハッピーローズ          14
# 27  202405020611   第29回NHKマイルカップ(GI)  2024-05-05    ジャンタルマンタル           2
# 28  202408030411     第169回天皇賞(春)(GI)  2024-04-28     テーオーロイヤル           1
# 29  202406030811         第84回皐月賞(GI)  2024-04-14    ジャスティンミラノ           2
# 30  202409020611         第84回桜花賞(GI)  2024-04-07     ステレンボッシュ           2
# 31  202409020411         第68回大阪杯(GI)  2024-03-31      ベラジオオペラ           2
# 32  202407010611       第54回高松宮記念(GI)  2024-03-24       マッドクール           6
# 33  202306050911  第40回ホープフルステークス(GI)  2023-12-28        レガレイラ           1
# 34  202306050811        第68回有馬記念(GI)  2023-12-24       ドウデュース           2
# 35  202309050611  第75回朝日フューチュリティ(GI)  2023-12-17    ジャンタルマンタル           1
# 36  202309050411   第75回阪神ジュベナイルF(GI)  2023-12-10    アスコリピチェーノ           3
# 37  202305050812     第43回ジャパンカップ(GI)  2023-11-26      イクイノックス           1
# 38  202308030611  第40回マイルチャンピオンS(GI)  2023-11-19        ナミュール           5
# 39  202308030411    第48回エリザベス女王杯(GI)  2023-11-12    ブレイディヴェーグ           1
# 40  202305040911     第168回天皇賞(秋)(GI)  2023-10-29      イクイノックス           1
# 41  202308020711         第84回菊花賞(GI)  2023-10-22       ドゥレッツァ           4
# 42  202308020511         第28回秋華賞(GI)  2023-10-15    リバティアイランド           1
# 43  202306040911    第57回スプリンターズS(GI)  2023-10-01        ママコチャ           3
# 44  202309030811        第64回宝塚記念(GI)  2023-06-25      イクイノックス           1
# 45  202305030211        第73回安田記念(GI)  2023-06-04       ソングライン           4
# 46  202305021211        第90回東京優駿(GI)  2023-05-28      タスティエーラ           4
# 47  202305021011        第84回優駿牝馬(GI)  2023-05-21    リバティアイランド           1
# 48  202305020811   第18回ヴィクトリアマイル(GI)  2023-05-14       ソングライン           4
# 49  202305020611   第28回NHKマイルカップ(GI)  2023-05-07     シャンパンカラー           9
#
#     finish_position  upset_degree  upset_magnitude performance_type  \
# 0                 1             6                6               好走
# 1                 1             1                1               好走
# 2                 1             0                0             人気通り
# 3                 1             3                3               好走
# 4                 1             0                0             人気通り
# 5                 1             8                8               好走
# 6                 1             0                0             人気通り
# 7                 1             2                2               好走
# 8                 1             2                2               好走
# 9                 1             1                1               好走
# 10                1             1                1               好走
# 11                1             0                0             人気通り
# 12                1             4                4               好走
# 13                1             4                4               好走
# 14                1             4                4               好走
# 15                1             0                0             人気通り
# 16                1             3                3               好走
# 17                1             2                2               好走
# 18                1             1                1               好走
# 19                1             1                1               好走
# 20                1             0                0             人気通り
# 21                1             8                8               好走
# 22                1             2                2               好走
# 23                1             0                0             人気通り
# 24                1             8                8               好走
# 25                1             1                1               好走
# 26                1            13               13               好走
# 27                1             1                1               好走
# 28                1             0                0             人気通り
# 29                1             1                1               好走
# 30                1             1                1               好走
# 31                1             1                1               好走
# 32                1             5                5               好走
# 33                1             0                0             人気通り
# 34                1             1                1               好走
# 35                1             0                0             人気通り
# 36                1             2                2               好走
# 37                1             0                0             人気通り
# 38                1             4                4               好走
# 39                1             0                0             人気通り
# 40                1             0                0             人気通り
# 41                1             3                3               好走
# 42                1             0                0             人気通り
# 43                1             2                2               好走
# 44                1             0                0             人気通り
# 45                1             3                3               好走
# 46                1             3                3               好走
# 47                1             0                0             人気通り
# 48                1             3                3               好走
# 49                1             8                8               好走
#
#    upset_level
# 0          大波乱
# 1           順当
# 2           順当
# 3           波乱
# 4           順当
# 5          大波乱
# 6           順当
# 7           順当
# 8           順当
# 9           順当
# 10          順当
# 11          順当
# 12          波乱
# 13          波乱
# 14          波乱
# 15          順当
# 16          波乱
# 17          順当
# 18          順当
# 19          順当
# 20          順当
# 21         大波乱
# 22          順当
# 23          順当
# 24         大波乱
# 25          順当
# 26         大波乱
# 27          順当
# 28          順当
# 29          順当
# 30          順当
# 31          順当
# 32          波乱
# 33          順当
# 34          順当
# 35          順当
# 36          順当
# 37          順当
# 38          波乱
# 39          順当
# 40          順当
# 41          波乱
# 42          順当
# 43          順当
# 44          順当
# 45          波乱
# 46          波乱
# 47          順当
# 48          波乱
# 49         大波乱

# %%
# 📊 レベル8: 複雑な集計・分析
# 距離適性分析
# 各馬が最も勝率の高い距離帯（1200m以下、1201-1600m、1601-2000m、2001m以上）を判定してください

# 17.馬の連続勝利記録
# 各馬の最新5戦の成績（着順）を時系列順で取得してください

query("""
      
    WITH horse_distance_performance AS (
        SELECT
            rr.horse_id,
            rr.horse_name, 
            CASE
                WHEN r.distance <= 1400 THEN '短距離'
                WHEN r.distance BETWEEN 1401 AND 1800 THEN 'マイル'
                WHEN r.distance BETWEEN 1801 AND 2400 THEN '中距離'
                ELSE '長距離'
            END AS distance_category,
            COUNT (*) AS total_runs,
            COUNT (CASE WHEN rr.finish_position = 1 THEN 1 END) AS wins,
            ROUND (
                (CASE WHEN rr.finish_position = 1 THEN 1 END) * 100.0 / COUNT(*),
                2
            ) AS win_rate
        FROM race_results rr
        JOIN races r ON rr.race_id = r.race_id
        GROUP BY rr.horse_id, distance_category
        HAVING COUNT(*) >= 3
    ),
    best_distance_per_horse AS (
        SELECT
            horse_id,
            horse_name,
            distance_category,
            total_runs,
            wins,
            win_rate,
            ROW_NUMBER() OVER (PARTITION BY horse_id ORDER BY win_rate DESC, toral_runs DESC) AS rank
        FROM horse_distance_performance
    )
    SELECT
        h.name_ja AS horse_name,
        bdph.distance_category AS best_distance,
        bdph.total_runs,
        bdph.wins,
        bdph.win_rate,
        (h.profile->>'total_prize_central')::bigint AS total_prize
    FROM best_distance_per_horse bdph
    JOIN horses h ON bdph.horse_id = h.id
    WHERE bdph.rank = 1
        AND (h.profile->>'total_prize_central') IS NOT NULL
        AND (h.profile->>'total_prize_central')::bigint != '0'
    ORDER BY (h.profile->>'total_prize_central')::BIGINT DESC
    LIMIT 20;
    
""")
# Out:
# ---------------------------------------------------------------------------
# UndefinedFunction                         Traceback (most recent call last)
# File ~/Documents/PROJECTS/STALLION/stallion-analytics/.venv/lib/python3.13/site-packages/sqlalchemy/engine/base.py:1967, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1966     if not evt_handled:
# -> 1967         self.dialect.do_execute(
#    1968             cursor, str_statement, effective_parameters, context
#    1969         )
#    1971 if self._has_events or self.engine._has_events:
#
# File ~/Documents/PROJECTS/STALLION/stallion-analytics/.venv/lib/python3.13/site-packages/sqlalchemy/engine/default.py:951, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     950 def do_execute(self, cursor, statement, parameters, context=None):
# --> 951     cursor.execute(statement, parameters)
#
# UndefinedFunction: operator does not exist: character varying <= integer
# LINE 8:                 WHEN r.distance <= 1400 THEN '短距離'
#                                         ^
# HINT:  No operator matches the given name and argument types. You might need to add explicit type casts.
#
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# Cell In[119], line 8
#       1 # 📊 レベル8: 複雑な集計・分析
#       2 # 距離適性分析
#       3 # 各馬が最も勝率の高い距離帯（1200m以下、1201-1600m、1601-2000m、2001m以上）を判定してください
#       4
#       5 # 17.馬の連続勝利記録
#       6 # 各馬の最新5戦の成績（着順）を時系列順で取得してください
# ----> 8 query("""
#       9
#      10     WITH horse_distance_performance AS (
#      11         SELECT
#      12             rr.horse_id,
#      13             rr.horse_name,
#      14             CASE
#      15                 WHEN r.distance <= 1400 THEN '短距離'
#      16                 WHEN r.distance BETWEEN 1401 AND 1800 THEN 'マイル'
#      17                 WHEN r.distance BETWEEN 1801 AND 2400 THEN '中距離'
#      18                 ELSE '長距離'
#      19             END AS distance_category,
#      20             COUNT (*) AS total_runs,
#      21             COUNT (CASE WHEN rr.finish_position = 1 THEN 1 END) AS wins,
#      22             ROUND (
#      23                 wins * 100.0 / COUNT(*),
#      24                 2
#      25             ) AS win_rate
#      26         FROM race_results rr
#      27         JOIN races r ON rr.race_id = r.race_id
#      28         GROUP BY rr.horse_id, distance_category
#      29         HAVING COUNT(*) >= 3
#      30     ),
#      31     best_distance_per_horse AS (
#      32         SELECT
#      33             horse_id,
#      34             horse_name,
#      35             distance_category,
#      36             total_runs,
#      37             wins,
#      38             win_rate,
#      39             ROW_NUMBER() OVER (PARTITION BY horse_id ORDER BY win_rate DESC, toral_runs DESC) AS rank
#      40         FROM horse_distance_performance
#      41     )
#      42     SELECT
#      43         h.name_ja AS horse_name,
#      44         bdph.distance_category AS best_distance,
#      45         bdph.total_runs,
#      46         bdph.wins,
#      47         bdph.win_rate,
#      48         (h.profile->>'total_prize_central')::bigint AS total_prize
#      49     FROM best_distance_per_horse bdph
#      50     JOIN horses h ON bdph.horse_id = h.id
#      51     WHERE bdph.rank = 1
#      52         AND (h.profile->>'total_prize_central') IS NOT NULL
#      53         AND (h.profile->>'total_prize_central')::bigint != '0'
#      54     ORDER BY (h.profile->>'total_prize_central')::BIGINT DESC
#      55     LIMIT 20;
#      56
#      57 """)
#
# Cell In[8], line 7, in query(sql)
#       5 def query(sql):
#       6     """SQLクエリを実行してDataFrameで結果を返す"""
# ----> 7     return pd.read_sql(sql, engine)
#
# File ~/Documents/PROJECTS/STALLION/stallion-analytics/.venv/lib/python3.13/site-packages/pandas/io/sql.py:736, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     726     return pandas_sql.read_table(
#     727         sql,
#     728         index_col=index_col,
#    (...)    733         dtype_backend=dtype_backend,
#     734     )
#     735 else:
# --> 736     return pandas_sql.read_query(
#     737         sql,
#     738         index_col=index_col,
#     739         params=params,
#     740         coerce_float=coerce_float,
#     741         parse_dates=parse_dates,
#     742         chunksize=chunksize,
#     743         dtype_backend=dtype_backend,
#     744         dtype=dtype,
#     745     )
#
# File ~/Documents/PROJECTS/STALLION/stallion-analytics/.venv/lib/python3.13/site-packages/pandas/io/sql.py:1848, in SQLDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    1791 def read_query(
#    1792     self,
#    1793     sql: str,
#    (...)   1800     dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    1801 ) -> DataFrame | Iterator[DataFrame]:
#    1802     """
#    1803     Read SQL query into a DataFrame.
#    1804
#    (...)   1846
#    1847     """
# -> 1848     result = self.execute(sql, params)
#    1849     columns = result.keys()
#    1851     if chunksize is not None:
#
# File ~/Documents/PROJECTS/STALLION/stallion-analytics/.venv/lib/python3.13/site-packages/pandas/io/sql.py:1671, in SQLDatabase.execute(self, sql, params)
#    1669 args = [] if params is None else [params]
#    1670 if isinstance(sql, str):
# -> 1671     return self.con.exec_driver_sql(sql, *args)
#    1672 return self.con.execute(sql, *args)
#
# File ~/Documents/PROJECTS/STALLION/stallion-analytics/.venv/lib/python3.13/site-packages/sqlalchemy/engine/base.py:1779, in Connection.exec_driver_sql(self, statement, parameters, execution_options)
#    1774 execution_options = self._execution_options.merge_with(
#    1775     execution_options
#    1776 )
#    1778 dialect = self.dialect
# -> 1779 ret = self._execute_context(
#    1780     dialect,
#    1781     dialect.execution_ctx_cls._init_statement,
#    1782     statement,
#    1783     None,
#    1784     execution_options,
#    1785     statement,
#    1786     distilled_parameters,
#    1787 )
#    1789 return ret
#
# File ~/Documents/PROJECTS/STALLION/stallion-analytics/.venv/lib/python3.13/site-packages/sqlalchemy/engine/base.py:1846, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1844     return self._exec_insertmany_context(dialect, context)
#    1845 else:
# -> 1846     return self._exec_single_context(
#    1847         dialect, context, statement, parameters
#    1848     )
#
# File ~/Documents/PROJECTS/STALLION/stallion-analytics/.venv/lib/python3.13/site-packages/sqlalchemy/engine/base.py:1986, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1983     result = context._setup_result_proxy()
#    1985 except BaseException as e:
# -> 1986     self._handle_dbapi_exception(
#    1987         e, str_statement, effective_parameters, cursor, context
#    1988     )
#    1990 return result
#
# File ~/Documents/PROJECTS/STALLION/stallion-analytics/.venv/lib/python3.13/site-packages/sqlalchemy/engine/base.py:2355, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2353 elif should_wrap:
#    2354     assert sqlalchemy_exception is not None
# -> 2355     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2356 else:
#    2357     assert exc_info[1] is not None
#
# File ~/Documents/PROJECTS/STALLION/stallion-analytics/.venv/lib/python3.13/site-packages/sqlalchemy/engine/base.py:1967, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1965                 break
#    1966     if not evt_handled:
# -> 1967         self.dialect.do_execute(
#    1968             cursor, str_statement, effective_parameters, context
#    1969         )
#    1971 if self._has_events or self.engine._has_events:
#    1972     self.dispatch.after_cursor_execute(
#    1973         self,
#    1974         cursor,
#    (...)   1978         context.executemany,
#    1979     )
#
# File ~/Documents/PROJECTS/STALLION/stallion-analytics/.venv/lib/python3.13/site-packages/sqlalchemy/engine/default.py:951, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     950 def do_execute(self, cursor, statement, parameters, context=None):
# --> 951     cursor.execute(statement, parameters)
#
# ProgrammingError: (psycopg2.errors.UndefinedFunction) operator does not exist: character varying <= integer
# LINE 8:                 WHEN r.distance <= 1400 THEN '短距離'
#                                         ^
# HINT:  No operator matches the given name and argument types. You might need to add explicit type casts.
#
# [SQL:
#
#     WITH horse_distance_performance AS (
#         SELECT
#             rr.horse_id,
#             rr.horse_name,
#             CASE
#                 WHEN r.distance <= 1400 THEN '短距離'
#                 WHEN r.distance BETWEEN 1401 AND 1800 THEN 'マイル'
#                 WHEN r.distance BETWEEN 1801 AND 2400 THEN '中距離'
#                 ELSE '長距離'
#             END AS distance_category,
#             COUNT (*) AS total_runs,
#             COUNT (CASE WHEN rr.finish_position = 1 THEN 1 END) AS wins,
#             ROUND (
#                 wins * 100.0 / COUNT(*),
#                 2
#             ) AS win_rate
#         FROM race_results rr
#         JOIN races r ON rr.race_id = r.race_id
#         GROUP BY rr.horse_id, distance_category
#         HAVING COUNT(*) >= 3
#     ),
#     best_distance_per_horse AS (
#         SELECT
#             horse_id,
#             horse_name,
#             distance_category,
#             total_runs,
#             wins,
#             win_rate,
#             ROW_NUMBER() OVER (PARTITION BY horse_id ORDER BY win_rate DESC, toral_runs DESC) AS rank
#         FROM horse_distance_performance
#     )
#     SELECT
#         h.name_ja AS horse_name,
#         bdph.distance_category AS best_distance,
#         bdph.total_runs,
#         bdph.wins,
#         bdph.win_rate,
#         (h.profile->>'total_prize_central')::bigint AS total_prize
#     FROM best_distance_per_horse bdph
#     JOIN horses h ON bdph.horse_id = h.id
#     WHERE bdph.rank = 1
#         AND (h.profile->>'total_prize_central') IS NOT NULL
#         AND (h.profile->>'total_prize_central')::bigint != '0'
#     ORDER BY (h.profile->>'total_prize_central')::BIGINT DESC
#     LIMIT 20;
#
# ]
# (Background on this error at: https://sqlalche.me/e/20/f405)

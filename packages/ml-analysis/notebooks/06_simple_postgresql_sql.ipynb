# %%
# PostgreSQLからさまざまなデータを取得する

import os
import pandas as pd
import psycopg2
from psycopg2.extras import RealDictCursor
from sqlalchemy import create_engine
from dotenv import load_dotenv
import json
from datetime import datetime

# 環境変数読み込み
load_dotenv()
# Out:
# True

# %%
# =============================================================================
# 1. 接続設定
# =============================================================================

print("🔌 データベース接続を設定中...")

# PostgreSQL接続設定
pg_config = {
    'host': os.getenv('POSTGRES_HOST', 'localhost'),
    'database': os.getenv('POSTGRES_DB', 'stallion_db'),
    'user': os.getenv('POSTGRES_USER', 'stallion_user'),
    'password': os.getenv('POSTGRES_PASSWORD'),
    'port': int(os.getenv('POSTGRES_PORT', '5432'))
}

# SQLAlchemy エンジン作成（pandasで使用）
DATABASE_URL = f"postgresql://{pg_config['user']}:{pg_config['password']}@{pg_config['host']}:{pg_config['port']}/{pg_config['database']}"
engine = create_engine(DATABASE_URL)

print("✅ 接続設定完了")
# Out:
# 🔌 データベース接続を設定中...
# ✅ 接続設定完了

# %%
# =============================================================================
# pandas.read_sql
# =============================================================================

def query(sql):
    """SQLクエリを実行してDataFrameで結果を返す"""
    return pd.read_sql(sql, engine)

def show_tables():
    """全テーブル一覧を表示"""
    sql = "SELECT table_name FROM information_schema.tables WHERE table_schema = 'public';"
    return query(sql)

def desc(table_name):
    """テーブル構造を表示"""
    sql = f"""
    SELECT column_name, data_type, is_nullable, column_default 
    FROM information_schema.columns 
    WHERE table_name = '{table_name}' 
    ORDER BY ordinal_position;
    """
    return query(sql)

def count_all(table_name):
    """テーブルの行数を取得"""
    sql = f"SELECT COUNT(*) as count FROM {table_name};"
    return query(sql).iloc[0, 0]

# %% [markdown]
# ---
# 以下、単発のSQLを実行

# %%
# queryの中にSQLを書いて実行する

query ("""
      
    SELECT
        jockey_name,
        COUNT(*) AS win_count
    FROM race_results
    WHERE finish_position = 1
    GROUP BY jockey_name
    ORDER BY win_count DESC
    LIMIT 20;
      
    """)
# Out:
#    jockey_name  win_count
# 0         ルメール         46
# 1         川田将雅         27
# 2         Ｍ．デム         24
# 3         福永祐一         19
# 4           武豊         18
# 5         岩田康誠         16
# 6         池添謙一         16
# 7         戸崎圭太         12
# 8         蛯名正義         12
# 9         横山典弘          9
# 10        内田博幸          8
# 11         ムーア          8
# 12        北村友一          7
# 13         浜中俊          7
# 14        横山武史          6
# 15         レーン          6
# 16        モレイラ          5
# 17        松山弘平          5
# 18        吉田隼人          5
# 19        Ｃ．デム          5

# %% [markdown]
# ---
# 以下SQL練習 with claude

# %%
query("""
    WITH jockey_horse_wins AS (
        SELECT 
            jockey_name,
            horse_name,
            COUNT(*) as wins_together
        FROM race_results 
        WHERE finish_position = 1
        GROUP BY jockey_name, horse_name
    ),
    ranked_combinations AS (
        SELECT 
            jockey_name,
            horse_name,
            wins_together,
            ROW_NUMBER() OVER (PARTITION BY jockey_name ORDER BY wins_together DESC) as rank
        FROM jockey_horse_wins
    )
    SELECT 
        jockey_name,
        horse_name,
        wins_together
    FROM ranked_combinations
    WHERE rank = 1
    ORDER BY wins_together DESC
    LIMIT 20;
""")
# Out:
#    jockey_name horse_name  wins_together
# 0         ルメール    アーモンドアイ              8
# 1           武豊   キタサンブラック              6
# 2         池添謙一    オルフェーヴル              6
# 3         福永祐一     コントレイル              5
# 4         蛯名正義       アパパネ              4
# 5         川田将雅  リバティアイランド              4
# 6         岩田康誠    ロードカナロア              4
# 7         内田博幸    ゴールドシップ              4
# 8         武幸四郎   メイショウマンボ              3
# 9         松山弘平   デアリングタクト              3
# 10        吉田隼人        ソダシ              3
# 11        北村友一   クロノジェネシス              3
# 12        戸崎圭太   ストレイトガール              3
# 13        横山武史    エフフォーリア              3
# 14         浜中俊    ミッキーアイル              2
# 15         ムーア       モーリス              2
# 16        横山典弘    ゴールドシップ              2
# 17        横山和生    ベラジオオペラ              2
# 18         レーン    リスグラシュー              2
# 19        Ｍ．デム     ドゥラメンテ              2

# %%
# 各競馬場での騎手勝利ランキング
# 各競馬場で最も勝利数の多い騎手TOP3を取得してください

query("""
    
    WITH track_jockey_wins AS (
        SELECT
            r.track_name,
            rr.jockey_name,
            COUNT(*) AS wins
        FROM races r
        JOIN race_results rr ON r.race_id = rr.race_id
        WHERE rr.finish_position = 1
        GROUP BY r.track_name, rr.jockey_name
    ),
    ranked_jockeys AS (
        SELECT
            track_name,
            jockey_name,
            wins,
            ROW_NUMBER() OVER (PARTITION BY track_name ORDER BY wins DESC) AS rank
        FROM track_jockey_wins
    )
    SELECT
        track_name,
        jockey_name,
        wins
    FROM ranked_jockeys
    WHERE rank <= 3
    ORDER BY track_name, rank;
      
""")
# Out:
#    track_name jockey_name  wins
# 0          中京        福永祐一     3
# 1          中京        藤田伸二     3
# 2          中京          武豊     2
# 3         中京1         幸英明     1
# 4          中山          武豊     8
# 5          中山        福永祐一     7
# 6          中山        ルメール     7
# 7          京都          武豊    21
# 8          京都        ルメール    12
# 9          京都        横山典弘     9
# 10         新潟          武豊     1
# 11         新潟        大野拓弥     1
# 12         東京          武豊    25
# 13         東京        ルメール    16
# 14         東京        横山典弘    10
# 15        東京1        ルメール     5
# 16        東京1        川田将雅     3
# 17        東京1        Ｍ．デム     3
# 18         阪神          武豊    11
# 19         阪神        ルメール     9
# 20         阪神        川田将雅     9
# 21        阪神1        福永祐一     1
# 22        阪神1        横山和生     1

# %%
# 17.馬の連続勝利記録
# 各馬の最新5戦の成績（着順）を時系列順で取得してください

query("""
    WITH horse_total_prize AS (
        SELECT 
            id as horse_id,
            name_ja,
            COALESCE((profile->>'total_prize_central')::bigint, 0) as total_prize
        FROM horses
        WHERE profile->>'total_prize_central' IS NOT NULL
    ),
    horse_prize_ranking AS (
        SELECT 
            horse_id,
            name_ja,
            total_prize,
            ROW_NUMBER() OVER (ORDER BY total_prize DESC) as prize_rank
        FROM horse_total_prize
        ORDER BY total_prize DESC
        LIMIT 20
    ),
    latest_5_races_per_horse AS (
        SELECT
            rr.horse_id,
            rr.horse_name,
            r.track_name,
            r.race_name,
            r.race_date,
            rr.finish_position,
            rr.popularity,
            rr.jockey_name,
            ROW_NUMBER() OVER(PARTITION BY rr.horse_id ORDER BY r.race_date DESC) AS race_rank
        FROM race_results rr
        JOIN races r ON rr.race_id = r.race_id
        WHERE rr.finish_position IS NOT NULL
    )
    SELECT
        hpr.prize_rank,
        hpr.name_ja,
        hpr.total_prize,
        lr.track_name,
        lr.race_name,
        lr.race_date,
        lr.finish_position,
        lr.popularity,
        lr.jockey_name,
        lr.race_rank
    FROM horse_prize_ranking hpr
    JOIN latest_5_races_per_horse lr ON hpr.horse_id = lr.horse_id
    WHERE lr.race_rank <= 5
    ORDER BY hpr.prize_rank, lr.race_rank;
""")
# Out:
#     prize_rank   name_ja  total_prize track_name           race_name  \
# 0            1  キタサンブラック       180684         中山        第62回有馬記念(GI)
# 1            1  キタサンブラック       180684         東京     第37回ジャパンカップ(GI)
# 2            1  キタサンブラック       180684         東京     第156回天皇賞(秋)(GI)
# 3            1  キタサンブラック       180684         阪神        第58回宝塚記念(GI)
# 4            1  キタサンブラック       180684         京都     第155回天皇賞(春)(GI)
# ..         ...       ...          ...        ...                 ...
# 95          20   ダイワメジャー       100223         中山        第52回有馬記念(GI)
# 96          20   ダイワメジャー       100223         京都  第24回マイルチャンピオンS(GI)
# 97          20   ダイワメジャー       100223         東京     第136回天皇賞(秋)(GI)
# 98          20   ダイワメジャー       100223         阪神        第48回宝塚記念(GI)
# 99          20   ダイワメジャー       100223         東京        第57回安田記念(GI)
#
#      race_date  finish_position  popularity jockey_name  race_rank
# 0   2017-12-24                1           1          武豊          1
# 1   2017-11-26                3           1          武豊          2
# 2   2017-10-29                1           1          武豊          3
# 3   2017-06-25                9           1          武豊          4
# 4   2017-04-30                1           1          武豊          5
# ..         ...              ...         ...         ...        ...
# 95  2007-12-23                3           6        Ｍデムー          1
# 96  2007-11-18                1           1        安藤勝己          2
# 97  2007-10-28                9           3        安藤勝己          3
# 98  2007-06-24               12           5        安藤勝己          4
# 99  2007-06-03                1           2        安藤勝己          5
#
# [100 rows x 10 columns]

# %%
# 18. レースの人気と着順の関係
# 各レースで人気順位と着順の差を計算してください（大波乱度分析）

query ("""

    WITH upset_analysis AS (
        SELECT
            rr.race_id,
            r.race_name,
            r.race_date,
            rr.horse_name,
            rr.popularity,
            rr.finish_position, 
            rr.popularity - rr.finish_position AS upset_degree,
            ABS(rr.popularity - rr.finish_position) AS upset_magnitude,
            CASE
                WHEN rr.finish_position < rr.popularity THEN '好走'
                WHEN rr.finish_position = rr.popularity THEN '人気通り'
                ELSE '凡走'
            END AS performance_type
        FROM race_results rr
        JOIN races r ON r.race_id = rr.race_id
        WHERE rr.popularity IS NOT NULL
            AND rr.finish_position IS NOT NULL
    )
    SELECT
        *,
        CASE
            WHEN upset_magnitude >= 6 THEN '大波乱'
            WHEN upset_magnitude >= 3 THEN '波乱'
            ELSE '順当'
        END AS upset_level
    FROM upset_analysis
    WHERE upset_analysis.finish_position = 1
    ORDER BY race_date DESC
    LIMIT 50;
       


    """)
# Out:
#          race_id           race_name   race_date   horse_name  popularity  \
# 0   202509030411        第66回宝塚記念(GI)  2025-06-15     メイショウタバル           7
# 1   202505030211        第75回安田記念(GI)  2025-06-08    ジャンタルマンタル           2
# 2   202505021211        第92回東京優駿(GI)  2025-06-01     クロワデュノール           1
# 3   202505021011        第86回優駿牝馬(GI)  2025-05-25       カムニャック           4
# 4   202505020811   第20回ヴィクトリアマイル(GI)  2025-05-18    アスコリピチェーノ           1
# 5   202505020611   第30回NHKマイルカップ(GI)  2025-05-11      パンジャタワー           9
# 6   202508020411     第171回天皇賞(春)(GI)  2025-05-04       ヘデントール           1
# 7   202506030811         第85回皐月賞(GI)  2025-04-20    ミュージアムマイル           3
# 8   202509020611         第85回桜花賞(GI)  2025-04-13     エンブロイダリー           3
# 9   202509020411         第69回大阪杯(GI)  2025-04-06      ベラジオオペラ           2
# 10  202507020611       第55回高松宮記念(GI)  2025-03-30       サトノレーヴ           2
# 11  202406050911  第41回ホープフルステークス(GI)  2024-12-28     クロワデュノール           1
# 12  202406050811        第69回有馬記念(GI)  2024-12-22        レガレイラ           5
# 13  202408070611  第76回朝日フューチュリティ(GI)  2024-12-15     アドマイヤズーム           5
# 14  202408070411   第76回阪神ジュベナイルF(GI)  2024-12-08    アルマヴェローチェ           5
# 15  202405050812     第44回ジャパンカップ(GI)  2024-11-24       ドウデュース           1
# 16  202408060611  第41回マイルチャンピオンS(GI)  2024-11-17      ソウルラッシュ           4
# 17  202408060411    第49回エリザベス女王杯(GI)  2024-11-10     スタニングローズ           3
# 18  202405040811     第170回天皇賞(秋)(GI)  2024-10-27       ドウデュース           2
# 19  202408050611         第85回菊花賞(GI)  2024-10-20      アーバンシック           2
# 20  202408050411         第29回秋華賞(GI)  2024-10-13      チェルヴィニア           1
# 21  202406040911    第58回スプリンターズS(GI)  2024-09-29          ルガル           9
# 22  202408040811        第65回宝塚記念(GI)  2024-06-23      ブローザホーン           3
# 23  202405030211        第74回安田記念(GI)  2024-06-02  ロマンチックウォリアー           1
# 24  202405021211        第91回東京優駿(GI)  2024-05-26      ダノンデサイル           9
# 25  202405021011        第85回優駿牝馬(GI)  2024-05-19      チェルヴィニア           2
# 26  202405020811   第19回ヴィクトリアマイル(GI)  2024-05-12    テンハッピーローズ          14
# 27  202405020611   第29回NHKマイルカップ(GI)  2024-05-05    ジャンタルマンタル           2
# 28  202408030411     第169回天皇賞(春)(GI)  2024-04-28     テーオーロイヤル           1
# 29  202406030811         第84回皐月賞(GI)  2024-04-14    ジャスティンミラノ           2
# 30  202409020611         第84回桜花賞(GI)  2024-04-07     ステレンボッシュ           2
# 31  202409020411         第68回大阪杯(GI)  2024-03-31      ベラジオオペラ           2
# 32  202407010611       第54回高松宮記念(GI)  2024-03-24       マッドクール           6
# 33  202306050911  第40回ホープフルステークス(GI)  2023-12-28        レガレイラ           1
# 34  202306050811        第68回有馬記念(GI)  2023-12-24       ドウデュース           2
# 35  202309050611  第75回朝日フューチュリティ(GI)  2023-12-17    ジャンタルマンタル           1
# 36  202309050411   第75回阪神ジュベナイルF(GI)  2023-12-10    アスコリピチェーノ           3
# 37  202305050812     第43回ジャパンカップ(GI)  2023-11-26      イクイノックス           1
# 38  202308030611  第40回マイルチャンピオンS(GI)  2023-11-19        ナミュール           5
# 39  202308030411    第48回エリザベス女王杯(GI)  2023-11-12    ブレイディヴェーグ           1
# 40  202305040911     第168回天皇賞(秋)(GI)  2023-10-29      イクイノックス           1
# 41  202308020711         第84回菊花賞(GI)  2023-10-22       ドゥレッツァ           4
# 42  202308020511         第28回秋華賞(GI)  2023-10-15    リバティアイランド           1
# 43  202306040911    第57回スプリンターズS(GI)  2023-10-01        ママコチャ           3
# 44  202309030811        第64回宝塚記念(GI)  2023-06-25      イクイノックス           1
# 45  202305030211        第73回安田記念(GI)  2023-06-04       ソングライン           4
# 46  202305021211        第90回東京優駿(GI)  2023-05-28      タスティエーラ           4
# 47  202305021011        第84回優駿牝馬(GI)  2023-05-21    リバティアイランド           1
# 48  202305020811   第18回ヴィクトリアマイル(GI)  2023-05-14       ソングライン           4
# 49  202305020611   第28回NHKマイルカップ(GI)  2023-05-07     シャンパンカラー           9
#
#     finish_position  upset_degree  upset_magnitude performance_type  \
# 0                 1             6                6               好走
# 1                 1             1                1               好走
# 2                 1             0                0             人気通り
# 3                 1             3                3               好走
# 4                 1             0                0             人気通り
# 5                 1             8                8               好走
# 6                 1             0                0             人気通り
# 7                 1             2                2               好走
# 8                 1             2                2               好走
# 9                 1             1                1               好走
# 10                1             1                1               好走
# 11                1             0                0             人気通り
# 12                1             4                4               好走
# 13                1             4                4               好走
# 14                1             4                4               好走
# 15                1             0                0             人気通り
# 16                1             3                3               好走
# 17                1             2                2               好走
# 18                1             1                1               好走
# 19                1             1                1               好走
# 20                1             0                0             人気通り
# 21                1             8                8               好走
# 22                1             2                2               好走
# 23                1             0                0             人気通り
# 24                1             8                8               好走
# 25                1             1                1               好走
# 26                1            13               13               好走
# 27                1             1                1               好走
# 28                1             0                0             人気通り
# 29                1             1                1               好走
# 30                1             1                1               好走
# 31                1             1                1               好走
# 32                1             5                5               好走
# 33                1             0                0             人気通り
# 34                1             1                1               好走
# 35                1             0                0             人気通り
# 36                1             2                2               好走
# 37                1             0                0             人気通り
# 38                1             4                4               好走
# 39                1             0                0             人気通り
# 40                1             0                0             人気通り
# 41                1             3                3               好走
# 42                1             0                0             人気通り
# 43                1             2                2               好走
# 44                1             0                0             人気通り
# 45                1             3                3               好走
# 46                1             3                3               好走
# 47                1             0                0             人気通り
# 48                1             3                3               好走
# 49                1             8                8               好走
#
#    upset_level
# 0          大波乱
# 1           順当
# 2           順当
# 3           波乱
# 4           順当
# 5          大波乱
# 6           順当
# 7           順当
# 8           順当
# 9           順当
# 10          順当
# 11          順当
# 12          波乱
# 13          波乱
# 14          波乱
# 15          順当
# 16          波乱
# 17          順当
# 18          順当
# 19          順当
# 20          順当
# 21         大波乱
# 22          順当
# 23          順当
# 24         大波乱
# 25          順当
# 26         大波乱
# 27          順当
# 28          順当
# 29          順当
# 30          順当
# 31          順当
# 32          波乱
# 33          順当
# 34          順当
# 35          順当
# 36          順当
# 37          順当
# 38          波乱
# 39          順当
# 40          順当
# 41          波乱
# 42          順当
# 43          順当
# 44          順当
# 45          波乱
# 46          波乱
# 47          順当
# 48          波乱
# 49         大波乱

# %%
# 📊 レベル8: 複雑な集計・分析
# 距離適性分析
# 各馬が最も勝率の高い距離帯（1200m以下、1201-1600m、1601-2000m、2001m以上）を判定してください

# 17.馬の連続勝利記録
# 各馬の最新5戦の成績（着順）を時系列順で取得してください

query("""
      
    WITH horse_distance_performance AS (
        SELECT
            rr.horse_id,
            rr.horse_name, 
            CASE
                WHEN r.distance::INTEGER <= 1400 THEN '短距離'
                WHEN r.distance::INTEGER <= 1800 THEN 'マイル'
                WHEN r.distance::INTEGER <= 2400 THEN '中距離'
                ELSE '長距離'
            END AS distance_category,
            COUNT (*) AS total_runs,
            COUNT (CASE WHEN rr.finish_position = 1 THEN 1 END) AS wins,
            ROUND (
                COUNT(CASE WHEN rr.finish_position = 1 THEN 1 END) * 100.0 / COUNT(*),
                2
            ) AS win_rate
        FROM race_results rr
        JOIN races r ON rr.race_id = r.race_id
        GROUP BY rr.horse_id, rr.horse_name, distance_category
        HAVING COUNT(*) >= 3
    ),
    best_distance_per_horse AS (
        SELECT
            horse_id,
            horse_name,
            distance_category,
            total_runs,
            wins,
            win_rate,
            ROW_NUMBER() OVER (PARTITION BY horse_id ORDER BY win_rate DESC, total_runs DESC) AS rank
        FROM horse_distance_performance
    )
    SELECT
        h.name_ja AS horse_name,
        bdph.distance_category AS best_distance,
        bdph.total_runs,
        bdph.wins,
        bdph.win_rate,
        CONCAT((h.profile->>'total_prize_central')::bigint, '円') AS total_prize
    FROM best_distance_per_horse bdph
    JOIN horses h ON bdph.horse_id = h.id
    WHERE bdph.rank = 1
        AND (h.profile->>'total_prize_central') IS NOT NULL
        AND (h.profile->>'total_prize_central')::bigint != '0'
    ORDER BY (h.profile->>'total_prize_central')::BIGINT DESC
    LIMIT 20;
    
""")
# Out:
#    horse_name best_distance  total_runs  wins  win_rate total_prize
# 0    キタサンブラック           長距離           6     4     66.67     180684円
# 1   テイエムオペラオー           中距離          14     8     57.14     180518円
# 2     イクイノックス           中距離           6     4     66.67     170655円
# 3      ドウデュース           中距離           9     4     44.44     170347円
# 4     アーモンドアイ           中距離           6     6    100.00     150956円
# 5   ディープインパクト           中距離           6     6    100.00     140455円
# 6     ゴールドシップ           長距離          11     6     54.55     130776円
# 7      ブエナビスタ           マイル           5     4     80.00     130643円
# 8   ジェンティルドンナ           マイル           4     3     75.00     130621円
# 9        ウオッカ           マイル           9     5     55.56     130487円
# 10    オルフェーヴル           中距離           6     5     83.33     130408円
# 11    ゼンノロブロイ           中距離          10     4     40.00     110560円
# 12     コントレイル           中距離           8     5     62.50     110529円
# 13   クロノジェネシス           中距離           8     4     50.00     110171円
# 14   タイトルホルダー           長距離           7     3     42.86     100875円
# 15  メイショウサムソン           中距離          11     4     36.36     100594円
# 16  タップダンスシチー           中距離          15     7     46.67     100422円
# 17   グランアレグリア           マイル           9     6     66.67     100381円
# 18  スペシャルウィーク           中距離          10     6     60.00     100262円
# 19    ダイワメジャー           マイル          14     6     42.86     100223円

# %%
# 20. 騎手×馬×競馬場の最強組み合わせ
# 騎手・馬・競馬場の3要素の組み合わせで最も勝率の高いTOP10を取得してください

query ("""

    WITH jockey_horse_track_performance AS (
        SELECT
            rr.jockey_name,
            rr.horse_id,
            r.track_name,
            COUNT(*) AS total_runs,
            COUNT(CASE WHEN finish_position = 1 THEN 1 END) AS wins,
            COUNT(CASE WHEN finish_position = 1 THEN 1 END) * 100.0 / COUNT(*) AS win_rate
        FROM race_results rr
        JOIN races r ON r.race_id = rr.race_id
        WHERE jockey_name IS NOT NULL AND horse_id IS NOT NULL AND track_name IS NOT NULL
        GROUP BY rr.jockey_name, rr.horse_id, r.track_name
        HAVING COUNT(*) >= 3
        )
    SELECT
        h.name_ja AS horse_name,
        (h.profile->>'total_prize_central')::bigint AS total_prize,
        jhtp.jockey_name,
        jhtp.track_name,
        jhtp.total_runs,
        jhtp.wins,
        ROUND(jhtp.win_rate, 2) AS win_rate
    FROM jockey_horse_track_performance AS jhtp
    JOIN horses h ON jhtp.horse_id = h.id
    WHERE (h.profile->>'total_prize_central') IS NOT NULL
        AND (h.profile->>'total_prize_central')::bigint != '0'
        AND win_rate >= 30.0
    ORDER BY win_rate DESC, (h.profile->>'total_prize_central')::bigint DESC
       
""")
# Out:
#    horse_name  total_prize jockey_name track_name  total_runs  wins  win_rate
# 0     イクイノックス       170655        ルメール         東京           3     3    100.00
# 1   ディープインパクト       140455          武豊         京都           3     3    100.00
# 2   スペシャルウィーク       100262          武豊         東京           3     3    100.00
# 3    ナリタブライアン        90742        南井克巳         中山           3     3    100.00
# 4     フィエールマン        70926        ルメール         京都           3     3    100.00
# ..        ...          ...         ...        ...         ...   ...       ...
# 83   エルウェーウィン        20560        南井克巳         中山           3     1     33.33
# 84   マイネルマックス        20279        佐藤哲三         中山           3     1     33.33
# 85      アカイイト        20002         幸英明         阪神           3     1     33.33
# 86   シャンパンカラー        10548        内田博幸         東京           3     1     33.33
# 87   ブゼンキャンドル        10365        安田康彦         京都           3     1     33.33
#
# [88 rows x 7 columns]

# %%
# 🏆 重賞データ分析 - 本格難易度問題集
# 📊 問題1: 時代変遷分析
# 各年代（1990年代、2000年代、2010年代、2020年代）で最も活躍した上位3騎手を特定し、時代を通じて一貫して活躍している騎手を分析してください。
# 条件：
# G1-G3重賞での勝利数で評価
# 各年代で最低10勝以上
# 4つすべての年代にランクインした騎手がいるかチェック

query ("""

    WITH decade_jockey_in_board AS (
       SELECT
            rr.jockey_name,
            rr.horse_name,
            r.track_name,
            rr.finish_position,
            r.grade,
            r.race_date,
            EXTRACT(YEAR FROM r.race_date) AS race_year,
            CASE
                WHEN EXTRACT(YEAR FROM r.race_date) BETWEEN 1990 AND 1999 THEN '1990s'
                WHEN EXTRACT(YEAR FROM r.race_date) BETWEEN 2000 AND 2009 THEN '2000s'
                WHEN EXTRACT(YEAR FROM r.race_date) BETWEEN 2010 AND 2019 THEN '2010s'
                WHEN EXTRACT(YEAR FROM r.race_date) BETWEEN 2020 AND 2029 THEN '2020s'
                ELSE 'その他'
            END AS decade
       FROM race_results rr
       JOIN races r ON rr.race_id = r.race_id
       WHERE rr.finish_position <= 5
    ),
    decade_jockey_points AS (
        SELECT
            jockey_name,
            decade,
            COUNT(*) AS top5_finishes,
            SUM(CASE WHEN finish_position = 1 THEN 10
                     WHEN finish_position = 2 THEN 7
                     WHEN finish_position = 3 THEN 4
                     WHEN finish_position = 4 THEN 2
                     WHEN finish_position = 5 THEN 1
                     ELSE 0 END) 
                AS finish_position_points,
            SUM(CASE WHEN grade = 'G1' THEN 5
                     WHEN grade = 'G2' THEN 2
                     WHEN grade = 'G3' THEN 1
                     ELSE 0 END) 
                AS grade_points
        FROM decade_jockey_in_board
        WHERE decade != 'その他'
        GROUP BY jockey_name, decade
    ),
    ranked_jockeys AS (
        SELECT
            jockey_name,
            decade,
            top5_finishes,
            finish_position_points,
            grade_points,
            grade_points * finish_position_points AS total_points,
            ROW_NUMBER() OVER (PARTITION BY decade ORDER BY grade_points * finish_position_points DESC) AS rank
        FROM decade_jockey_points
        WHERE top5_finishes >= 10
        ORDER BY decade, finish_position_points DESC, grade_points DESC
    )
    SELECT
        decade,
        rank,
        jockey_name,
        top5_finishes,
        finish_position_points,
        grade_points,
        total_points
    FROM ranked_jockeys
    WHERE rank <= 5
    ORDER BY decade, rank;
    
""")
# Out:
#    decade  rank jockey_name  top5_finishes  finish_position_points  \
# 0   1990s     1          武豊            308                    1918
# 1   1990s     2        岡部幸雄            259                    1396
# 2   1990s     3        横山典弘            204                    1032
# 3   1990s     4         河内洋            213                    1118
# 4   1990s     5        南井克巳            165                     905
# 5   2000s     1          武豊            316                    1872
# 6   2000s     2        福永祐一            261                    1279
# 7   2000s     3        横山典弘            239                    1318
# 8   2000s     4        安藤勝己            211                    1175
# 9   2000s     5        四位洋文            196                     940
# 10  2010s     1        福永祐一            282                    1416
# 11  2010s     2        岩田康誠            272                    1388
# 12  2010s     3          武豊            239                    1301
# 13  2010s     4        川田将雅            240                    1275
# 14  2010s     5        ルメール            211                    1313
# 15  2020s     1        ルメール            202                    1243
# 16  2020s     2        川田将雅            183                    1068
# 17  2020s     3        松山弘平            134                     704
# 18  2020s     4        横山武史            117                     589
# 19  2020s     5          武豊            120                     598
#
#     grade_points  total_points
# 0            766       1469188
# 1            594        829224
# 2            499        514968
# 3            454        507572
# 4            378        342090
# 5            800       1497600
# 6            600        767400
# 7            551        726218
# 8            509        598075
# 9            484        454960
# 10           654        926064
# 11           627        870276
# 12           579        753279
# 13           590        752250
# 14           527        691951
# 15           549        682407
# 16           437        466716
# 17           300        211200
# 18           287        169043
# 19           281        168038

# %%
# 1. 一貫性スーパースター発掘
# 4年代すべてTOP5の騎手を特定
query("""
WITH your_decade_query AS (
    WITH decade_jockey_in_board AS (
       SELECT
            rr.jockey_name,
            rr.horse_name,
            r.track_name,
            rr.finish_position,
            r.grade,
            r.race_date,
            EXTRACT(YEAR FROM r.race_date) AS race_year,
            CASE
                WHEN EXTRACT(YEAR FROM r.race_date) BETWEEN 1990 AND 1999 THEN '1990s'
                WHEN EXTRACT(YEAR FROM r.race_date) BETWEEN 2000 AND 2009 THEN '2000s'
                WHEN EXTRACT(YEAR FROM r.race_date) BETWEEN 2010 AND 2019 THEN '2010s'
                WHEN EXTRACT(YEAR FROM r.race_date) BETWEEN 2020 AND 2029 THEN '2020s'
                ELSE 'その他'
            END AS decade
       FROM race_results rr
       JOIN races r ON rr.race_id = r.race_id
       WHERE rr.finish_position <= 5
    ),
    decade_jockey_points AS (
        SELECT
            jockey_name,
            decade,
            COUNT(*) AS top5_finishes,
            SUM(CASE WHEN finish_position = 1 THEN 10
                     WHEN finish_position = 2 THEN 7
                     WHEN finish_position = 3 THEN 4
                     WHEN finish_position = 4 THEN 2
                     WHEN finish_position = 5 THEN 1
                     ELSE 0 END) 
                AS finish_position_points,
            SUM(CASE WHEN grade = 'G1' THEN 5
                     WHEN grade = 'G2' THEN 2
                     WHEN grade = 'G3' THEN 1
                     ELSE 0 END) 
                AS grade_points
        FROM decade_jockey_in_board
        WHERE decade != 'その他'
        GROUP BY jockey_name, decade
    ),
    ranked_jockeys AS (
        SELECT
            jockey_name,
            decade,
            top5_finishes,
            finish_position_points,
            grade_points,
            grade_points * finish_position_points AS total_points,
            ROW_NUMBER() OVER (PARTITION BY decade ORDER BY grade_points * finish_position_points DESC) AS rank
        FROM decade_jockey_points
        WHERE top5_finishes >= 10
        ORDER BY decade, finish_position_points DESC, grade_points DESC
    )
    SELECT
        decade,
        rank,
        jockey_name,
        top5_finishes,
        finish_position_points,
        grade_points,
        total_points
    FROM ranked_jockeys
    WHERE rank <= 5
    ORDER BY decade, rank
), 
consistency_check AS (
    SELECT 
        jockey_name,
        COUNT(DISTINCT decade) as active_decades,
        STRING_AGG(decade || ':' || rank::text, ' → ' ORDER BY decade) as career_trajectory,
        AVG(total_points) as avg_points_per_decade
    FROM your_decade_query
    GROUP BY jockey_name
)
SELECT * FROM consistency_check 
WHERE active_decades >= 1
ORDER BY avg_points_per_decade DESC;
""")
# Out:
#    jockey_name  active_decades                      career_trajectory  \
# 0           武豊               4  1990s:1 → 2000s:1 → 2010s:3 → 2020s:5
# 1         岩田康誠               1                                2010s:2
# 2         福永祐一               2                      2000s:2 → 2010s:1
# 3         岡部幸雄               1                                1990s:2
# 4         ルメール               2                      2010s:5 → 2020s:1
# 5         横山典弘               2                      1990s:3 → 2000s:3
# 6         川田将雅               2                      2010s:4 → 2020s:2
# 7         安藤勝己               1                                2000s:4
# 8          河内洋               1                                1990s:4
# 9         四位洋文               1                                2000s:5
# 10        南井克巳               1                                1990s:5
# 11        松山弘平               1                                2020s:3
# 12        横山武史               1                                2020s:4
#
#     avg_points_per_decade
# 0               972026.25
# 1               870276.00
# 2               846732.00
# 3               829224.00
# 4               687179.00
# 5               620593.00
# 6               609483.00
# 7               598075.00
# 8               507572.00
# 9               454960.00
# 10              342090.00
# 11              211200.00
# 12              169043.00

# %%
# 騎手キャリア曲線分析
# 各騎手のピーク年代とキャリア推移
query("""
    WITH your_results AS (
        WITH decade_jockey_in_board AS (
            SELECT
                rr.jockey_name,
                rr.horse_name,
                r.track_name,
                rr.finish_position,
                r.grade,
                r.race_date,
                EXTRACT(YEAR FROM r.race_date) AS race_year,
                CASE
                    WHEN EXTRACT(YEAR FROM r.race_date) BETWEEN 1990 AND 1999 THEN '1990s'
                    WHEN EXTRACT(YEAR FROM r.race_date) BETWEEN 2000 AND 2009 THEN '2000s'
                    WHEN EXTRACT(YEAR FROM r.race_date) BETWEEN 2010 AND 2019 THEN '2010s'
                    WHEN EXTRACT(YEAR FROM r.race_date) BETWEEN 2020 AND 2029 THEN '2020s'
                    ELSE 'その他'
                END AS decade
            FROM race_results rr
            JOIN races r ON rr.race_id = r.race_id
            WHERE rr.finish_position <= 5
        ),
        decade_jockey_points AS (
            SELECT
                jockey_name,
                decade,
                COUNT(*) AS top5_finishes,
                SUM(CASE WHEN finish_position = 1 THEN 10
                        WHEN finish_position = 2 THEN 7
                        WHEN finish_position = 3 THEN 4
                        WHEN finish_position = 4 THEN 2
                        WHEN finish_position = 5 THEN 1
                        ELSE 0 END) 
                    AS finish_position_points,
                SUM(CASE WHEN grade = 'G1' THEN 5
                        WHEN grade = 'G2' THEN 2
                        WHEN grade = 'G3' THEN 1
                        ELSE 0 END) 
                    AS grade_points
            FROM decade_jockey_in_board
            WHERE decade != 'その他'
            GROUP BY jockey_name, decade
        ),
        ranked_jockeys AS (
            SELECT
                jockey_name,
                decade,
                top5_finishes,
                finish_position_points,
                grade_points,
                grade_points * finish_position_points AS total_points,
                ROW_NUMBER() OVER (PARTITION BY decade ORDER BY grade_points * finish_position_points DESC) AS rank
            FROM decade_jockey_points
            WHERE top5_finishes >= 10
            ORDER BY decade, finish_position_points DESC, grade_points DESC
        )
        SELECT
            decade,
            rank,
            jockey_name,
            top5_finishes,
            finish_position_points,
            grade_points,
            total_points
        FROM ranked_jockeys
        WHERE rank <= 5
        ORDER BY decade, rank
    ),
    career_analysis AS (
        SELECT 
            jockey_name,
            decade,
            total_points,
            ROW_NUMBER() OVER (PARTITION BY jockey_name ORDER BY total_points DESC) as peak_rank
        FROM your_results
    )
    SELECT 
        jockey_name,
        STRING_AGG(decade || '(' || total_points || ')', ' → ' ORDER BY decade) as career_curve,
        (SELECT decade FROM career_analysis ca2 WHERE ca2.jockey_name = ca.jockey_name AND peak_rank = 1) as peak_decade
    FROM career_analysis ca
    GROUP BY jockey_name
    HAVING COUNT(*) >= 1  -- 3年代以上活躍
    ORDER BY peak_decade, MAX(total_points) DESC;
""")
# Out:
#    jockey_name                                       career_curve peak_decade
# 0         岡部幸雄                                      1990s(829224)       1990s
# 1          河内洋                                      1990s(507572)       1990s
# 2         南井克巳                                      1990s(342090)       1990s
# 3           武豊  1990s(1469188) → 2000s(1497600) → 2010s(753279...       2000s
# 4         横山典弘                      1990s(514968) → 2000s(726218)       2000s
# 5         安藤勝己                                      2000s(598075)       2000s
# 6         四位洋文                                      2000s(454960)       2000s
# 7         福永祐一                      2000s(767400) → 2010s(926064)       2010s
# 8         岩田康誠                                      2010s(870276)       2010s
# 9         川田将雅                      2010s(752250) → 2020s(466716)       2010s
# 10        ルメール                      2010s(691951) → 2020s(682407)       2010s
# 11        松山弘平                                      2020s(211200)       2020s
# 12        横山武史                                      2020s(169043)       2020s

# %%
# 新世代 vs ベテラン対決
# 2020年代での新世代とベテランの成績比較
query("""
    WITH your_results AS (
        WITH decade_jockey_in_board AS (
            SELECT
                rr.jockey_name,
                rr.horse_name,
                r.track_name,
                rr.finish_position,
                r.grade,
                r.race_date,
                EXTRACT(YEAR FROM r.race_date) AS race_year,
                CASE
                    WHEN EXTRACT(YEAR FROM r.race_date) BETWEEN 1990 AND 1999 THEN '1990s'
                    WHEN EXTRACT(YEAR FROM r.race_date) BETWEEN 2000 AND 2009 THEN '2000s'
                    WHEN EXTRACT(YEAR FROM r.race_date) BETWEEN 2010 AND 2019 THEN '2010s'
                    WHEN EXTRACT(YEAR FROM r.race_date) BETWEEN 2020 AND 2029 THEN '2020s'
                    ELSE 'その他'
                END AS decade
            FROM race_results rr
            JOIN races r ON rr.race_id = r.race_id
            WHERE rr.finish_position <= 5
        ),
        decade_jockey_points AS (
            SELECT
                jockey_name,
                decade,
                COUNT(*) AS top5_finishes,
                SUM(CASE WHEN finish_position = 1 THEN 10
                        WHEN finish_position = 2 THEN 7
                        WHEN finish_position = 3 THEN 4
                        WHEN finish_position = 4 THEN 2
                        WHEN finish_position = 5 THEN 1
                        ELSE 0 END) 
                    AS finish_position_points,
                SUM(CASE WHEN grade = 'G1' THEN 5
                        WHEN grade = 'G2' THEN 2
                        WHEN grade = 'G3' THEN 1
                        ELSE 0 END) 
                    AS grade_points
            FROM decade_jockey_in_board
            WHERE decade != 'その他'
            GROUP BY jockey_name, decade
        ),
        ranked_jockeys AS (
            SELECT
                jockey_name,
                decade,
                top5_finishes,
                finish_position_points,
                grade_points,
                grade_points * finish_position_points AS total_points,
                ROW_NUMBER() OVER (PARTITION BY decade ORDER BY grade_points * finish_position_points DESC) AS rank
            FROM decade_jockey_points
            WHERE top5_finishes >= 10
            ORDER BY decade, finish_position_points DESC, grade_points DESC
        )
        SELECT
            decade,
            rank,
            jockey_name,
            top5_finishes,
            finish_position_points,
            grade_points,
            total_points
        FROM ranked_jockeys
        WHERE rank <= 20
        ORDER BY decade, rank
    )
    SELECT 
        decade,
        jockey_name,
        total_points as points_2020s,
        CASE 
            WHEN jockey_name IN (SELECT jockey_name FROM your_results WHERE decade = '1990s') THEN 'レジェンド'
            WHEN jockey_name IN (SELECT jockey_name FROM your_results WHERE decade = '2000s') THEN 'ベテラン'
            WHEN jockey_name IN (SELECT jockey_name FROM your_results WHERE decade = '2010s') THEN '中堅'
            ELSE '新世代'
        END as generation_type
    FROM your_results 
    WHERE decade = '2020s'
    ORDER BY total_points DESC;
""")
# Out:
#    decade jockey_name  points_2020s generation_type
# 0   2020s        ルメール        682407              中堅
# 1   2020s        川田将雅        466716              中堅
# 2   2020s        松山弘平        211200             新世代
# 3   2020s        横山武史        169043             新世代
# 4   2020s          武豊        168038           レジェンド
# 5   2020s        戸崎圭太        154714              中堅
# 6   2020s        福永祐一        127205            ベテラン
# 7   2020s        Ｍ．デム        111946              中堅
# 8   2020s        横山典弘         79800           レジェンド
# 9   2020s        池添謙一         75440            ベテラン
# 10  2020s        坂井瑠星         67614             新世代
# 11  2020s        岩田望来         53785             新世代
# 12  2020s         浜中俊         53290              中堅
# 13  2020s        岩田康誠         47371            ベテラン
# 14  2020s        鮫島克駿         43368             新世代
# 15  2020s        北村友一         42770              中堅
# 16  2020s        田辺裕信         39528              中堅
# 17  2020s        和田竜二         38070              中堅
# 18  2020s        横山和生         37023             新世代
# 19  2020s        西村淳也         34452             新世代

# %%
"""
🚀 問題4: 黄金コンビ発掘システム
騎手×調教師の組み合わせで「隠れた黄金コンビ」を発見してください。以下の条件をすべて満たすコンビを抽出：

過去5年間で20回以上タッグを組んでいる
重賞勝率25%以上
一般的な勝率より統計的に有意に高い成績
G1での勝利経験がある

さらに、各コンビの「得意距離帯」「得意競馬場」も分析。
"""

query ("""

    WITH jockey_trainer_stats AS (
        SELECT
            rr.jockey_name,
            rr.trainer_name,
            COUNT (*) AS total_runs,
            COUNT (CASE WHEN rr.finish_position = 1 THEN 1 END) AS wins,
            COUNT (CASE WHEN rr.finish_position = 1 THEN 1 END) * 100.0 / COUNT(*) AS win_rate,
            COUNT (CASE WHEN rr.finish_position = 1 AND r.grade = 'G1' THEN 1 END) AS g1_wins,
       
            -- 距離帯別勝率を計算
            COUNT(CASE WHEN r.distance::INTEGER <= 1200 AND rr.finish_position = 1 THEN 1 END) * 100.0 
                / NULLIF(COUNT(CASE WHEN r.distance::INTEGER <= 1200 THEN 1 END), 0) AS sprint_rate,
            COUNT(CASE WHEN r.distance::INTEGER BETWEEN 1201 AND 1800 AND rr.finish_position = 1 THEN 1 END) * 100.0 
                / NULLIF(COUNT(CASE WHEN r.distance::INTEGER BETWEEN 1201 AND 1800 THEN 1 END), 0) AS mile_rate,
            COUNT(CASE WHEN r.distance::INTEGER BETWEEN 1801 AND 2400 AND rr.finish_position = 1 THEN 1 END) * 100.0 
                / NULLIF(COUNT(CASE WHEN r.distance::INTEGER BETWEEN 1801 AND 2400 THEN 1 END), 0) AS middle_rate,
            COUNT(CASE WHEN r.distance::INTEGER > 2400 AND rr.finish_position = 1 THEN 1 END) * 100.0 
                / NULLIF(COUNT(CASE WHEN r.distance::INTEGER > 2400 THEN 1 END), 0) AS long_rate,
       
            -- 得意競馬場 
            MODE() WITHIN GROUP (ORDER BY
                CASE WHEN rr.finish_position = 1 THEN r.track_name END) 
                AS favorite_track,

            -- 主な代表馬
            MAX(CASE WHEN rr.finish_position = 1 THEN rr.horse_name END) AS top_horse,
       
            -- 勝利レースにおけるオッズの平均
            AVG(CASE WHEN rr.finish_position =1 THEN rr.odds END) AS avg_winning_odds,
       
            -- 勝利レースにおける平均開催年
            AVG(CASE WHEN rr.finish_position = 1 THEN EXTRACT(YEAR FROM r.race_date) END) AS avg_winning_year
       
        FROM race_results rr
        JOIN races r ON r.race_id = rr.race_id
        GROUP BY rr.jockey_name, rr.trainer_name
        HAVING COUNT(*) >= 20
            AND COUNT (CASE WHEN r.grade = 'G1' AND rr.finish_position = 1 THEN 1 END) >= 1
    )
    SELECT
        ROUND(win_rate, 2) AS win_rate,
        ROUND(avg_winning_year, 0)::INTEGER AS avg_winning_year,
        jockey_name,
        trainer_name,
        total_runs,
        wins,
        g1_wins,
        ROUND(avg_winning_odds, 2) AS avg_winning_odds,
        CASE 
            WHEN GREATEST(COALESCE(sprint_rate, 0), COALESCE(mile_rate, 0), COALESCE(long_rate, 0)) = COALESCE(sprint_rate, 0) THEN '短距離'
            WHEN GREATEST(COALESCE(sprint_rate, 0), COALESCE(mile_rate, 0), COALESCE(long_rate, 0)) = COALESCE(mile_rate, 0) THEN 'マイル'
            WHEN GREATEST(COALESCE(sprint_rate, 0), COALESCE(mile_rate, 0), COALESCE(long_rate, 0)) = COALESCE(middle_rate, 0) THEN '中距離'
            ELSE '長距離'
        END AS best_distance_type,
        favorite_track,
        top_horse
    FROM jockey_trainer_stats
    WHERE win_rate >= 10.0
          AND g1_wins >= 3
    ORDER BY win_rate DESC
       
""")
# Out:
#     win_rate  avg_winning_year jockey_name trainer_name  total_runs  wins  \
# 0      42.31              2016          武豊         清水久詞          26    11
# 1      40.91              1998          武豊         白井寿昭          22     9
# 2      40.00              2012        内田博幸         須貝尚介          20     8
# 3      37.50              2021        北村友一         斉藤崇史          24     9
# 4      36.23              2001          武豊         池江泰郎          69    25
# 5      35.71              2006        安藤勝己         松田国英          42    15
# 6      31.25              2020        ルメール          国枝栄          48    15
# 7      30.00              2016         ムーア          堀宣行          30     9
# 8      29.63              2021        吉田隼人         須貝尚介          27     8
# 9      28.95              2017        岩田康誠         安田隆行          38    11
# 10     28.57              2021        川田将雅         高野友和          35    10
# 11     28.44              2021        川田将雅         中内田充         109    31
# 12     28.41              2018        ルメール         藤沢和雄          88    25
# 13     27.27              1998         的場均         尾形充弘          33     9
# 14     26.67              2003         ペリエ         藤沢和雄          45    12
# 15     25.97              2003          武豊          橋田満          77    20
# 16     22.41              2000          武豊         伊藤雄二          58    13
# 17     22.22              2011        池添謙一         池江泰寿          63    14
# 18     21.82              2008          武豊         角居勝彦          55    12
# 19     21.74              1995        田原成貴         松元省一          23     5
# 20     21.62              2022        ルメール         木村哲也          74    16
# 21     21.57              2018        川田将雅         安田隆行          51    11
# 22     20.83              2021        横山武史         鹿戸雄一          24     5
# 23     20.59              2019        福永祐一         矢作芳人          34     7
# 24     20.45              2011        蛯名正義         二ノ宮敬          44     9
# 25     20.41              2022          武豊         友道康夫          49    10
# 26     20.34              2003         本田優         西浦勝一          59    12
# 27     20.00              1992        小島貞博         戸山為夫          40     8
# 28     20.00              2001          武豊          森秀行          60    12
# 29     19.44              2016        Ｍ．デム          堀宣行          36     7
# 30     19.44              2021        ルメール         手塚貴久          36     7
# 31     17.89              1994         小島太         境勝太郎          95    17
# 32     17.48              2010        蛯名正義          国枝栄         103    18
# 33     17.46              2005        佐藤哲三         佐々木晶         126    22
# 34     17.44              1998        岡部幸雄         藤沢和雄         195    34
# 35     16.87              2003          武豊         橋口弘次          83    14
# 36     16.67              2008        安藤勝己         松田博資          72    12
# 37     16.13              2017        川田将雅         池江泰寿          93    15
# 38     15.66              2004        福永祐一         瀬戸口勉          83    13
# 39     15.38              2021        松山弘平         杉山晴紀          26     4
# 40     14.63              1998         河内洋         長浜博之          82    12
# 41     13.89              2010        藤田伸二           昆貢          36     5
# 42     13.64              2010        岩田康誠         松田博資          44     6
# 43     13.58              2014        福永祐一         友道康夫          81    11
# 44     13.21              2005        蛯名正義          小島太          53     7
# 45     13.08              2004        横山典弘         藤沢和雄         107    14
# 46     12.77              2008        岩田康誠         角居勝彦          47     6
# 47     12.50              1998        角田晃一          佐山優          64     8
# 48     12.24              2004        池添謙一         鶴留明雄          98    12
# 49     12.24              2002         幸英明         松元省一          49     6
# 50     12.23              2000        和田竜二         岩元市三         139    17
# 51     12.12              1999        四位洋文         白井寿昭          33     4
# 52     10.94              2018         浜中俊         池江泰寿          64     7
# 53     10.64              2016        戸崎圭太         藤原英昭          47     5
#
#     g1_wins  avg_winning_odds best_distance_type favorite_track  top_horse
# 0         6              4.00                長距離             京都   トウケイヘイロー
# 1         5              2.99                長距離             東京   ダンスパートナー
# 2         4              9.50                長距離             阪神    ゴールドシップ
# 3         5              3.23                長距離             中山       ラーゴム
# 4        11              1.94                長距離             京都    メジロランバダ
# 5         7              3.05                マイル             阪神   フサイチホウオー
# 6         8              2.59                マイル             東京  ミッキーグローリー
# 7         3              4.74                短距離             中山   リアルインパクト
# 8         3             13.10                マイル             札幌        ソダシ
# 9         4              7.97                短距離             阪神    ロードカナロア
# 10        4              5.38                マイル             阪神      レイパパレ
# 11        6              3.70                マイル             中京  リバティアイランド
# 12       10              3.91                短距離             阪神      レイデオロ
# 13        4              6.71                マイル             中山  ブラックタキシード
# 14        7              2.99                長距離             中山     マグナーテン
# 15        5              3.12                マイル             東京     スズカマンボ
# 16        5              2.01                マイル             阪神  ファインモーション
# 17        8              3.84                長距離             阪神  ドリームジャーニー
# 18        3              3.78                長距離             東京  ヴィクトワールピサ
# 19        3              5.16                短距離             中山    フラワーパーク
# 20        8              2.92                長距離             東京      レガレイラ
# 21        3              4.16                短距離             中山  ミッキーゴージャス
# 22        3              4.56                長距離             中山     セットアップ
# 23        5              2.29                長距離             中山   リアルスティール
# 24        3             18.19                マイル             東京   ナカヤマフェスタ
# 25        6              4.82                長距離             中山   ワールドプレミア
# 26        5             11.78                マイル             阪神  マイソールサウンド
# 27        3              3.56                マイル             中山   レガシーワールド
# 28        3              2.70                長距離             中山   スキーキャプテン
# 29        3              5.47                マイル             中山    ネオリアリズム
# 30        4              4.69                長距離             京都  ブラウンラチェット
# 31        4              5.71                短距離             中山    ビッグファイト
# 32        7              9.63                長距離             中山    マツリダゴッホ
# 33        3              5.93                長距離             阪神  タップダンスシチー
# 34        8              4.13                マイル             東京    ロードクロノス
# 35        3              3.34                短距離             京都   ローズキングダム
# 36        4              3.68                マイル             阪神     マルセリーナ
# 37        3              5.05                短距離             京都     ラブリーデイ
# 38        4              5.68                マイル             京都    リキセレナード
# 39        3              3.08                マイル             中山   デアリングタクト
# 40        3              3.64                マイル             中山  ミッドナイトベット
# 41        3             10.44                短距離             中京   ローレルゲレイロ
# 42        3              7.18                マイル             東京     ブエナビスタ
# 43        3              4.47                短距離             阪神      ヴィブロス
# 44        3              5.77                短距離             京都  ミッドサマーフェア
# 45        3              3.94                マイル             東京    レッドスパーダ
# 46        4             10.08                長距離             京都  ヴィクトワールピサ
# 47        4             11.13                長距離             京都     ヒシミラクル
# 48        3             11.46                短距離             京都  トウショウオリオン
# 49        3              4.03                マイル             東京      トゥナンテ
# 50        7              5.36                長距離             京都  ポートブライアンズ
# 51        3              8.68                マイル             京都   ダンスパートナー
# 52        3              5.61                マイル            東京1     ラブリーデイ
# 53        4             11.36                短距離             東京   ストレイトガール

# %%
# 高野Q


query ("""

    WITH horse_track_condition_stats AS (
        SELECT
            rr.horse_id,
            COUNT(*) AS total_runs,
            COUNT(CASE WHEN rr.finish_position = 1 THEN 1 END) AS wins,
            
            -- 重について
            COUNT(CASE WHEN r.track_condition = '重' THEN 1 END) AS runs_firm,
            COUNT(CASE WHEN r.track_condition = '重' AND rr.finish_position = 1 THEN 1 END) AS wins_firm,
            SUM(CASE WHEN r.track_condition = '重' AND rr.finish_position <= 5 THEN 6 - rr.finish_position END) * 100.0 
                / COUNT(CASE WHEN r.track_condition = '重' THEN 1 END)  AS points_firm,
       
            -- 不良について
            COUNT(CASE WHEN r.track_condition = '不良' THEN 1 END) AS runs_yielding,
            COUNT(CASE WHEN r.track_condition = '不良' AND rr.finish_position = 1 THEN 1 END) AS wins_yielding,
            SUM(CASE WHEN r.track_condition = '不良' AND rr.finish_position <= 5 THEN 6 - rr.finish_position END) * 100.0 
                / COUNT(CASE WHEN r.track_condition = '不良' THEN 1 END)  AS points_yielding
       
        FROM race_results rr
        JOIN races r ON rr.race_id = r.race_id
        WHERE r.track_condition IN ('重', '不良')
        GROUP BY rr.horse_id
    ),
    sire_track_condition_stats AS (
        SELECT
            h.sire_id,
            COUNT(*) AS total_children,
            SUM(htcs.total_runs) AS total_runs,
            SUM(htcs.wins) AS total_wins,
       
            -- 重馬場の計算
            SUM(htcs.runs_firm) AS total_runs_firm,
            SUM(htcs.wins_firm) AS total_wins_firm,
            SUM(htcs.points_firm * htcs.runs_firm) / NULLIF(SUM(htcs.runs_firm), 0) AS avg_points_firm,
            -- 不良馬場の計算
            SUM(htcs.runs_yielding) AS total_runs_yielding,
            SUM(htcs.wins_yielding) AS total_wins_yielding,
            SUM(htcs.points_yielding * htcs.runs_yielding) / NULLIF(SUM(htcs.runs_yielding), 0) AS avg_points_yielding,

            -- 集計
            SUM(htcs.points_firm + htcs.points_yielding * 2.0) AS total_points,
            ROW_NUMBER() OVER (ORDER BY SUM(htcs.points_firm + htcs.points_yielding * 2.0) DESC) AS rank
       
        FROM horse_track_condition_stats htcs
        JOIN horses h ON htcs.horse_id = h.id
        WHERE h.sire_id IS NOT NULL AND h.sire_id != ''
        GROUP BY h.sire_id
    )
    SELECT
        ROUND(total_points, 2) AS total_points
        h.name_ja,
        total_children,
        total_runs,
        total_wins,
        ROUND(total_wins * 100.0 / NULLIF(total_runs, 0), 2) AS overall_win_rate,
        total_runs_firm,
        total_wins_firm,
        ROUND(total_wins_firm * 100.0 / NULLIF(total_runs_firm, 0), 2) AS win_rate_firm,
        ROUND(avg_points_firm, 2) AS avg_points_firm,
        total_runs_yielding,
        total_wins_yielding,
        ROUND(total_wins_yielding * 100.0 / NULLIF(total_runs_yielding, 0), 2) AS win_rate_yielding,
        ROUND(avg_points_yielding, 2) AS avg_points_yielding,
    FROM sire_track_condition_stats
    JOIN horses h ON sire_track_condition_stats.sire_id = h.id
    WHERE total_children >= 5 AND total_runs >= 20 AND total_points IS NOT NULL
    ORDER BY rank;
    

""")
# Out:
#      name_ja  total_children  total_runs  total_wins  overall_win_rate  \
# 0  ディープインパクト             129       197.0        17.0              8.63
# 1   キングカメハメハ              68       103.0        10.0              9.71
# 2    ルーラーシップ              18        27.0         3.0             11.11
# 3    ステイゴールド              51        69.0         7.0             10.14
# 4     ハーツクライ              49        60.0         4.0              6.67
# 5  ダンスインザダーク              27        39.0         1.0              2.56
# 6  シンボリクリスエス              18        21.0         1.0              4.76
# 7  マンハッタンカフェ              38        55.0         3.0              5.45
# 8  スクリーンヒーロー              16        24.0         3.0             12.50
# 9    ダイワメジャー              40        49.0         3.0              6.12
#
#    total_runs_firm  total_wins_firm  win_rate_firm  avg_points_firm  \
# 0            137.0             14.0          10.22           138.69
# 1             77.0              6.0           7.79           106.49
# 2             21.0              1.0           4.76            80.95
# 3             46.0              5.0          10.87           132.61
# 4             43.0              2.0           4.65           113.95
# 5             27.0              0.0           0.00           118.52
# 6             14.0              0.0           0.00           114.29
# 7             38.0              2.0           5.26            84.21
# 8             19.0              3.0          15.79           142.11
# 9             33.0              1.0           3.03            96.97
#
#    total_runs_yielding  total_wins_yielding  win_rate_yielding  \
# 0                 60.0                  3.0               5.00
# 1                 26.0                  4.0              15.38
# 2                  6.0                  2.0              33.33
# 3                 23.0                  2.0               8.70
# 4                 17.0                  2.0              11.76
# 5                 12.0                  1.0               8.33
# 6                  7.0                  1.0              14.29
# 7                 17.0                  1.0               5.88
# 8                  5.0                  0.0               0.00
# 9                 16.0                  2.0              12.50
#
#    avg_points_yielding  total_points
# 0               100.00       4900.00
# 1               130.77       2500.00
# 2               233.33       2316.67
# 3               147.83       1800.00
# 4               111.76       1500.00
# 5                66.67       1350.00
# 6               171.43       1000.00
# 7                94.12        800.00
# 8                20.00        400.00
# 9                68.75        400.00
